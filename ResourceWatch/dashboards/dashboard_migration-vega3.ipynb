# %% [markdown]
# #### functionality

# %%
from vega3 import Vega 
import json
import requests
import getpass

# %%
bearerToken = getpass.getpass('Please enter your bearer Token:')
def PatchApi(vegaSpec, datasetId, WidgetId):
    url = 'https://api.resourcewatch.org/v1/dataset/{0}/widget/{1}'.format(datasetId,WidgetId)
    body = {'widgetConfig': vegaSpec
           
           }
    Headers = {'content-type': 'application/json; charset=UTF-8',
               'Authorization': 'Bearer {0}'.format(bearerToken)}
    
    r = requests.patch(url=url ,data=json.dumps(body), headers=Headers)
    return r.json()
# Out:
# Please enter your bearer Token:········

# %% [markdown]
# #### VegaConfig file

# %%
Config="""
{
  "range": {
    "dotSize": [20, 250],
    "category": [
      "#3BB2D0",
      "#2C75B0",
      "#FAB72E",
      "#EF4848",
      "#65B60D",
      "#717171"
    ],
    "category20": [
      "#3BB2D0",
      "#2C75B0",
      "#FAB72E",
      "#EF4848",
      "#65B60D",
      "#C32D7B",
      "#F577B9",
      "#5FD2B8",
      "#F1800F",
      "#9F1C00",
      "#A5E9E3",
      "#B9D765",
      "#393F44",
      "#CACCD0",
      "#717171"
    ],
    "ordinal": { "scheme": "greens" },
    "ramp": { "scheme": "purples" }
  },
  "axis": {
    "labelFontSize": 13,
    "labelFont": "Lato",
    "labelColor": "#717171",
    "labelPadding": 10,
    "ticks": true,
    "tickSize": 5,
    "tickColor": "#A9ABAD",
    "tickOpacity": 0.5,
    "tickExtra": false
  },
  "axisX": {
    "bandPosition": 0.5,
    "domainWidth": 1.2,
    "domainColor": "#A9ABAD",
    "labelAlign": "center",
    "labelBaseline": "top"
  },
  "axisY": {
    "domain": false,
    "labelAlign": "left",
    "labelBaseline": "bottom",
    "tickOpacity": 0.5,
    "grid": true,
    "ticks": false,
    "gridColor": "#A9ABAD",
    "gridOpacity": 0.5
  },
  "mark": {
    "fill": "#3BB2D0"
  },
  "symbol": {
    "fill": "#3BB2D0",
    "stroke": "#fff"
  },
  "rect": {
    "cornerRadius": 0,
    "fill": "#3BB2D0"
  },
  "line": {
    "interpolate": "linear",
    "stroke": "#3BB2D0",
    "fillOpacity": 0
  }
}
"""

# %% [markdown]
# #### template

# %%
widgetID=""
datasetID=""
specV3=json.loads("""
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# # Biodiversity

# %% [markdown]
# # Cities

# %% [markdown]
# ## Urban Expansion

# %%
widgetID="b9186ce9-78ae-418b-a6d3-d521283ce485"
datasetID="565c3cb1-8015-4029-b497-e9245608580f"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "data": [
    {
      "name": "table",
      "values": [
        {
          "x": "2015",
          "length": 1685,
          "y": "2.84 million sq km"
        },
        {
          "x": "2000",
          "length": 1505,
          "y": "2.26 million sq km"
        },
        {
          "x": "1990",
          "length": 1367,
          "y": "1.87 million sq km"
        },
        {
          "x": "1975",
          "length": 1049,
          "y": "1.10 million sq km"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "linear",
      "nice": true,
      "zero": true,
      "range": "width",
      "domain": {
        "data": "table",
        "field": "length"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "nice": true,
      "zero": true,
      "range": "height",
      "domain": {
        "data": "table",
        "field": "length"
      }
    },
    {
      "name": "color",
      "range": "ramp",
      "reverse": true,
      "type": "ordinal",
      "domain": {"data": "table","field": "x"}
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "title": "Extent of Urbanisation (km)",
      "labelOverlap":"parity"
    },
    {
      "orient": "left",
      "scale": "y",
      "title": "Extent of Urbanisation (km)",
      "labelOverlap":"parity"
    }
  ],
  "marks": [
    {"name":"area",
      "type": "rect",
      "interactive":true,
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "length"
          },
          "y": {
            "scale": "y",
            "field": "length"
          },
          "x2": {
            "scale": "x",
            "value": 0
          },
          "y2": {
            "scale": "y",
            "value": 0
          }
        },
        "update": {
          "fill": {
            "scale": "color",
            "field": "x"
          },
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fill": {
           "value": "#fff"
          },
          "fillOpacity": {
            "value": 1
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Year of Extent:",
      "fill": "color",
      "orient": "right"
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "x",
            "property": "year",
            "type": "number",
            "format": "4"
          },
          {
            "column": "y",
            "property": "category",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=200
vega4view['height']=200
Vega(vega4view)
# Out:
# <div class="vega-embed" id="17277309-8877-40d1-9956-7fa377b37dfa"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-11-29T10:35:23.142Z',
#    'dataset': '565c3cb1-8015-4029-b497-e9245608580f',
#    'default': True,
#    'defaultEditableWidget': False,
#    'description': '',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Urban Expansion',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'Urban-Expansion',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-11-29T10:35:23.142Z',
#    'userId': '57a0aa1071e394dd32ffe137',
#    'verified': False,
#    'widgetConfig': {'autosize': {'contains': 'padding',
#      'resize': True,
#      'type': 'pad'},
#     'axes': [{'labelOverlap': 'parity',
#       'orient': 'bottom',
#       'scale': 'x',
#       'title': 'Extent of Urbanisation (km)'},
#      {'labelOverlap': 'parity',
#       'orient': 'left',
#       'scale': 'y',
#       'title': 'Extent of Urbanisation (km)'}],
# ...

# %% [markdown]
# # Climate

# %% [markdown]
# ## Global Land-Ocean Temperature Index

# %%
widgetID="21906ec8-9766-4f8f-9a1e-e15d05d88c7c"
datasetID="9b6fcdb8-9c74-4d83-b066-889a7b4362f5"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/ca59432c-b602-4d4a-809e-2a57758bddf3?sql=SELECT distinct on (year) year as x, annual_mean as y FROM cli_044_global_mean_temp WHERE (year >= 2000) ORDER BY year ASC",
      "format": {"type": "json","property": "data"}
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "linear",
      "nice": false,
      "zero": false,
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "nice": true,
      "zero": true,
      "range": "height",
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "range": "ramp",
      "reverse": true,
      "type": "ordinal",
      "domain": {
        "data": "table",
        "field": "x"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "title": "Year",
      "format":".4",
      "labelOverlap": "parity"
    },
    {
      "orient": "left",
      "scale": "y",
      "title": "Global temperature increase (ºC)",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "type": "line",
      "interactive": false,
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "lines"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "datum.y",
            "property": "ºC",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "datum.x",
            "property": "year",
            "type": "number",
            "format": ".4"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="c9dd877a-5cb0-460d-815a-e14335c436cb"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-12-18T17:54:56.991Z',
#    'dataset': '9b6fcdb8-9c74-4d83-b066-889a7b4362f5',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'This graph illustrates the change in global surface temperature relative to 1951-1980 average temperatures. Sixteen of the 17 warmest years in the 136-year record all have occurred since 2001, with the exception of 1998. The year 2016 ranks as the warmest on record.  For additional information please see https://climate.nasa.gov/vital-signs/global-temperature/.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Global Land-Ocean Temperature Index',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'temp',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-12-18T17:54:56.991Z',
#    'userId': '58f63c81bd32c60206ed6b12',
#    'verified': False,
# ...

# %% [markdown]
# ## Sea Level Rise

# %%
widgetID="ce78c907-cf11-4f42-8d7b-0622f79ee1a1"
datasetID="06f42f22-df3e-4732-a558-beaa3708b247"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/ca59432c-b602-4d4a-809e-2a57758bddf3?sql=SELECT distinct on (year) year as x, smoothed_gmsl_var_mm as y FROM cli_040_sea_level WHERE (year >= 2000) ORDER BY year ASC",
      "format": {"type": "json","property": "data"}
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "linear",
      "nice": false,
      "zero": false,
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "nice": true,
      "zero": true,
      "range": "height",
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "range": "ramp",
      "reverse": true,
      "type": "ordinal",
      "domain": {
        "data": "table",
        "field": "x"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "title": "Year",
      "format":".4",
      "labelOverlap": "parity"
    },
    {
      "orient": "left",
      "scale": "y",
      "title": "Sea Level Rise (mm)",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "type": "line",
      "interactive": false,
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "lines"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "datum.y",
            "property": "mm",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "datum.x",
            "property": "Year",
            "type": "number",
            "format": ".4"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="780a02bc-ffc9-48af-aa21-5b585bb84263"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-12-18T16:47:07.169Z',
#    'dataset': '06f42f22-df3e-4732-a558-beaa3708b247',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'Sea level rise is caused primarily by two factors related to global warming: the added water from melting ice sheets and glaciers and the expansion of sea water as it warms. This graph tracks the change in sea level since 1993 as observed by satellites.  For additional information please see https://climate.nasa.gov/vital-signs/sea-level/.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Sea Level Rise',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'SL',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-12-18T16:47:07.169Z',
#    'userId': '58f63c81bd32c60206ed6b12',
#    'verified': False,
#    'widgetConfig': {'autosize': {'contains': 'padding',
# ...

# %% [markdown]
# ## Total GHG Emissions Excluding Land Use Change and Forestry (Metric Tons of CO2 Equivalent)

# %%
widgetID="3ddc5512-6409-478c-9997-331b9ec80ecf"
datasetID="065011cb-7441-4770-a121-e7c2058e65fb"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/ca59432c-b602-4d4a-809e-2a57758bddf3?sql=SELECT year as x,  total_ghg_emissions_excluding_land_use_change_and_forestry_mtc as y FROM cli_008_greenhouse_gas_emissions_country_sector_edit WHERE (year >= 2000) AND country='World' ORDER BY year ASC",
      "format": {"type": "json","property": "data"}
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "linear",
      "nice": false,
      "zero": false,
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "nice": true,
      "zero": true,
      "range": "height",
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "range": "ramp",
      "reverse": true,
      "type": "ordinal",
      "domain": {
        "data": "table",
        "field": "x"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "title": "Year",
      "format":"4f",
      "labelOverlap": "parity"
    },
    {
      "orient": "left",
      "format":"2s",
      "scale": "y",
      "title": "GHG Emissions (MtCO2)",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "type": "line",
      "interactive": false,
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "lines"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "datum.y",
            "property": "value",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "datum.x",
            "property": "year",
            "type": "number",
            "format": ".4"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="b4bedc37-9257-474a-8b31-7ae6a0113997"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2018-01-26T14:59:09.972Z',
#    'dataset': '065011cb-7441-4770-a121-e7c2058e65fb',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'This chart defines the top 10 emitters based on their total annual emissions, also known as “absolute emissions.” Why? Over time, the absolute amount of GHGs emitted is what ultimately affects atmospheric concentrations of GHGs and the global carbon budget (see cumulative emissions, below). So the largest absolute emitters today have a larger role to play in determining the climate of the future. Regardless of other factors, these total annual numbers will have to be reduced for the top 10 emitters if global warming is to be limited to 2 degrees C.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Total GHG Emissions Including Land Use Change and Forestry (Metric Tons of CO2 Equivalent)',
#    'protected': False,
# ...

# %% [markdown]
# ## Atmospheric CO2 levels (Mauna Loa Observatory)

# %%
widgetID="13eed768-b18b-4221-8106-160e1933c4df"
datasetID="e4b9ef04-7bda-4757-b70f-c129f2a9cc8e"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/ca59432c-b602-4d4a-809e-2a57758bddf3?sql=SELECT distinct on (yr) yr as x, co2 as y FROM dash_0083_temp_co2 WHERE (yr >= 2000) ORDER BY yr,mn ASC",
      "format": {"type": "json","property": "data"}
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "linear",
      "nice": false,
      "zero": false,
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "nice": true,
      "zero": true,
      "range": "height",
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "range": "ramp",
      "reverse": true,
      "type": "ordinal",
      "domain": {
        "data": "table",
        "field": "x"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "title": "Year",
      "format":".4",
      "labelOverlap": "parity"
    },
    {
      "orient": "left",
      "scale": "y",
      "title": "CO2 (ppm)",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "type": "line",
      "interactive": false,
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "lines"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "value",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "x",
            "property": "category",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="6bb5d1b9-779b-4a0a-b5bb-a0090d7bd0dc"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'errors': [{'detail': 'Widget not found with the id 13eed768-b18b-4221-8106-160e1933c4df',
#    'status': 404}]}

# %% [markdown]
# # Commerce

# %% [markdown]
# ## Most Highly Connected Ports

# %%
widgetID="707dfd6e-e2ed-49ec-a0f5-70c8f716a744"
datasetID="c17296d6-8629-4769-900b-81d7a7037b1e"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },

  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/c17296d6-8629-4769-900b-81d7a7037b1e?sql=SELECT port AS y, pciinbound, pcioutbound AS x FROM com_029_data_global_container_port_network ORDER BY pcioutbound DESC LIMIT 10",
      "format": {"type": "json","property": "data"}
    }
    
  ],

  "marks": [
    {
      "type": "rect",
      "from": {"data": "table"},
      "encode": {
        "update": {
           "opacity": {
            "value": 1
          },
          "x": {"scale": "x", "value": 0},
          "x2": {"scale": "x", "field": "x"},
          "y": {"scale": "y", "field": "y"},
          "height": {"scale": "y", "band": 1}
        },
        "hover":{
           "opacity": {
            "value": 0.8
          }
        }
      }
    }
  ],

  "scales": [
    {
      "name": "x",
      "type": "linear",
      "domain": {"data": "table", "field": "x"},
      "range": "width",
      "nice": true
    },
    {
      "name": "y",
      "type": "band",
      "domain": {
        "data": "table", "field": "y"
      },
      "range": "height",
      "padding": 0.05
    }
  ],

  "axes": [
    {
      "scale": "x",
      "orient": "bottom",
      "labelOverlap": "parity",
      "format": ".2",
      "tickCount": 5
    },
    {
      "scale": "y",
      "labelOverlap": "parity",
      "orient": "left"
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "x",
            "property": "value",
            "type": "number",
            "format": ".2"
          },
          {
            "column": "y",
            "property": "Country",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="473e68a5-60bb-4077-8f18-a17b1bd61610"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-12-13T20:40:23.694Z',
#    'dataset': 'c17296d6-8629-4769-900b-81d7a7037b1e',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': '',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Most Highly Connected Ports',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'ports',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-12-13T20:40:23.694Z',
#    'userId': '5981e73b0c069f3c93dc5e2a',
#    'verified': False,
#    'widgetConfig': {'autosize': {'contains': 'padding',
#      'resize': True,
#      'type': 'pad'},
#     'axes': [{'format': '.2',
#       'labelOverlap': 'parity',
#       'orient': 'bottom',
#       'scale': 'x',
#       'tickCount': 5},
#      {'labelOverlap': 'parity', 'orient': 'left', 'scale': 'y'}],
#     'data': [{'format': {'property': 'data', 'type': 'json'},
#       'name': 'table',
# ...

# %% [markdown]
# ## Global Material Extraction by Type

# %%
widgetID="72febd0b-7430-4cac-9a18-64f10f6b42be"
datasetID="c61c364b-1d68-4dd9-ae3d-76c2a0022280"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/573bbe7b-6282-4ea5-80c4-6561a543401f?sql=SELECT year as x, metal_ores/1000000.0 AS a_metal_ores, fossil_fuels/1000000.0 AS b_fossil_fuels, non_metallic_minerals/1000000.0 AS c_non_metallic_minerals, biomass/1000000.0 AS d_biomass FROM dash_0078_global_raw_material_extraction",
      "format": {"type": "json","property": "data"},
      "transform": [
        {
          "type": "fold",
          "as": ["c","y"],
          "fields": [
            "a_metal_ores",
            "b_fossil_fuels",
            "c_non_metallic_minerals",
            "d_biomass"
          ]
        },
        {
          "type": "stack",
          "groupby": ["x"],
          "sort": {"field": "c"},
          "field": "y"
        },
        {
"type": "formula",
"as": "c",
"expr": "replace(upper(slice(datum.c,0,1))+slice(datum.c,1),/_/g,' ')"
}
      ]
    }
  ],

  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {"data": "table", "field": "x"}
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true, "zero": true,
      "domain": {"data": "table", "field": "y1"}
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {"data": "table", "field": "c"}
    }
  ],

  "axes": [
    {"title":"years","orient": "bottom", "scale": "x", "zindex": 1,
    "labelOverlap": "parity",
    "labelPadding":6,
     "encode":{
    "labels": {
             "update":{"angle": {"value": 90},
             "align": {"value": "left"},
             "baseline": {"value": "middle"}}}
    }},
    {"title":"Extracted Material, Billions of Tonnes","orient": "left", "scale": "y", "zindex": 0, "labelOverlap": "parity"}
  ],

  "marks": [
    {
      "type": "rect",
      "from": {"data": "table"},
      "encode": {
        "enter": {
          "x": {"scale": "x", "field": "x"},
          "width": {"scale": "x", "band": 1, "offset": -1},
          "y": {"scale": "y", "field": "y0"},
          "y2": {"scale": "y", "field": "y1"},
          "fill": {"scale": "color", "field": "c"}
        },
        "update": {
          "fillOpacity": {"value": 1}
        },
        "hover": {
          "fillOpacity": {"value": 0.5}
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Year of Extent:",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "value",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "c",
            "property": "type",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Year:",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="8a848e74-6d89-41d4-b9cc-607b2c5b5df4"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-12-13T22:03:38.870Z',
#    'dataset': 'c61c364b-1d68-4dd9-ae3d-76c2a0022280',
#    'default': False,
#    'defaultEditableWidget': False,
# ...

# %% [markdown]
# ## Global Material Extraction by Region

# %%
widgetID="e5d45dd1-aae9-41b2-bb50-d028797d66c1"
datasetID="c61c364b-1d68-4dd9-ae3d-76c2a0022280"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },

  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/ca586f45-01d6-496d-811a-f36a10f583aa?sql=SELECT year as x, africa/1000000 AS a_africa, asia_pacific/1000000 AS b_asia_pacific, eecca/1000000 AS c_eecca, europe/1000000 AS d_europe, latin_america_caribbean/1000000 AS e_latin_america_caribbean, north_america/1000000 AS f_north_america, west_asia/1000000 AS g_west_asia FROM dash_0080_global_raw_material_extraction_region ORDER BY year ASC",
      "format": {"type": "json","property": "data"},
      "transform": [
        {
          "type": "fold",
          "as": ["c","y"],
          "fields": [
    "a_africa",
    "b_asia_pacific",
    "c_eecca",
    "d_europe",
    "e_latin_america_caribbean",
    "f_north_america",
    "g_west_asia"
    ]
        },
        {
          "type": "stack",
          "groupby": ["x"],
          "sort": {"field": "c"},
          "field": "y"
        }
      ]
    }
  ],

  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {"data": "table", "field": "x"}
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true, "zero": true,
      "domain": {"data": "table", "field": "y1"}
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category20",
      "domain": {"data": "table", "field": "c"}
    }
  ],

  "axes": [
    {"title":"years","orient": "bottom", "scale": "x", "zindex": 1,
    "labelOverlap": "parity",  "labelPadding":6,
     "encode":{
    "labels": {
             "update":{"angle": {"value": 90},
             "align": {"value": "left"},
          "baseline": {"value": "middle"}}}
    }},
    {"title":"Extracted Material, Billions of Tonnes","orient": "left", "scale": "y", "zindex": 0, "labelOverlap": "parity"}
  ],

  "marks": [
    {
      "type": "rect",
      "from": {"data": "table"},
      "encode": {
        "enter": {
          "x": {"scale": "x", "field": "x"},
          "width": {"scale": "x", "band": 1, "offset": -1},
          "y": {"scale": "y", "field": "y0"},
          "y2": {"scale": "y", "field": "y1"},
          "fill": {"scale": "color", "field": "c"}
        },
        "update": {
          "fillOpacity": {"value": 1}
        },
        "hover": {
          "fillOpacity": {"value": 0.5}
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Region",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "value",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "c",
            "property": "type",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Year:",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="77029524-fdad-4675-9d7f-cd54f1dc896b"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-12-14T15:59:35.943Z',
#    'dataset': 'c61c364b-1d68-4dd9-ae3d-76c2a0022280',
#    'default': False,
#    'defaultEditableWidget': False,
# ...

# %% [markdown]
# # Energy

# %% [markdown]
# ## Varying Electricity Mixes in Large Economies

# %%
widgetID="5952e6c3-7aca-4604-b6ed-8f6ae4665a12"
datasetID="0f6c0ded-4f88-4902-b846-7bf57a9c3843"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
   "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/0f6c0ded-4f88-4902-b846-7bf57a9c3843?sql=SELECT field_1 as x,electricity_production_kwh_billions, share_coal,share_naturalgas, share_oil, share_hydropower,share_renewable, share_nuclear, access_to_electricity FROM ene_024_energy_production_sources_access WHERE share_coal IS NOT NULL AND field_1 IN ('India','Russian Federation','Brazil','Germany','France')",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type": "fold",
          "as": [
            "c",
            "y"
          ],
          "fields": [
            "share_coal",
            "share_hydropower",
            "share_naturalgas",
            "share_nuclear",
            "share_oil",
            "share_renewable"
          ]
        },
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(upper(slice(datum.c,6,7))+slice(datum.c,7),/_/g,' ')"
        },
        {
          "type": "stack",
          "field": "y",
          "groupby": [
            "x"
          ],
          "offset":  "normalize",
          "sort": {
            "field":  "c",
            "order": "descending"
          }
        },
        {
          "type": "formula",
          "as": "y",
          "expr": "if(datum.y < 5,\'\', round(datum.y))"
        },
        {
          "type": "formula",
          "as": "y0",
          "expr": "datum.y0*100"
        },
        {
          "type": "formula",
          "as": "y1",
          "expr": "datum.y1*100"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": false,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "limit": {
              "value": 50
            },
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    { "name":"bars",
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    },
    {
          "type": "text",
          "from": {"data": "bars"},
          "encode": {
            "enter": {
              "x": {"field": "x", "offset":{"field": "width", "mult": 0.5}},
              "y": {"field": "y", "offset": {"field": "height", "mult": 0.5}},
              "fill": {"value": "white"},
              "align": {"value": "center"},
              "baseline": {"value": "middle"},
              "text": {"field": "datum.y"}
            }
          }
        }
  ],
  "legends": [
    {
      "title": "% Electricity generation",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "percentage",
            "type": "number",
            "format": ".2"
          },
          {
            "column": "c",
            "property": "type",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Country",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="a8b7a5b4-e240-4ec8-bd87-c7a2fa3a6a61"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-11-14T22:12:44.988Z',
#    'dataset': '0f6c0ded-4f88-4902-b846-7bf57a9c3843',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'Highlights the wide variety of energy mixes in several large countries around the world by displaying the proportional contributions of major sources of electricity generation. Data from the World Bank Group.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Varying Electricity Mixes in Large Economies',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'Selected-Electricity-Production-Mixes',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-11-14T22:12:44.988Z',
#    'userId': '5981e73b0c069f3c93dc5e2a',
#    'verified': False,
#    'widgetConfig': {'autosize': {'contains': 'padding',
#      'resize': True,
#      'type': 'pad'},
# ...

# %% [markdown]
# ## Renewable Energy Investment

# %%
widgetID="118f245b-bf0f-47a0-be1e-3915a3a62cf6"
datasetID="37d5db2e-8ab8-4870-bfcc-534cdd5bdb76"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/37d5db2e-8ab8-4870-bfcc-534cdd5bdb76?sql=SELECT year as x, marine AS a_marine, geothermal AS b_geothermal, small_hydro AS c_small_hydro, biofuels AS d_biofuels, biomass_and_waste_to_energy AS e_biomass, wind AS f_wind, solar AS g_solar FROM ene_025_renewable_energy_investment_by_sector",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type": "fold",
          "as": [
            "c",
            "y"
          ],
          "fields":  [
            "a_marine",
            "b_geothermal",
            "c_small_hydro",
            "d_biofuels",
            "e_biomass",
            "f_wind",
            "g_solar"
          ]
        },
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(upper(slice(datum.c,2,3))+slice(datum.c,3),/_/g,' ')"
        },
        {
          "type": "stack",
          "field": "y",
          "groupby": [
            "x"
          ],
          "sort": {
            "field":  "c",
            "order": "descending"
          }
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": false,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category20",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "limit": {
              "value": 50
            },
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    { "title":"New Investment, USD billions",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    { "name":"bars",
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "% Electricity generation",
      "fill": "color",
      "orient": "right"
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "investment (usd billions)",
            "type": "number",
            "format": ".2"
          },
          {
            "column": "c",
            "property": "type",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="828e330c-4500-4acb-bfde-8bbe1f0154c7"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-11-16T22:10:07.335Z',
#    'dataset': '37d5db2e-8ab8-4870-bfcc-534cdd5bdb76',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'Total value, in billions of USD, of global investment in various types of renewable energy for each year since 2004. Data from Frankfurt School-UNEP Centre/BNEF report "Global Trends in Renewable Energy Investment 2017".',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Renewable Energy Investment',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'test_investment',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-11-16T22:10:07.335Z',
#    'userId': '5981e73b0c069f3c93dc5e2a',
#    'verified': False,
#    'widgetConfig': {'autosize': {'contains': 'padding',
#      'resize': True,
#      'type': 'pad'},
# ...

# %% [markdown]
# ## Electricity Mix to Meet Different Climate Scenarios

# %%
widgetID="33a9f375-22e3-42bd-9604-771e18ac10e9"
datasetID="33a6b7d0-a495-4231-880b-9f2d071a8ce2"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/ca59432c-b602-4d4a-809e-2a57758bddf3?sql=SELECT year as x, value*100 AS y, scenario as c FROM dash_0061_gcam_wind_solar_share_projections  ORDER BY year ASC",
      "format": {
        "property": "data",
        "type": "json"
      },
      "transform": [
      {
          "type": "formula",
          "as": "c",
          "expr": "replace(datum.c,/_/g,' ')"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x && hover.datum.y === datum.y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "point",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "title": "year",
      "orient": "bottom",
      "labelOverlap": "parity",
      "scale": "x"
    },
    {
      "title": "% Wind & solar",
      "orient": "left",
      "labelOverlap": "parity",
      "scale": "y"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "type": "group",
      "from": {
        "facet": {
          "name": "series",
          "data": "table",
          "groupby": "c"
        }
      },
      "marks": [
        {
          "type": "line",
          "interactive": false,
          "from": {
            "data": "series"
          },
          "encode": {
            "enter": {
              "x": {
                "scale": "x",
                "field": "x"
              },
              "y": {
                "scale": "y",
                "field": "y"
              },
              "stroke": {
                "scale": "color",
                "field": "c"
              },
              "strokeWidth": {
                "value": 2
              }
            }
          }
        }
      ]
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "fill": {
                "scale": "color",
                "field": "c"
              },
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
      }
  ],
    
  "legends": [
    {
      "title": "Climate Scenarios",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "datum.y",
            "property": "percentage",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "datum.c",
            "property": "Scenario",
            "type": "string"
          },
          {
            "column": "datum.x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="2cd48882-d158-4d46-bb89-f3f051149a98"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-11-20T18:46:51.142Z',
#    'dataset': '33a6b7d0-a495-4231-880b-9f2d071a8ce2',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'The share of total electricity production derived from wind and solar technologies, projected through 2100 under several different scenarios of climate change governance. Data from JCGRI, the home and primary development institution of GCAM, a dynamic-recursive model with technology-rich representations of the economy, energy sector, land use and water.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Electricity Mix to Meet Different Climate Scenarios',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'test_mix',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-11-20T18:46:51.142Z',
#    'userId': '5981e73b0c069f3c93dc5e2a',
#    'verified': False,
# ...

# %% [markdown]
# ## Electricity Consumption under Different Climate Scenarios

# %%
widgetID="a6d0a52c-8f17-439b-a5a1-f1d1b1d6b003"
datasetID="33a6b7d0-a495-4231-880b-9f2d071a8ce2"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/2e0e735c-7bd9-44f4-ac5f-fbc8a967da8a?sql=SELECT year as x, value as y, scenario as c FROM dash_0061_gcam_dashboard_series WHERE  indicator = 'Secondary Energy|Electricity' ORDER BY year ASC",
      "format": {
        "property": "data",
        "type": "json"
      },
      "transform": [
      {
          "type": "formula",
          "as": "c",
          "expr": "replace(datum.c,/_/g,' ')"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x && hover.datum.y === datum.y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "point",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "title": "year",
      "orient": "bottom",
      "labelOverlap": "parity",
      "scale": "x"
    },
    {
      "title": "Exajoules, Annual",
      "orient": "left",
      "labelOverlap": "parity",
      "scale": "y"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "type": "group",
      "from": {
        "facet": {
          "name": "series",
          "data": "table",
          "groupby": "c"
        }
      },
      "marks": [
        {
          "type": "line",
          "interactive": false,
          "from": {
            "data": "series"
          },
          "encode": {
            "enter": {
              "x": {
                "scale": "x",
                "field": "x"
              },
              "y": {
                "scale": "y",
                "field": "y"
              },
              "stroke": {
                "scale": "color",
                "field": "c"
              },
              "strokeWidth": {
                "value": 2
              }
            }
          }
        }
      ]
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "fill": {
                "scale": "color",
                "field": "c"
              },
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
      }
  ],
    
  "legends": [
    {
      "title": "Climate Scenarios",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "datum.y",
            "property": "percentage",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "datum.c",
            "property": "Scenario",
            "type": "string"
          },
          {
            "column": "datum.x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="ae77f057-457d-4b36-b820-0c2222f3e1e3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-11-21T22:40:44.299Z',
#    'dataset': '33a6b7d0-a495-4231-880b-9f2d071a8ce2',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'Total, global electricity consumption, projected through 2100 under several different scenarios of climate change governance. Data from JCGRI, the home and primary development institution of GCAM, a dynamic-recursive model with technology-rich representations of the economy, energy sector, land use and water.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Electricity Consumption under Different Climate Scenarios',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'Electricity-Mix-to-Meet-Different-Climate-Scenarios-RECREATED',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-11-21T22:40:44.299Z',
#    'userId': '5981e73b0c069f3c93dc5e2a',
#    'verified': False,
# ...

# %% [markdown]
# # Food and Agriculture

# %% [markdown]
# ## Food Lost or Wasted By Region and Stage in Value Chain (Percent of kcal lost and wasted)

# %%
widgetID="5eec6ec5-51e5-4d39-af23-9d1cda64dc3a"
datasetID="5e87d53c-10d9-419e-a0e6-122e26b064ca"
specV3=json.loads("""
{
  
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "offset",
      "update": "height*0.35"
    },
    {
      "name": "chartHeight",
      "update": "height*0.6"
    },
    {
      "name": "tableHeight",
      "update": "height*0.2"
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/5e87d53c-10d9-419e-a0e6-122e26b064ca?sql=SELECT region as x, total_share_of_food_that_is_lost_or_wasted,production,handling_and_storage,processing,distribution_and_market,consumption FROM foo_045_foodlossandwaste order by consumption desc",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type": "fold",
          "as": [
            "c",
            "y"
          ],
          "fields": [
            "production",
            "handling_and_storage",
            "processing",
            "distribution_and_market",
            "consumption"
          ]
        },
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(upper(slice(datum.c,0,1))+slice(datum.c,1),/_/g,' ')"
        },
        {
          "type": "stack",
          "field": "y",
          "groupby": [
            "x"
          ],
          "offset": "normalize",
          "sort": {
            "field": "c",
            "order": "descending"
          }
        },
        {
          "type": "formula",
          "as": "y",
          "expr": "if(datum.y < 5, \'\', round(datum.y) )"
        },
        {
          "type": "formula",
          "as": "y0",
          "expr": "datum.y0*100"
        },
        {
          "type": "formula",
          "as": "y1",
          "expr": "datum.y1*100"
        }
      ]
    },
    {
      "name": "summary",
      "url": "https://api.resourcewatch.org/v1/query/5e87d53c-10d9-419e-a0e6-122e26b064ca?sql=SELECT%20min(total_share_of_food_that_is_lost_or_wasted)%20as%20label,%20region%20as%20x%20FROM%20foo_045_foodlossandwaste%20group%20by%20region%20order%20by%20region%20desc",
      "format": {"type": "json","property": "data"}
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y_d",
      "type": "band",
      "range": "height",
      "domain": [
        0,
        1
      ]
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
  ],
  "legends": [
    {
      "title": "% Electricity generation",
      "fill": "color",
      "orient": "right"
    }
  ],
  "marks": [
    {
      "type": "group",
      "autosize": "pad",
      "encode": {
        "enter": {
          "y": {
            "scale": "y_d",
            "value": 0
          },
          "height": {"signal": "chartHeight"},
          "stroke": {
            "value": "#000"
          }
        }
      },
      "scales": [
        {
          "name": "y",
          "type": "linear",
          "range": [
            {
              "signal": "chartHeight"
            },
            0
          ],
          "nice": false,
          "zero": true,
          "domain": {
            "data": "table",
            "field": "y1"
          }
        }
      ],
      "axes": [
        {
          "orient": "left",
          "scale": "y",
          "zindex": 0,
          "labelOverlap": "parity"
        },
        {
          "orient": "bottom",
          "scale": "x",
          "zindex": 1,
          "labelOverlap": "parity",
          "labelPadding": 6,
          "encode": {
            "labels": {
              "update": {
                "limit": {
                  "value": 50
                },
                "angle": {
                  "value": 90
                },
                "align": {
                  "value": "left"
                },
                "baseline": {
                  "value": "middle"
                }
              }
            }
          }
        }
      ],
      "marks": [
        {
          "name": "bars",
          "type": "rect",
          "from": {
            "data": "table"
          },
          "encode": {
            "enter": {
              "x": {
                "scale": "x",
                "field": "x"
              },
              "width": {
                "scale": "x",
                "band": 1,
                "offset": -1
              },
              "y": {
                "scale": "y",
                "field": "y0"
              },
              "y2": {
                "scale": "y",
                "field": "y1"
              },
              "fill": {
                "scale": "color",
                "field": "c"
              }
            },
            "update": {
              "fillOpacity": {
                "value": 1
              }
            },
            "hover": {
              "fillOpacity": {
                "value": 0.5
              }
            }
          }
        },
        {
          "type": "text",
          "from": {
            "data": "bars"
          },
          "encode": {
            "enter": {
              "x": {
                "field": "x",
                "offset": {
                  "field": "width",
                  "mult": 0.5
                }
              },
              "y": {
                "field": "y",
                "offset": {
                  "field": "height",
                  "mult": 0.5
                }
              },
              "fill": {
                "value": "white"
              },
              "align": {
                "value": "center"
              },
              "baseline": {
                "value": "middle"
              },
              "text": {
                "field": "datum.y"
              }
            }
          }
        }
      ]
    },
    { "name":"test",
      "type": "group",
      "encode": {
        "enter": {
          "y": {
            "scale": "y_d",
            "value": 1,
            "offset": {"signal":"offset*1.2"}
          },
          "height": {"signal": "tableHeight"},
          "width": {
            "signal": "width"
          },
          "fill": {
            "value": "#FDEDD1"
          }
        }
      },
      "marks": [
        {
          "type": "text",
          "interactive": true,
          "from": {
            "data": "summary"
          },
          "encode": {
            "update": {
              "y": {"signal": "tableHeight*0.5"},
              "x": {"scale": "x", "field":"x","offset": { "signal": "bandwidth(\'x\')",
                  "mult": 0.5
                }},
              "text": { "field":"label"},
              "baseline": {"value": "bottom"},
              "align": {"value": "center"},
              "fontSize": {"value": 10}
            }
          }
        },
       {
          "type": "text",
          "interactive": false,
          "encode": {
            "enter": {
              "y": {"signal": "tableHeight"},
              "x": {"signal": "width/2"},
              "text": {"value": "Total share of food that is lost or wasted"},
              "baseline": {"value": "bottom"},
              "align": {"value": "center"},
              "fontSize": {"value": 12}
            }
          }
        }
      ]
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "Percentage",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "x",
            "property": "Region",
            "type": "string"
          },
          {
            "column": "c",
            "property": "Category",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=250
Vega(vega4view)
# Out:
# <div class="vega-embed" id="e9a37a4f-f780-4ac6-8a81-a3ea8b6aea8a"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-10-09T15:38:59.677Z',
#    'dataset': '5e87d53c-10d9-419e-a0e6-122e26b064ca',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': '“Food loss and waste” refers to the edible parts of plants and animals produced or harvested for human consumption but not ultimately consumed by people. It represents a decrease in the mass, caloric, and/or nutritional value of edible food intended for human consumption at any stage in the food value chain\nEfforts to reduce food loss and waste should focus on stages “close to the farm” in most developing regions and focus on stages “close to the fork” in developed regions.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Food Lost or Wasted By Region and Stage in Value Chain  (Percent of kcal lost and wasted)',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
# ...

# %% [markdown]
# ## Drivers of Deforestation

# %%
widgetID="c3fa95e0-c241-4539-a9c4-84a480ec5ba8"
datasetID="e66121ff-b785-4f27-aa1b-180af31a17cc"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/e66121ff-b785-4f27-aa1b-180af31a17cc?sql=SELECT continent as x, urban_expansion AS a_urban_expansion, infrastructure AS b_infrastructure, mining AS c_mining, agriculture_local_subsistence AS d_agriculture_local_subsistence, agriculture_commercial AS e_agriculture_commercial FROM for_019_drivers_of_deforestation",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type": "fold",
          "as": [
            "c",
            "y"
          ],
          "fields": [
            "a_urban_expansion",
        "b_infrastructure",
        "c_mining",
        "d_agriculture_local_subsistence",
        "e_agriculture_commercial"
          ]
        },
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(upper(slice(datum.c,6,7))+slice(datum.c,7),/_/g,' ')"
        },
        {
          "type": "stack",
          "field": "y",
          "groupby": [
            "x"
          ],
          "offset":  "normalize",
          "sort": {
            "field":  "c",
            "order": "descending"
          }
        },
        {
          "type": "formula",
          "as": "y",
          "expr": "if(datum.y < 5,'', round(datum.y))"
        },
        {
          "type": "formula",
          "as": "y0",
          "expr": "datum.y0*100"
        },
        {
          "type": "formula",
          "as": "y1",
          "expr": "datum.y1*100"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "paddingInner":0.1,
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": false,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "limit": {
              "value": 50
            },
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    { "name":"bars",
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": 0
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    },
    {
          "type": "text",
          "from": {"data": "bars"},
          "encode": {
            "enter": {
              "x": {"field": "x", "offset":{"field": "width", "mult": 0.5}},
              "y": {"field": "y", "offset": {"field": "height", "mult": 0.5}},
              "fill": {"value": "white"},
              "align": {"value": "center"},
              "baseline": {"value": "middle"},
              "text": {"field": "datum.y"}
            }
          }
        }
  ],
  "legends": [
    {
      "title": "Net forest % area changed",
      "fill": "color",
      "orient": "right"
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "Percentage",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "x",
            "property": "Region",
            "type": "string"
          },
          {
            "column": "c",
            "property": "Category",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="f61fa7a1-a9f0-4a1d-9191-b8a969787e55"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-11-20T22:24:40.501Z',
#    'dataset': 'e66121ff-b785-4f27-aa1b-180af31a17cc',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'The breakdown of what drives deforestation in Africa, the Americas, and Asia. The main drivers are urban expansion, infrastructure, mining, and both commercial and local/subsistence agriculture. Commercial agriculture is a driver of over 50% of deforestation around the world.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Drivers of Deforestation',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'Drivers-of-Deforestation-2',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-11-20T22:24:40.501Z',
#    'userId': '5981e73b0c069f3c93dc5e2a',
#    'verified': False,
#    'widgetConfig': {'autosize': {'contains': 'padding',
#      'resize': True,
#      'type': 'pad'},
# ...

# %% [markdown]
# # Forest

# %% [markdown]
# ## Country Annual Tree Cover Loss

# %%
widgetID="e8282e04-645b-4596-ae9b-f7b5e8c1b64a"
datasetID="32324f22-e7f6-4e0d-bc38-d82c6484f1be"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://wri-01.cartodb.com/api/v2/sql?q=SELECT year as x, Sum(loss) as y FROM   umd_nat_staging   WHERE  thresh = 30 GROUP  BY year ORDER  BY year",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "window",
          "sort": {
            "field": "x",
            "order": "ascending"
          },
          "frame": [
            -3,
            0
          ],
          "ops": [
            "average"
          ],
          "fields": [
            "y"
          ],
          "as": [
            "y0"
          ]
        },
        {"type": "formula", "as": "y0", "expr": "datum.x < 2003? null : datum.y0"}
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "domain": {
        "data": "table",
        "field": "x"
      },
      "range": "width",
      "padding": 0.05,
      "round": true
    },
    {
      "name": "xn",
      "type": "point",
      "domain": {
        "data": "table",
        "field": "x"
      },
      "range": "width",
      "padding": 0.05,
      "round": true
    },
    {"type": "linear",
      "name": "y",
      "domain": {
        "data": "table",
        "field": "y"
      },
      "nice": true,
      "range": "height"
    },
    {
      "domain": [
        "3 years average"
      ],
      "range": [
        "red"
      ],
      "type": "ordinal",
      "name": "color"
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "labelOverlap":"parity",
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "orient": "left",
      "labelOverlap":"parity",
      "scale": "y",
      "format": "2s"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1
          },
          "y": {
            "scale": "y",
            "field": "y"
          },
          "y2": {
            "scale": "y",
            "value": 0
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        },
        "hover": {
          "opacity": {
            "value": 0.8
          }
        }
      }
    },
    {
      "type": "line",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "defined": {
    "signal": "datum.y0 !== null"
    },
          "interpolate": {
            "value": "linear"
          },
          "x": {
            "scale": "xn",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "stroke": {
            "value": "red"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    }
  ],
  "legends": [
    {
       "fill": "color",
       "orient":"top-left"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "Loss (ha)",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=200
Vega(vega4view)
# Out:
# <div class="vega-embed" id="5345a490-a8ca-4261-8b03-f33781d9b559"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-10-10T16:40:57.596Z',
#    'dataset': '32324f22-e7f6-4e0d-bc38-d82c6484f1be',
#    'default': True,
#    'defaultEditableWidget': False,
#    'description': 'This figure summarizes global tree cover loss from 2001 to 2015, calculated with >30% canopy density. “Tree cover” refers to the biophysical presence of trees, which may be a part of natural forests or tree plantations. Thus, loss of tree cover may occur for many reasons, including deforestation, fire, and logging within the course of sustainable forestry operations.',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Country Annual Tree Cover Loss',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'Total-Tree-Cover-Loss-Between-2011-16',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-10-10T16:40:57.596Z',
#    'userId': '59db4eace9c1380001d6e4c3',
#    'verified': False,
# ...

# %% [markdown]
# ## Countries with greatest percent tree cover loss (2001-2015)

# %%
widgetID="ce44eef3-eb73-4bb3-94d7-7a5798f08e17"
datasetID="32324f22-e7f6-4e0d-bc38-d82c6484f1be"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },

  "data": [
    {
      "name": "table",
      "url": "https://wri-01.cartodb.com/api/v2/sql?q=SELECT country as y, (Sum(loss) / max(extent_2000))*100 as x FROM   umd_nat_staging   WHERE  thresh = 30 and extent_2000>1000000 GROUP  BY country ORDER  BY 2 desc limit 10",
      "format": {"type": "json","property": "rows"}
    }
    
  ],

  "marks": [
    {
      "type": "rect",
      "from": {"data": "table"},
      "encode": {
        "update": {
           "opacity": {
            "value": 1
          },
          "x": {"scale": "x", "value": 0},
          "x2": {"scale": "x", "field": "x"},
          "y": {"scale": "y", "field": "y"},
          "height": {"scale": "y", "band": 1}
        },
        "hover":{
           "opacity": {
            "value": 0.8
          }
        }
      }
    }
  ],

  "scales": [
    {
      "name": "x",
      "type": "linear",
      "domain": {"data": "table", "field": "x"},
      "range": "width",
      "nice": true
    },
    {
      "name": "y",
      "type": "band",
      "domain": {
        "data": "table", "field": "y"
      },
      "range": "height",
      "padding": 0.05
    }
  ],

  "axes": [
    { "title":"% loss",
      "scale": "x",
      "orient": "bottom",
      "labelOverlap": "parity",
      "format": ".2",
      "tickCount": 5
    },
    { 
      "scale": "y",
      "labelOverlap": "parity",
      "orient": "left"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "x",
            "property": "% Loss",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "y",
            "property": "Country",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="0549a0d9-7e73-44ce-a888-44e14dd684d7"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-10-11T09:24:58.815Z',
#    'dataset': '32324f22-e7f6-4e0d-bc38-d82c6484f1be',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'The graph lists top 10 countries with greatest percent loss (2001-2015) relative to tree cover in 2000, where tree cover is greater than 1 million hectares (greater than 30%). “Tree cover” refers to the biophysical presence of trees, which may be a part of natural forests or tree plantations. Thus, loss of tree cover may occur for many reasons, including deforestation, fire, and logging within the course of sustainable forestry operations',
#    'env': 'production',
#    'freeze': False,
#    'name': 'Countries with greatest percent tree cover loss (2001-2015)',
#    'protected': False,
#    'published': True,
#    'queryUrl': '',
#    'slug': 'Countries-with-greatest-percent-loss-2001-2015-relative-to-tree-cover-in-2000',
# ...

# %% [markdown]
# # Water

# %% [markdown]
# ## % crop producion growing under water risk areas by 2040

# %%
widgetID="04b1610b-74ef-413b-b167-3a0169f77b3f"
datasetID="5edefab9-c707-447e-96f9-6115149e3a87"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
   "data": [
    {
      "format": {"property": "rows","type": "json"},
      "name": "table",
      "url": "https://wri-01.carto.com/api/v2/sql?q=with%20t%20as%20(select%20sum(area)%20as%20area,%20wsbs00tl%20as%20risk,%20crop%20from%20crops_stats%20group%20by%20wsbs00tl,%20crop%20order%20by%20risk%20asc),%20r%20as%20(SELECT%20sum(value)%20as%20value,%20commodity%20FROM%20combined01_prepared%20where%20year=%272040%27%20and%20impactparameter=%27Food%20Demand%27%20group%20by%20commodity%20),%20d%20as%20(%20select%20(value*100/(sum(value)%20over()))%20as%20value,%20commodity%20from%20r%20)%20select%20crop,%20risk,value,%20(area*100/sum(area)%20over(partition%20by%20crop))%20area_perc%20from%20d%20inner%20join%20t%20on%20lower(commodity)=crop%20order%20by%20risk%20asc,%20crop%20asc"
    },
    {
      "transform": [
        {
          "groupby": ["crop"],
          "as": [ "val_s","val_e"],
          "offset": "zero",
          "field": "area_perc",
          "type": "stack"
        },
        {
          "groupby": ["risk"],
          "as": [ "t_s","t_e"],
          "offset": "zero",
          "field": "value",
          "type": "stack"
        }
      ],
      "source": "table",
      "name": "stats_risk"
    },
    {
      "transform": [
        {
          "fields":["t_s","t_e"],
            "ops":["max","max"],
            "as":["t_s","t_e"],
          
          "groupby": ["crop"],
          "type": "aggregate"
        },
        {
          "type": "collect",
          "sort": {
            "field": ["t_s"],
            "order": ["ascending"]
            }
        }
      ],
      "source": "stats_risk",
      "name": "legend_crop"
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "linear",
      "range": "width",
      "domain": {
        "data": "stats_risk",
        "field": "t_e"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": false,
      "zero": true,
      "domain": {
        "data": "stats_risk",
        "field": "val_e"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": [
        "#f4f4f1",
        "#fff6d6",
        "#f1bc2e",
        "#f1832e",
        "#ef5330",
        "#e24e2c"
      ],
      "domain": {
        "data": "stats_risk",
        "field": "risk"
      }
    }
  ],
  "axes": [
    { "title":"% Crop extent area",
      "orient": "top",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "limit": {
              "value": 50
            },
            "align": {
              "value": "center"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    { "title":"% Crop production under water risk",
      "orient": "left",
      "scale": "y",
      "grid":false,
      "zindex": 0,
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    { "name":"bars",
      "type": "rect",
      "from": {
        "data": "stats_risk"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "t_s"
          },
          "x2": {
            "scale": "x",
            "field": "t_e"
          },
          "y": {
            "scale": "y",
            "field": "val_s"
          },
          "y2": {
            "scale": "y",
            "field": "val_e"
          },
          "fill": {
            "scale": "color",
            "field": "risk"
          },
          "stroke": {
            "scale": "color",
            "field": "risk"
          },
          "strokeOpacity": {
            "value": 1
          }
        },
        "update": {
          "fillOpacity": {
            "value": 0.8
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    },
    {
          "type": "text",
          "from": {"data": "legend_crop"},
          "encode": {
            "enter": {
              "x": {"signal": "datum.t_s+((datum.t_e-datum.t_s)/2)", "scale":"x"},
              "y": {"value": -5, "scale": "y"},
              "align": {"value": "center"},
              "baseline": {"value": "middle"},
              "text": {"field": "crop"}
            }
          }
        }
  ],
  "legends": [
    {
      "title": "Water risk",
      "fill": "color",
      "orient": "right"
    }
  ],
    "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
            {
            "column": "crop",
            "property": "crop",
            "type": "string"
          },{
            "column": "risk",
            "property": "Risk",
            "type": "string"
          },
          {
            "column": "val_e",
            "property": "% risk area",
            "type": "number",
            "format": ".2s"
          },
          
          {
            "column": "t_e",
            "property": "% crop area",
            "type": "number",
            "format": ".2s"
          }
        ]
      }
    }
  ]
}

""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="de664c95-6654-4e36-858b-26299121c64c"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'authors': '',
#    'createdAt': '2017-07-11T10:58:23.880Z',
#    'dataset': '5edefab9-c707-447e-96f9-6115149e3a87',
#    'default': False,
#    'defaultEditableWidget': False,
#    'description': 'asdfasdf',
#    'env': 'production',
#    'freeze': False,
#    'name': '% crop producion growing under water risk areas by 2040',
#    'protected': False,
#    'published': True,
#    'queryUrl': 'query/5edefab9-c707-447e-96f9-6115149e3a87?sql=SELECT * FROM crops',
#    'slug': 'crop-growing-in-high-water-risk-areas-by-2040',
#    'source': '',
#    'template': False,
#    'updatedAt': '2017-07-11T10:58:23.880Z',
#    'userId': '58333dcfd9f39b189ca44c75',
#    'verified': False,
#    'widgetConfig': {'autosize': {'contains': 'padding',
#      'resize': True,
#      'type': 'pad'},
#     'axes': [{'encode': {'labels': {'update': {'align': {'value': 'center'},
#          'baseline': {'value': 'middle'},
# ...

# %% [markdown]
# ## % forest loss alerts within each water risk category

# %%
widgetID="42756e3f-2c35-4d28-a221-47b0751380f7"
datasetID="86777822-d995-49cd-b9c3-d4ea4f82c0a3"
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
       
      "format": {"property": "rows","type": "json"},
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT%20sum(rs_tl_c)%20%20as%20x,%20rs_tl_c%20as%20y%20FROM%20river_basins%20where%20rs_tl_c%20!=%2010%20group%20by%20rs_tl_c%20order%20by%20y%20asc",
    
      "transform": [
        {
          "type": "window",
          "ops": ["row_number"], "as": ["rank"]
        },
        {
          "type": "formula",
          "as": "category",
          "expr": "datum.rank < 6 ? datum.x : 'Others'"
        },
        {
          "type": "aggregate",
          "groupby": ["category"],
          "ops": ["sum"],
          "fields": ["y"],
          "as": ["value"]
        },
        {
          "type": "pie",
          "field": "value",
          "startAngle":  0,
          "endAngle":  6.29
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "c",
      "type": "ordinal",
      "range": [
"#fffbca",
"#ffe01b",
"#f6bb0f",
"#f6811d",
"#e24e2c"
],
      "domain": { "data": "table", "field": "category" }
    }
  ],
  "marks": [
    {
      "type": "arc",
      "from": { "data": "table" },
      "encode": {
        "enter": {
          "fill": { "scale": "c", "field": "category" },
          "x": { "signal": "width / 2" },
          "y": { "signal": "height / 2" }
        },
        "update": {
          "opacity": { "value": 1 },
          "startAngle": { "field": "startAngle" },
          "endAngle": { "field": "endAngle" },
          "innerRadius": { "signal": "width > height ? height / 3 : width / 3" },
          "outerRadius": { "signal": "width > height ? height / 2 : width / 2" }
        },
        "hover":{
          "opacity":{"value":0.8}
        }
      }
    }
  ],
  "legend": [
{
"values": [
{
"value": "#fff6d6",
"type": "string",
"label": "1.Low"
},
{
"value": "#f1bc2e",
"type": "string",
"label": "2.Mid-low"
},
{
"value": "#f1832e",
"type": "string",
"label": "3.Mid-High"
},
{
"value": "#ef5330",
"type": "string",
"label": "4.High"
},
{
"value": "#e24e2c",
"type": "string",
"label": "5.Extremely high"
}
],
"shape": "square",
"label": null,
"type": "color"
}
],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "datum.y",
            "property": "value",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "datum.category",
            "property": "category",
            "type": "string"
          }
        ]
      }
    }
  ]
}


""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="6b9e4b14-4cc2-4939-8766-639562bd3011"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
# Out:
# {'data': {'attributes': {'application': ['rw'],
#    'createdAt': '2017-07-14T09:40:32.571Z',
#    'dataset': '86777822-d995-49cd-b9c3-d4ea4f82c0a3',
#    'default': False,
#    'defaultEditableWidget': False,
#    'env': 'production',
#    'freeze': False,
#    'name': '% forest loss alerts within each water risk category',
#    'protected': False,
#    'published': True,
#    'queryUrl': 'query/cb833538-4fb0-4261-a9d0-125175624f29?sql=select * from river_basins',
#    'slug': 'Watersheds-are-at-risk-due-to-deforestation',
#    'template': False,
#    'updatedAt': '2017-07-14T09:40:32.571Z',
#    'userId': '57a0aa1071e394dd32ffe137',
#    'verified': False,
#    'widgetConfig': {'autosize': {'contains': 'padding',
#      'resize': True,
#      'type': 'pad'},
#     'data': [{'format': {'property': 'rows', 'type': 'json'},
#       'name': 'table',
#       'transform': [{'as': ['rank'], 'ops': ['row_number'], 'type': 'window'},
#        {'as': 'category',
# ...
