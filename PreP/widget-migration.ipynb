# %% [markdown]
# #### Templating

# %%
widgetID=""
datasetID=""
specV3=json.loads("""
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# # Table of Contents
#  <p><div class="lev2 toc-item"><a href="#Config" data-toc-modified-id="Config-01"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Config</a></div><div class="lev1 toc-item"><a href="#Projected-changes-in-streamflow---Rain-dominant" data-toc-modified-id="Projected-changes-in-streamflow---Rain-dominant-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Projected changes in streamflow - Rain dominant</a></div><div class="lev1 toc-item"><a href="#Projected-changes-in-streamflow---Mixed-rain-and-snow" data-toc-modified-id="Projected-changes-in-streamflow---Mixed-rain-and-snow-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Projected changes in streamflow - Mixed rain and snow</a></div><div class="lev1 toc-item"><a href="#Projected-changes-in-streamflow---Snow-dominant" data-toc-modified-id="Projected-changes-in-streamflow---Snow-dominant-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Projected changes in streamflow - Snow dominant</a></div><div class="lev1 toc-item"><a href="#Projected-temperature-changes-in-Puget-Sound" data-toc-modified-id="Projected-temperature-changes-in-Puget-Sound-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Projected temperature changes in Puget Sound</a></div><div class="lev1 toc-item"><a href="#Projected-precipitation-change-in-Puget-Sound" data-toc-modified-id="Projected-precipitation-change-in-Puget-Sound-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Projected precipitation change in Puget Sound</a></div><div class="lev1 toc-item"><a href="#Temperature-change" data-toc-modified-id="Temperature-change-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Temperature change</a></div><div class="lev1 toc-item"><a href="#Precipitation-change" data-toc-modified-id="Precipitation-change-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Precipitation change</a></div><div class="lev1 toc-item"><a href="#Precipitation-change-sonoma" data-toc-modified-id="Precipitation-change-sonoma-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Precipitation change sonoma</a></div><div class="lev1 toc-item"><a href="#Historical-and-Projected-annual-changes-in-summer-air-temperature-(ºF)" data-toc-modified-id="Historical-and-Projected-annual-changes-in-summer-air-temperature-(ºF)-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Historical and Projected annual changes in summer air temperature (ºF)</a></div><div class="lev1 toc-item"><a href="#Temperature-maximums-in-Porto-Alegre" data-toc-modified-id="Temperature-maximums-in-Porto-Alegre-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Temperature maximums in Porto Alegre</a></div><div class="lev1 toc-item"><a href="#Temperature-lows-in-Porto-Alegre" data-toc-modified-id="Temperature-lows-in-Porto-Alegre-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Temperature lows in Porto Alegre</a></div><div class="lev1 toc-item"><a href="#Projected-changes-in-streamflow---Rain-dominant" data-toc-modified-id="Projected-changes-in-streamflow---Rain-dominant-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Projected changes in streamflow - Rain dominant</a></div>

# %%
from vega3 import Vega 
import json
import requests
import getpass

# %%
bearerToken = getpass.getpass('Please enter your bearer Token:')
def PatchApi(vegaSpec, datasetId, WidgetId):
    url = 'https://api.resourcewatch.org/v1/dataset/{0}/widget/{1}'.format(datasetId,WidgetId)
    body = {'widgetConfig': ""
           
           }
    Headers = {'content-type': 'application/json; charset=UTF-8',
               'autorithation': 'Bearer {}'.format(bearerToken)}
    
    r = requests.patch(url=url ,data=json.dumps(body), headers=Headers)
    return r.json()

# %% [markdown]
# ## Config

# %%
Config="""
{
    "axis": {
      "grid": true,
      "gridColor": "#dedede"
    }
  }
"""

# %% [markdown]
# #  Projected changes in streamflow - Rain dominant

# %%
####Templating
widgetID='2cb0babd-55b0-4fee-9596-0832cf9d48dc'
datasetID='6a18cd92-acd3-4107-b855-95fa2af24473'
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, historical as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Samish' order by numeric_m ASC",
      "name": "line1",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'Historical'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, A1B_2040s as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Samish' order by numeric_m ASC",
      "name": "line2",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'A1B_2040s'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, A1B_2080s as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Samish' order by numeric_m ASC",
      "name": "line3",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'A1B_2080s'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "name": "axis",
      "values": [
        {
          "x": "Years",
          "y": "cfs"
        }
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Historical"
        },
        {
          "cat": "A1B_2040s"
        },
        {
          "cat": "A1B_2080s"
        }
      ]
    }
  ],
  "name": "Rain dominant",
  "scales": [
    {
      "name": "x",
      "type": "point",
      "nice": true,
      "range": "width",
      "domain":{ "fields": [
    {"data": "line1", "field": "z"},
    {"data": "line2", "field": "z"},
    {"data": "line3", "field": "z"}
   ]}
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": { "fields": [
    {"data": "line1", "field": "y"},
    {"data": "line2", "field": "y"},
    {"data": "line3", "field": "y"}
   ]}
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {"data": "legend", "field": "cat"}
    }
  ],

  "axes": [
    {"orient": "bottom", "scale": "x"},
    {"orient": "left", "scale": "y",
    "title":"CFS",
    "encode": {
      "title": {
        "update": {
          "dx": {"value": 0},
          "dy": {"value": 0},
          "x": {"value": 0},
          "y": {"value": -10},
          "align": {"value": "right"},
          "baseline": {"value": "bottom"},
          "angle": {"value": 0},
          "fontSize": {"value": 12}
        }
      }
    }
    }
  ],

      "marks": [
        {
          "type": "line",
          "from": {"data": "line1"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2}
            },
            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        },
        {
          "type": "line",
          "from": {"data": "line2"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2},
              "strokeDash":{
                "value":[
                  1,2
                ]
              }
            },

            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        },
        {
          "type": "line",
          "from": {"data": "line3"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2},
              "strokeDash":{
                "value":[
                  3,3
                ]
              }
            },
            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        }
      ],
"legends": [
  {
    "title":"Samish river",
    "stroke": "color",
    "orient":"top-right",
    "offset":{"signal":"width<200?-10:0"},
    "encode": {
      "title": {
        "update": {
          "fontSize": {"value": 14}
        }
      },
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
 ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="1ed5b779-7d4e-4c6c-8860-f159542de579"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Projected changes in streamflow - Mixed rain and snow

# %%
####Templating
widgetID="98e026bc-ab55-4086-adb2-afdc9b918985"
datasetID="6a18cd92-acd3-4107-b855-95fa2af24473"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, historical as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Snohomish' order by numeric_m ASC",
      "name": "line1",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'Historical'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, A1B_2040s as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Snohomish' order by numeric_m ASC",
      "name": "line2",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'A1B_2040s'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, A1B_2080s as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Snohomish' order by numeric_m ASC",
      "name": "line3",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'A1B_2080s'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "name": "axis",
      "values": [
        {
          "x": "Years",
          "y": "cfs"
        }
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Historical"
        },
        {
          "cat": "A1B_2040s"
        },
        {
          "cat": "A1B_2080s"
        }
      ]
    }
  ],
  "name": "Rain dominant",
  "scales": [
    {
      "name": "x",
      "type": "point",
      "nice": true,
      "range": "width",
      "domain":{ "fields": [
    {"data": "line1", "field": "z"},
    {"data": "line2", "field": "z"},
    {"data": "line3", "field": "z"}
   ]}
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": { "fields": [
    {"data": "line1", "field": "y"},
    {"data": "line2", "field": "y"},
    {"data": "line3", "field": "y"}
   ]}
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {"data": "legend", "field": "cat"}
    }
  ],

  "axes": [
    {"orient": "bottom", "scale": "x"},
    {"orient": "left", "scale": "y",
    "title":"CFS",
    "encode": {
      "title": {
        "update": {
          "dx": {"value": 0},
          "dy": {"value": 0},
          "x": {"value": 0},
          "y": {"value": -10},
          "align": {"value": "right"},
          "baseline": {"value": "bottom"},
          "angle": {"value": 0},
          "fontSize": {"value": 12}
        }
      }
    }
    }
  ],

      "marks": [
        {
          "type": "line",
          "from": {"data": "line1"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2}
            },
            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        },
        {
          "type": "line",
          "from": {"data": "line2"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2},
              "strokeDash":{
                "value":[
                  1,2
                ]
              }
            },

            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        },
        {
          "type": "line",
          "from": {"data": "line3"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2},
              "strokeDash":{
                "value":[
                  3,3
                ]
              }
            },
            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        }
      ],
"legends": [
  {
    "title":"Snohomish river",
    "stroke": "color",
    "orient":"top-right",
    "offset":{"signal":"width<200?-10:0"},
    "encode": {
      "title": {
        "update": {
          "fontSize": {"value": 14}
        }
      },
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
 ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="dbe6f597-b953-45e9-b9c6-17fc060ae28e"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Projected changes in streamflow - Snow dominant

# %%
####Templating
widgetID="d0143c52-0920-4700-8c28-9600fcdf76e7"
datasetID="6a18cd92-acd3-4107-b855-95fa2af24473"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, historical as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Sauk' order by numeric_m ASC",
      "name": "line1",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'Historical'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, A1B_2040s as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Sauk' order by numeric_m ASC",
      "name": "line2",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'A1B_2040s'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "url": "https://api.resourcewatch.org/query/6a18cd92-acd3-4107-b855-95fa2af24473?sql=select numeric_m as x, A1B_2080s as y, month as z from index_6a18cd92acd34107b85595fa2af24473 where streamflow='Sauk' order by numeric_m ASC",
      "name": "line3",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type":"formula",
          "as":"c",
          "expr":"'A1B_2080s'"
        },
        {
          "type": "collect",
          "sort": {
            "field": [
              "x"
            ],
            "order": [
              "ascending"
            ]
          }
        }
      ]
    },
    {
      "name": "axis",
      "values": [
        {
          "x": "Years",
          "y": "cfs"
        }
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Historical"
        },
        {
          "cat": "A1B_2040s"
        },
        {
          "cat": "A1B_2080s"
        }
      ]
    }
  ],
  "name": "Rain dominant",
  "scales": [
    {
      "name": "x",
      "type": "point",
      "nice": true,
      "range": "width",
      "domain":{ "fields": [
    {"data": "line1", "field": "z"},
    {"data": "line2", "field": "z"},
    {"data": "line3", "field": "z"}
   ]}
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": { "fields": [
    {"data": "line1", "field": "y"},
    {"data": "line2", "field": "y"},
    {"data": "line3", "field": "y"}
   ]}
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {"data": "legend", "field": "cat"}
    }
  ],

  "axes": [
    {"orient": "bottom", "scale": "x"},
    {"orient": "left", "scale": "y",
    "title":"CFS",
    "encode": {
      "title": {
        "update": {
          "dx": {"value": 0},
          "dy": {"value": 0},
          "x": {"value": 0},
          "y": {"value": -10},
          "align": {"value": "right"},
          "baseline": {"value": "bottom"},
          "angle": {"value": 0},
          "fontSize": {"value": 12}
        }
      }
    }
    }
  ],

      "marks": [
        {
          "type": "line",
          "from": {"data": "line1"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2}
            },
            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        },
        {
          "type": "line",
          "from": {"data": "line2"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2},
              "strokeDash":{
                "value":[
                  1,2
                ]
              }
            },

            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        },
        {
          "type": "line",
          "from": {"data": "line3"},
          "encode": {
            "enter": {
              "x": {"scale": "x", "field": "z"},
              "y": {"scale": "y", "field": "y"},
              "stroke": {"scale": "color", "field": "c"},
              "strokeWidth": {"value": 2},
              "strokeDash":{
                "value":[
                  3,3
                ]
              }
            },
            "update": {
              "fillOpacity": {"value": 1}
            },
            "hover": {
              "fillOpacity": {"value": 0.5}
            }
          }
        }
      ],
"legends": [
  {
    "title":"Sauk river",
    "stroke": "color",
    "orient":"top-right",
    "offset":{"signal":"width<200?-10:0"},
    "encode": {
      "title": {
        "update": {
          "fontSize": {"value": 14}
        }
      },
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
 ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="32aa2787-8f4b-4303-a880-0938a87e461c"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Projected temperature changes in Puget Sound

# %%
####Templating
widgetID="8739c082-712e-4c06-8023-9387030711de"
datasetID="4e6fbd04-253d-4fae-929e-0dbc8e106c86"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://prep-admin.carto.com/api/v2/sql?q=SELECT year, avg_hist,avg_rcp45, avg_rcp85, min_hist, min_rcp45, min_rcp85, max_hist, max_rcp45, max_rcp85 FROM temp_graph_1 order by year asc",
      "name": "table",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "fold",
          "fields": [
            "avg_hist",
            "avg_rcp45",
            "avg_rcp85"
          ],
          "as": [
            "key",
            "y"
          ]
        },
        {
          "type": "filter",
          "expr": "datum.y!=null"
        },
        {
          "type": "filter",
          "expr": "datum.y!=0"
        },
        {"type": "formula", "as": "model", "expr": "substring(datum.key,4)"},
        {"type": "formula", "as": "op", "expr": "substring(datum.key,0,3)"},
        {"type": "formula", "as": "min", "expr": "datum.model==='hist' ? datum.min_hist : (datum.model==='rcp45' ? datum.min_rcp45 : datum.min_rcp85) "},
        {"type": "formula", "as": "max", "expr": "datum.model==='hist' ? datum.max_hist : (datum.model==='rcp45' ? datum.max_rcp45 : datum.max_rcp85) "},
        {
        "expr": "((datum.y - 44) + 12.45)",
        "type": "formula",
        "as": "y"
        },
        {
        "expr": "datum.year",
        "type": "formula",
        "as": "x"
        },
        {
        "expr": "((datum.min - 44)+ 12.45)",
        "type": "formula",
        "as": "min"
        },
        {
        "expr": "((datum.max - 44)+ 12.45)",
        "type": "formula",
        "as": "max"
        }
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Historical"
        },
        {
          "cat": "Low emissions (RCP 4.5)"
        },
        {
          "cat": "High emissions (RCP 4.5)"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "year"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "fields": [
          {
            "data": "table",
            "field": "y"
          },
          {
            "data": "table",
            "field": "min"
          },
          {
            "data": "table",
            "field": "max"
          }
        ]
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "model"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "title":"Years"
    },
    {
      "orient": "left",
      "scale": "y",
      "title":"ºF",
    "encode": {
      "title": {
        "update": {
          "dx": {"value": 0},
          "dy": {"value": 0},
          "x": {"value": 0},
          "y": {"value": -10},
          "align": {"value": "right"},
          "baseline": {"value": "bottom"},
          "angle": {"value": 0},
          "fontSize": {"value": 12}
        }
      }
    }
    }
  ],
  "marks": [
    {
      "type": "group",
      "interactive": false,
      "from": {
        "facet": {
          "name": "series",
          "data": "table",
          "groupby": "model"
        }
      },
      "marks": [
        
        {
          "type": "area",
          "from": {
            "data": "series"
          },
          "encode": {
            "update": {
              "interpolate": {"value": "monotone"},
              "x": {
                "scale": "x",
                "field": "year"
              },
              "y": {
                "scale": "y",
                "field": "max"
              },
              "y2": {
                "scale": "y",
                "field": "min"
              },
              "fill": {
                "scale": "color",
                "field": "model"
              },
              "fillOpacity": {
                "value": 0.5
              }
            },
            "hover": {
              "fillOpacity": {
                "value": 0.5
              }
            }
          }
        },
        {
          "type": "line",
          "from": {
            "data": "series"
          },
          "encode": {
            "enter": {
              "x": {
                "scale": "x",
                "field": "year"
              },
              "y": {
                "scale": "y",
                "field": "y"
              },
              "stroke": {
                "scale": "color",
                "field": "model"
              },
              "strokeWidth": {
                "value": 2
              }
            },
            "update": {
              "fillOpacity": {
                "value": 1
              }
            },
            "hover": {
              "fillOpacity": {
                "value": 0.5
              }
            }
          }
        }
      ]
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "fill": {
            "value": "#c34545"
          },
          "stroke": {
            "value": "#fff"
          },
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
  "legends": [
  {
    "stroke": "color",
    "orient":"top-left",
    "offset":{"signal":"width<200? 0:10"},
    "encode": {
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
],
 "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          },
          {
            "key": "model",
            "label": "Model",
            "format": null
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="dde74b70-70b9-4770-923a-d2647a576e9e"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Projected precipitation change in Puget Sound

# %%
####Templating
widgetID="518ad6e8-448f-45e6-943e-359af82e4ed0"
datasetID="49ef62d6-eebe-4a52-800e-d48d3d15996d"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://prep-admin.carto.com/api/v2/sql?q=SELECT year, avg_hist,avg_rcp45, avg_rcp85, min_hist, min_rcp45, min_rcp85, max_hist, max_rcp45, max_rcp85 FROM precip_graph order by year asc",
      "name": "table",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "fold",
          "fields": [
            "avg_hist",
            "avg_rcp45",
            "avg_rcp85"
          ],
          "as": [
            "key",
            "y"
          ]
        },
        {
          "type": "filter",
          "expr": "datum.y!=null"
        },
        {
          "type": "filter",
          "expr": "datum.y!=0"
        },
        {"type": "formula", "as": "model", "expr": "substring(datum.key,4)"},
        {"type": "formula", "as": "op", "expr": "substring(datum.key,0,3)"},
        {"type": "formula", "as": "min", "expr": "datum.model==='hist' ? datum.min_hist : (datum.model==='rcp45' ? datum.min_rcp45 : datum.min_rcp85) "},
        {"type": "formula", "as": "max", "expr": "datum.model==='hist' ? datum.max_hist : (datum.model==='rcp45' ? datum.max_rcp45 : datum.max_rcp85) "},
        {
        "expr": "(datum.y )*100",
        "type": "formula",
        "as": "y"
        },
        {
        "expr": "datum.year",
        "type": "formula",
        "as": "x"
        },
        {
        "expr": "((datum.min)*100)",
        "type": "formula",
        "as": "min"
        },
        {
        "expr": "((datum.max)*100)",
        "type": "formula",
        "as": "max"
        }
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Historical"
        },
        {
          "cat": "Low emissions (RCP 4.5)"
        },
        {
          "cat": "High emissions (RCP 4.5)"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "year"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "fields": [
          {
            "data": "table",
            "field": "y"
          },
          {
            "data": "table",
            "field": "min"
          },
          {
            "data": "table",
            "field": "max"
          }
        ]
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "model"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "title":"Years"
    },
    {
      "orient": "left",
      "scale": "y",
      "title":"% Change",
    "encode": {
      "title": {
        "update": {
          "dx": {"value": 0},
          "dy": {"value": 0},
          "x": {"value": 30},
          "y": {"value": -10},
          "align": {"value": "right"},
          "baseline": {"value": "bottom"},
          "angle": {"value": 0},
          "fontSize": {"value": 12}
        }
      }
    }
    }
  ],
  "marks": [
    {
      "type": "group",
      "interactive": false,
      "from": {
        "facet": {
          "name": "series",
          "data": "table",
          "groupby": "model"
        }
      },
      "marks": [
        
        {
          "type": "area",
          "from": {
            "data": "series"
          },
          "encode": {
            "update": {
              "interpolate": {"value": "monotone"},
              "x": {
                "scale": "x",
                "field": "year"
              },
              "y": {
                "scale": "y",
                "field": "max"
              },
              "y2": {
                "scale": "y",
                "field": "min"
              },
              "fill": {
                "scale": "color",
                "field": "model"
              },
              "fillOpacity": {
                "value": 0.5
              }
            },
            "hover": {
              "fillOpacity": {
                "value": 0.5
              }
            }
          }
        },
        {
          "type": "line",
          "from": {
            "data": "series"
          },
          "encode": {
            "enter": {
              "x": {
                "scale": "x",
                "field": "year"
              },
              "y": {
                "scale": "y",
                "field": "y"
              },
              "stroke": {
                "scale": "color",
                "field": "model"
              },
              "strokeWidth": {
                "value": 2
              }
            },
            "update": {
              "fillOpacity": {
                "value": 1
              }
            },
            "hover": {
              "fillOpacity": {
                "value": 0.5
              }
            }
          }
        }
      ]
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "fill": {
            "value": "#c34545"
          },
          "stroke": {
            "value": "#fff"
          },
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
  "legends": [
  {
    "stroke": "color",
    "orient":"top-left",
    "offset":{"signal":"width<200? 0:10"},
    "encode": {
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
],
"interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          },
          {
            "key": "model",
            "label": "Model",
            "format": null
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="b75bea39-70e1-4107-8272-6c6a73ceb306"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Temperature change

# %%
####Templating
widgetID="570355b8-01b5-435c-b682-58ae45d52115"
datasetID="3a17f882-a1b3-47dc-a52b-e68d7d02aae5"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/3a17f882-a1b3-47dc-a52b-e68d7d02aae5?sql=select%20year%20as%20x,%20annual%20as%20y%20from%20index_3a17f882a1b347dca52be68d7d02aae5%20order%20by%20year%20ASC",
      "name": "table",
      "format": {
        "type": "json",
        "property": "data"
      }
    },
    {
      "name":"dots",
      "source":"table",
      "transform":[
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"

        }
      ]
    },
    {
      "name": "regression",
      "source": "table",
      "transform": [
        {
          "type": "joinaggregate",
          "fields": [
            "x",
            "x",
            "x",
            "y",
            "x",
            "x"
          ],
          "ops": [
            "mean",
            "variance",
            "count",
            "mean",
            "min",
            "max"
          ],
          "as": [
            "mean_x",
            "variance_x",
            "count_x",
            "mean_y",
            "x0",
            "x1"
          ]
        },
        {
          "expr": "(datum.x - datum.mean_x) * (datum.y - datum.mean_y) / datum.count_x",
          "type": "formula",
          "as": "precovariance"
        },
        {
          "type": "joinaggregate",
          "fields":  [
              "precovariance"
            ],
            "ops":[
              "sum"
            ],
            "as":["covariance"]
        },
        {
          "expr": "datum.covariance / datum.variance_x",
          "type": "formula",
          "as": "a_factor"
        },
        {
          "expr": "datum.mean_y - datum.a_factor * datum.mean_x",
          "type": "formula",
          "as": "b_factor"
        },
        {
          "expr": "datum.a_factor * datum.x + datum.b_factor",
          "type": "formula",
          "as": "y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "xscale",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "yscale",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "y"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "labelOverlap": "parity",
      "scale": "xscale"
    },
    {
      "orient": "left",
      "scale": "yscale",
      "labelOverlap": "parity",
      "title":"ºF",
    "encode": {
      "title": {
        "update": {
          "dx": {"value": 0},
          "dy": {"value": 0},
          "x": {"value": 0},
          "y": {"value": -10},
          "align": {"value": "right"},
          "baseline": {"value": "bottom"},
          "angle": {"value": 0},
          "fontSize": {"value": 12}
        }
      }
    }
    }
  ],
  "marks": [
    {"name":"lines",
    "interactive": false,
      "type": "line",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "value": "#c34545"
          },
          "strokeJoin":{"value":"round"}
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "type": "rule",
      "interactive": false,
      "from": {
        "data": "regression"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x0"
          },
          "x2": {
            "scale": "xscale",
            "field": "x1"
          },
          "y": {
            "scale": "yscale",
            "field": "mean_y"
          },
          "y2": {
            "scale": "yscale",
            "field": "mean_y"
          },
          "stroke": {
            "value": "#000"
          },
           "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "type": "line",
      "interactive": false,
      "from": {
        "data": "regression"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "value": "#263e57"
          }
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {"data": "dots"},
      "encode": {
        "enter": {
            "stroke": {
            "value": "#c34545"
          },
          "fill": {
            "value": "#fff"
          },
          "x": { "scale": "xscale", "field": "x" },
          "y": { "scale": "yscale", "field": "y" }
        },
        "update": {
          "opacity": { "value": 1 }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": { "data": "lines" },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            { "signal": "width" },
            { "signal": "height" }
          ]
        }
      ],
      "encode": {
        "update": {
            "fill":{"value":"red"},
          "path": { "field": "path" },
          "opacity": { "value": 0 }
        }
      }
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="ee0f0f3e-0223-4404-9b37-321354acc65c"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Precipitation change

# %%
####Templating
widgetID="73f00267-fe34-42aa-a611-13b102f38d75"
datasetID="06c44f9a-aae7-401e-874c-de13b7764959"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/06c44f9a-aae7-401e-874c-de13b7764959?sql=select annual as y, year as x from index_06c44f9aaae7401e874cde13b7764959%20order%20by%20year%20asc",
      "name": "table",
      "format": {
        "type": "json",
        "property": "data"
      }
    },
    {
      "name":"dots",
      "source":"table",
      "transform":[
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"

        }
      ]
    },
    {
      "name": "regression",
      "source": "table",
      "transform": [
        {
          "type": "joinaggregate",
          "fields": [
            "x",
            "x",
            "x",
            "y",
            "x",
            "x"
          ],
          "ops": [
            "mean",
            "variance",
            "count",
            "mean",
            "min",
            "max"
          ],
          "as": [
            "mean_x",
            "variance_x",
            "count_x",
            "mean_y",
            "x0",
            "x1"
          ]
        },
        {
          "expr": "(datum.x - datum.mean_x) * (datum.y - datum.mean_y) / datum.count_x",
          "type": "formula",
          "as": "precovariance"
        },
        {
          "type": "joinaggregate",
          "fields":  [
              "precovariance"
            ],
            "ops":[
              "sum"
            ],
            "as":["covariance"]
        },
        {
          "expr": "datum.covariance / datum.variance_x",
          "type": "formula",
          "as": "a_factor"
        },
        {
          "expr": "datum.mean_y - datum.a_factor * datum.mean_x",
          "type": "formula",
          "as": "b_factor"
        },
        {
          "expr": "datum.a_factor * datum.x + datum.b_factor",
          "type": "formula",
          "as": "y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "xscale",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "yscale",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "y"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "labelOverlap": "parity",
      "scale": "xscale"
    },
    {
      "orient": "left",
      "scale": "yscale",
      "labelOverlap": "parity",
      "title":"MM",
    "encode": {
      "title": {
        "update": {
          "dx": {"value": 0},
          "dy": {"value": 0},
          "x": {"value": 0},
          "y": {"value": -10},
          "align": {"value": "right"},
          "baseline": {"value": "bottom"},
          "angle": {"value": 0},
          "fontSize": {"value": 12}
        }
      }
    }
    }
  ],
  "marks": [
    {"name":"lines",
    "interactive": false,
      "type": "line",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "value": "#3671CC"
          },
          "strokeJoin":{"value":"round"}
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "type": "rule",
      "interactive": false,
      "from": {
        "data": "regression"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x0"
          },
          "x2": {
            "scale": "xscale",
            "field": "x1"
          },
          "y": {
            "scale": "yscale",
            "field": "mean_y"
          },
          "y2": {
            "scale": "yscale",
            "field": "mean_y"
          },
          "stroke": {
            "value": "#000"
          },
           "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "type": "line",
      "interactive": false,
      "from": {
        "data": "regression"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "value": "#263e57"
          }
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {"data": "dots"},
      "encode": {
        "enter": {
            "stroke": {
            "value": "#3671CC"
          },
          "fill": {
            "value": "#fff"
          },
          "x": { "scale": "xscale", "field": "x" },
          "y": { "scale": "yscale", "field": "y" }
        },
        "update": {
          "opacity": { "value": 1 }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": { "data": "lines" },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            { "signal": "width" },
            { "signal": "height" }
          ]
        }
      ],
      "encode": {
        "update": {
            "fill":{"value":"red"},
          "path": { "field": "path" },
          "opacity": { "value": 0 }
        }
      }
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="5335a512-a548-45a6-8e8e-381a84cc0f6c"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Precipitation change sonoma

# %%
####Templating
widgetID="ec40fa88-2f75-4681-abd4-0161db504ee6"
datasetID="c9a1753c-9bc5-4024-b4bd-dff9ec9044c1"
specV3=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://prep-admin.carto.com/api/v2/sql?q=select%20*, date as x %20from%20sonoma_widgets_sonoma_precip%20order%20by%20date%20asc",
      "name": "table",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "formula",
          "as": "y",
          "expr": "datum.x < 2010 ? datum.hst : datum.ccsm4_rcp85"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "90TH Percentile (56.4 IN/YR)"
        },
        {
          "cat": "10TH Percentile (27.1 IN/YR)"
        }
      ]
    }
    
  ],
  "scales": [
    {
      "name": "xscale",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "yscale",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": ["#3B4F63","#aaa"],
      "domain": {
        "data": "legend",
        "field": "cat"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "labelOverlap": "parity",
      "scale": "xscale"
    },
    {
      "orient": "left",
      "scale": "yscale",
      "labelOverlap": "parity",
      "title": "Annual precipitation In inches",
      "encode": {
        "title": {
          "update": {
            "dx": {
              "value": 0
            },
            "dy": {
              "value": 0
            },
            "x": {
              "value": 0
            },
            "y": {
              "value": -10
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "bottom"
            },
            "angle": {
              "value": 0
            },
            "fontSize": {
              "value": 12
            }
          }
        }
      }
    }
  ],
  "marks": [
    
    {
      "type": "rule",
      "interactive": false,
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "value": 0
          },
          "x2": {
            "signal": "width"
          },
          "y": {
            "scale": "yscale",
            "value": 27.1
          },
          "stroke": {
            "value": "#aaa"
          },
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
     {
      "type": "rule",
      "interactive": false,
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "value": 0
          },
          "x2": {
            "signal": "width"
          },
          "y": {
            "scale": "yscale",
            "value": 56.4
          },
          "stroke": {
            "value": "#3B4F63"
          },
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "lines",
      "interactive": false,
      "type": "line",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "value": "#ddd000"
          },
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "stroke": {
            "value": "#ddd000"
          },
          "fill": {
            "value": "#fff"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "lines"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
  "legends": [
  {
    "fill": "color",
    "orient":"bottom",
    "encode": {
      "symbols": {
        "update": {
          "stroke": {"value": "transparent"},
          "shape": {"value": "M-1,-0.5 H 2V 0 H-1Z"}
        }
      }
    }
  }
],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="5cce6d70-695d-46d1-9215-b22d9b2c1174"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Historical and Projected annual changes in summer air temperature (ºF)

# %%
####Templating
widgetID = "f2fbd06e-8e2e-4b06-a883-0e4c1146c79c"
datasetID = "3feaf26c-42c8-43ce-b1b5-07a02a773c36"
specV3 = json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/3feaf26c-42c8-43ce-b1b5-07a02a773c36?sql=select * from index_3feaf26c42c843ceb1b507a02a773c36 order by date asc",
      "name": "table",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "expr": "datum.date < 2010 ? ((datum.HST*1.8)+32) : ((datum.CCSM4_rcp85*1.8)+32)",
          "type": "formula",
          "as": "y"
        },
        {
          "expr": "datum.date < 2010 ? null : ((datum.min*1.8)+32)",
          "type": "formula",
          "as": "y0"
        },
        {
          "expr": "datum.date < 2010 ? null : ((datum.max*1.8)+32)",
          "type": "formula",
          "as": "y1"
        },
        {"type": "project", "fields": ["date", "y", "y0","y1"], "as": ["x", "y", "y0","y1"]},
        {
          "expr": "datum.x < 2010 ? 'Historic' : 'CCSM4'",
          "type": "formula",
          "as": "c"
        }
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Historic"
        },
        {
          "cat": "CCSM4"
        },
        {
          "cat": "Models amplitude"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "xscale",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "yscale",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": false,
      "domain": {"fields": [{
        "data": "table",
        "field": "y"},
        {
        "data": "table",
        "field": "y0"},
        {
        "data": "table",
        "field": "y1"}
      ]}
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": ["#efa600","#1a6d9e","#CEE2EB"],
      "domain": {
        "data": "legend",
        "field": "cat"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "xscale"
    },
    {
      "orient": "left",
      "scale": "yscale",
      "title": "ºF",
      "encode": {
        "title": {
          "update": {
            "dx": {
              "value": 0
            },
            "dy": {
              "value": 0
            },
            "x": {
              "value": 0
            },
            "y": {
              "value": -10
            },
            "align": {
              "value": "right"
            },
            "baseline": {
              "value": "bottom"
            },
            "angle": {
              "value": 0
            },
            "fontSize": {
              "value": 12
            }
          }
        }
      }
    }
  ],
  "marks": [
    {
      "name": "datarea-modeled",
      "interactive": false,
      "type": "area",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          
          "defined": {
            "signal": "datum.y0!==null"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y0"
          },
          "y2": {
            "scale": "yscale",
            "field": "y1"
          },
          "fill": {
            "value": "#CEE2EB"
          },
          
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "lines",
 "type": "group",
 "from": {
 "facet": {
          "name": "linesc",
          "data": "table",
          "groupby": "c"
        }
 },
 "marks": [
  
    {
      
      "interactive": false,
      "type": "line",
      "from": {
        "data": "linesc"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "scale": "color",
            "field": "c"
          },
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    }
    ]
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "fill": {
            "value": "#c34545"
          },
          "stroke": {
            "value": "#fff"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
  "legends": [
  {
    "fill": "color",
    "orient":"top-left",
    "offset":{"signal":"width<200? 0:10"},
    "encode": {
      "symbols": {
        "update": {
          "shape":{
            "value":"square"
          },
          "stroke": {"value": "transparent"},
           "size": {"value": 40}
        }
      },
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
 ],
 "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          }
        ]
      }
    }
  ]
}
""")
vega4view = dict(specV3)
vega4view['config'] = json.loads(Config)
vega4view['width'] = 300
vega4view['height'] = 300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="3231473c-8434-44b2-932a-2f053abcc11b"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# # Temperature maximums in Porto Alegre

# %%
####Templating
widgetID="f30386c9-7fd1-4669-878f-faaaa44abb95"
datasetID="c2d418e1-6fef-4204-863c-090d0461334d"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/c2d418e1-6fef-4204-863c-090d0461334d?sql=select%20value%20as%20y,%20date%20as%20x,%20type from%20index_c2d418e16fef4204863c090d0461334d%20order%20by%20date%20ASC",
      "name": "table",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "expr": "test(/rcp85/gi, datum.type) ? 'rcp85' : 'rcp45'",
          "type": "formula",
          "as": "c"
        },
        {
  "type": "joinaggregate",
  "fields": ["y", "y"],
  "ops": ["min", "max"],
  "groupby":["c","x"],
  "as": ["y0", "y1"]
 },
     {"type": "filter", "expr": "test(/mean/gi, datum.type)"}   
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Mean RCP 4.5"
        },
        {
          "cat": "Mean RCP 8.5"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "xscale",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "yscale",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": false,
      "domain": {
         "fields": [
           {
        "data": "table",
        "field": "y"},
        {
        "data": "table",
        "field": "y0"},
        {
        "data": "table",
        "field": "y1"}
        ]
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": ["#efa600","#25b5cd"],
      "domain": {
        "data": "legend",
        "field": "cat"
      }
    }
  ],
  "axes": [
    {  "title": "Years",
      "orient": "bottom",
      "scale": "xscale"
    },
    {
      "orient": "left",
      "scale": "yscale",
      "title": "ºC",
      "encode": {
        "title": {
          "update": {
            "dx": {
              "value": 0
            },
            "dy": {
              "value": 0
            },
            "x": {
              "value": 0
            },
            "y": {
              "value": -10
            },
            "align": {
              "value": "right"
            },
            "baseline": {
              "value": "bottom"
            },
            "angle": {
              "value": 0
            }
          }
        }
      }
    }
  ],
  "marks": [
    {
      "name": "lines",
"type": "group",
"from": {
"facet": {
          "name": "linesc",
          "data": "table",
          "groupby": "c"
        }
},
"marks": [
    {
      "name": "datarea-modeled",
      "interactive": false,
      "type": "area",
      "from": {
        "data": "linesc"
      },
      "encode": {
        "enter": {
          
          "defined": {
            "signal": "datum.y0!==null"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y0"
          },
          "y2": {
            "scale": "yscale",
            "field": "y1"
          },
         "fill": {
            "scale": "color",
            "field": "c"
          },
          
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "opacity": {
            "value": 0.2
          }
        }
      }
    },
  
    {
      
      "interactive": false,
      "type": "line",
      "from": {
        "data": "linesc"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "scale": "color",
            "field": "c"
          },
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    }
    ]
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "fill": {
            "value": "#c34545"
          },
          "stroke": {
            "value": "#fff"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
  "legends": [
  {
    "fill": "color",
    "orient":"top-left",
    "offset":{"signal":"width<200? 0:10"},
    "encode": {
      "symbols": {
        "update": {
          "shape":{
            "value":"square"
          },
          "stroke": {"value": "transparent"},
           "size": {"value": 40}
        }
      },
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
],
"interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="2049249d-4c9b-4520-a9d3-da7a1aa952c6"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Temperature lows in Porto Alegre

# %%
####Templating
widgetID="0bf764d6-9bb8-4565-bd11-4d729d0fd004"
datasetID="62520fd2-2dfb-4a13-840b-35ac88fc7aa4"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/62520fd2-2dfb-4a13-840b-35ac88fc7aa4?sql=select%20value%20as%20y,%20date%20as%20x,%20type from%20index_62520fd22dfb4a13840b35ac88fc7aa4%20order%20by%20date%20ASC",
      "name": "table",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "expr": "test(/rcp85/gi, datum.type) ? 'rcp85' : 'rcp45'",
          "type": "formula",
          "as": "c"
        },
        {
  "type": "joinaggregate",
  "fields": ["y", "y"],
  "ops": ["min", "max"],
  "groupby":["c","x"],
  "as": ["y0", "y1"]
 },
     {"type": "filter", "expr": "test(/mean/gi, datum.type)"}   
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Mean RCP 4.5"
        },
        {
          "cat": "Mean RCP 8.5"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "xscale",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "yscale",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": false,
      "domain": {
         "fields": [
           {
        "data": "table",
        "field": "y"},
        {
        "data": "table",
        "field": "y0"},
        {
        "data": "table",
        "field": "y1"}
        ]
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": ["#efa600","#25b5cd"],
      "domain": {
        "data": "legend",
        "field": "cat"
      }
    }
  ],
  "axes": [
    {  "title": "Years",
      "orient": "bottom",
      "scale": "xscale"
    },
    {
      "orient": "left",
      "scale": "yscale",
      "title": "ºC",
      "encode": {
        "title": {
          "update": {
            "dx": {
              "value": 0
            },
            "dy": {
              "value": 0
            },
            "x": {
              "value": 0
            },
            "y": {
              "value": -10
            },
            "align": {
              "value": "right"
            },
            "baseline": {
              "value": "bottom"
            },
            "angle": {
              "value": 0
            }
          }
        }
      }
    }
  ],
  "marks": [
    {
      "name": "lines",
"type": "group",
"from": {
"facet": {
          "name": "linesc",
          "data": "table",
          "groupby": "c"
        }
},
"marks": [
    {
      "name": "datarea-modeled",
      "interactive": false,
      "type": "area",
      "from": {
        "data": "linesc"
      },
      "encode": {
        "enter": {
          
          "defined": {
            "signal": "datum.y0!==null"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y0"
          },
          "y2": {
            "scale": "yscale",
            "field": "y1"
          },
         "fill": {
            "scale": "color",
            "field": "c"
          },
          
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "opacity": {
            "value": 0.2
          }
        }
      }
    },
  
    {
      
      "interactive": false,
      "type": "line",
      "from": {
        "data": "linesc"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "scale": "color",
            "field": "c"
          },
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    }
    ]
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "fill": {
            "value": "#c34545"
          },
          "stroke": {
            "value": "#fff"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
  "legends": [
  {
    "fill": "color",
    "orient":"top-left",
    "offset":{"signal":"width<200? 0:10"},
    "encode": {
      "symbols": {
        "update": {
          "shape":{
            "value":"square"
          },
          "stroke": {"value": "transparent"},
           "size": {"value": 40}
        }
      },
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
],
"interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="b75bd6ce-9c7c-422e-8db0-64809e0354fc"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)

# %% [markdown]
# #  Projected changes in streamflow - Rain dominant

# %%
####Templating
widgetID="a43d3629-46b3-4537-a96c-9ac67a260e0c"
datasetID="bd61bb68-592b-42ff-90d6-b6a5d0006101"
specV3=json.loads("""
{
  "autosize": {"type": "pad", "resize": true, "contains":"padding"},
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "url": "https://api.resourcewatch.org/query/bd61bb68-592b-42ff-90d6-b6a5d0006101?sql=select%20value%20as%20y,%20date%20as%20x,%20type from%20index_c2d418e16fef4204863c090d0461334d%20order%20by%20date%20ASC",
      "name": "table",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "expr": "test(/rcp85/gi, datum.type) ? 'rcp85' : 'rcp45'",
          "type": "formula",
          "as": "c"
        },
        {
  "type": "joinaggregate",
  "fields": ["y", "y"],
  "ops": ["min", "max"],
  "groupby":["c","x"],
  "as": ["y0", "y1"]
 },
     {"type": "filter", "expr": "test(/mean/gi, datum.type)"}   
      ]
    },
    {
      "name": "legend",
      "values": [
        {
          "cat": "Mean RCP 4.5"
        },
        {
          "cat": "Mean RCP 8.5"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "xscale",
      "type": "linear",
      "range": "width",
      "nice": false,
      "zero": false,
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "yscale",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": false,
      "domain": {
         "fields": [
           {
        "data": "table",
        "field": "y"},
        {
        "data": "table",
        "field": "y0"},
        {
        "data": "table",
        "field": "y1"}
        ]
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": ["#efa600","#25b5cd"],
      "domain": {
        "data": "legend",
        "field": "cat"
      }
    }
  ],
  "axes": [
    {  "title": "Years",
      "orient": "bottom",
      "scale": "xscale"
    },
    {
      "orient": "left",
      "scale": "yscale",
      "title": "mm",
      "encode": {
        "title": {
          "update": {
            "dx": {
              "value": 0
            },
            "dy": {
              "value": 0
            },
            "x": {
              "value": 0
            },
            "y": {
              "value": -10
            },
            "align": {
              "value": "right"
            },
            "baseline": {
              "value": "bottom"
            },
            "angle": {
              "value": 0
            }
          }
        }
      }
    }
  ],
  "marks": [
    {
      "name": "lines",
"type": "group",
"from": {
"facet": {
          "name": "linesc",
          "data": "table",
          "groupby": "c"
        }
},
"marks": [
    {
      "name": "datarea-modeled",
      "interactive": false,
      "type": "area",
      "from": {
        "data": "linesc"
      },
      "encode": {
        "enter": {
          
          "defined": {
            "signal": "datum.y0!==null"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y0"
          },
          "y2": {
            "scale": "yscale",
            "field": "y1"
          },
         "fill": {
            "scale": "color",
            "field": "c"
          },
          
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "opacity": {
            "value": 0.2
          }
        }
      }
    },
  
    {
      
      "interactive": false,
      "type": "line",
      "from": {
        "data": "linesc"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          },
          "stroke": {
            "scale": "color",
            "field": "c"
          },
          "strokeJoin": {
            "value": "round"
          }
        },
        "update": {
          "strokeOpacity": {
            "value": 1
          }
        }
      }
    }
    ]
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "fill": {
            "value": "#c34545"
          },
          "stroke": {
            "value": "#fff"
          },
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "xscale",
            "field": "x"
          },
          "y": {
            "scale": "yscale",
            "field": "y"
          }
        },
        "update": {
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
  "legends": [
  {
    "fill": "color",
    "orient":"top-left",
    "offset":{"signal":"width<200? 0:10"},
    "encode": {
      "symbols": {
        "update": {
          "shape":{
            "value":"square"
          },
          "stroke": {"value": "transparent"},
           "size": {"value": 40}
        }
      },
      "legend": {
        "update": {
          "stroke": {"value": "transparent"},
          "strokeWidth": {"value": 1.5}
        }
      }
    }
  }
],
"interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "key": "x",
            "label": "Year",
            "format": null
          },
          {
            "key": "y",
            "label": "Value",
            "format": ".2f"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['config']=json.loads(Config)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="ae7d220e-fd2f-449a-815d-a0c653da0b12"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
PatchApi(specV3, datasetID, widgetID)
