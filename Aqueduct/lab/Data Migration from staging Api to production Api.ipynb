# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Migrate-AQ-Food-api-entities" data-toc-modified-id="Migrate-AQ-Food-api-entities-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Migrate AQ Food api entities</a></span></li></ul></div>

# %% [markdown]
# Migrate AQ Food api entities:
#     * Datasets with layers and widgets associated plus metadata amd vocabulary.
#     * Update the notebooks for layers and widgets to reflect the new layer/widget and dataset id
# Migrate AQ Risk api entities:
#     * Datasets with layers plus metadata
# Migrate AQ Rankings api entities:
#     * Datasets with layers plus metadata
#
# Set up the micro in production For floods and Risk

# %% [markdown]
# # Migrate AQ Food and AQ country ranking api entities

# %%
import getpass
import requests as re
import json
from datetime import datetime

# %%
staging_server = "https://staging-api.globalforestwatch.org"
prod_server = "https://api.resourcewatch.org"

# %%
def auth():
    with re.Session() as s:
        headers = {'Content-Type': 'application/json'}
        payload = json.dumps({ 'email': f'{input("Email: ")}',
                               'password': f'{getpass.getpass(prompt="Password: ")}'})
        response = s.post(f'{prod_server}/auth/login',  headers = headers,  data = payload)
        response.raise_for_status()
    return response.json().get('data').get('token')

token = auth()
# Out:
# Email: alicia.arenzana@vizzuality.com
# Password: ········

# %%
def getUrl(url, payload):
    response = re.get(url, payload)
    response.raise_for_status()
    return response.json()

def DeleteAssets(url):
    response = re.delete(url, headers = {'Authorization':f'Bearer {token}'})
    response.raise_for_status()
    return response.status_code

def CreateAssets(url, body):
    response = re.post(url, data=json.dumps(body), headers = {'Authorization':f'Bearer {token}', 'Content-Type': 'application/json'})
    if response.status_code !=200:
        print(response.text)
        print(url)
        print(json.dumps(body))
    response.raise_for_status()
    return response.json()

def recreateDataset(dataset):
    
    if dataset.get('type')!='dataset':
        return None
    
    url = f'{prod_server}/v1/dataset'
    body = {'dataset':{
        'application': dataset['attributes'].get('application'),
        'name': dataset['attributes'].get('name'),
        'connectorType': dataset['attributes'].get('connectorType'),
        'provider': dataset['attributes'].get('provider'),
        'published': dataset['attributes'].get('published'),
        'overwrite': dataset['attributes'].get('overwrite'),
        'mainDateField': dataset['attributes'].get('mainDateField'),
        'env': dataset['attributes'].get('env'),
        'geoInfo': dataset['attributes'].get('geoInfo'),
        'protected': dataset['attributes'].get('protected'),
        'legend': dataset['attributes'].get('legend'),
        'widgetRelevantProps': dataset['attributes'].get('widgetRelevantProps'),
        'layerRelevantProps': dataset['attributes'].get('layerRelevantProps')
        }
    }
    if dataset['attributes'].get('provider') == 'cartodb':
            body['dataset']['connectorUrl'] =  dataset['attributes'].get('connectorUrl')
    if dataset['attributes'].get('provider') == 'gee':
            body['dataset']['tableName'] =  dataset['attributes'].get('tableName')
    response = CreateAssets(url, body)
    return response

def recreateLayer(datasetId, layer):
    if layer.get('type')!='layer':
        return None
    
    url = f'{prod_server}/v1/dataset/{datasetId}/layer'

    body = {
        'application': layer['attributes'].get('application'),
        'name': layer['attributes'].get('name'),
        'iso': layer['attributes'].get('iso'),
        'provider': layer['attributes'].get('provider'),
        'default': layer['attributes'].get('default'),
        'protected': layer['attributes'].get('protected'),
        'published': layer['attributes'].get('published'),
        'env': layer['attributes'].get('env'),
        'layerConfig': layer['attributes'].get('layerConfig'),
        'legendConfig': layer['attributes'].get('legendConfig'),
        'interactionConfig': layer['attributes'].get('interactionConfig'),
        'applicationConfig': layer['attributes'].get('applicationConfig'),
        'staticImageConfig': layer['attributes'].get('staticImageConfig')
    }
    
    response = CreateAssets(url, body)
    return response

def recreateWidget(datasetId, widget):
    if widget.get('type')!='widget':
        return None
    
    url = f'{prod_server}/v1/dataset/{datasetId}/widget'
    body = {
        'application': widget['attributes'].get('application'),
        'name': widget['attributes'].get('name'),
        'description': widget['attributes'].get('description'),
        'verified': widget['attributes'].get('verified'),
        'default': widget['attributes'].get('default'),
        'protected': widget['attributes'].get('protected'),
        'defaultEditableWidget': widget['attributes'].get('defaultEditableWidget'),
        'published': widget['attributes'].get('published'),
        'freeze': widget['attributes'].get('freeze'),
        'env': widget['attributes'].get('env'),
        'queryUrl': widget['attributes'].get('queryUrl'),
        'widgetConfig': widget['attributes'].get('widgetConfig'),
        'template': widget['attributes'].get('template'),
        'layerId': widget['attributes'].get('layerId')
    }
    response = CreateAssets(url, body)
    return response

def recreateMetadata(datasetId, metadata, layerId=None, widgetId=None):
    if metadata.get('type')!='metadata':
        return None
    if layerId and widgetId:
        raise Exception("layerId and widgetId not allowed at the same time")
    elif layerId:
        url = f'{prod_server}/v1/dataset/{datasetId}/layer/{layerId}/metadata'
    elif widgetId:
        url = f'{prod_server}/v1/dataset/{datasetId}/widget/{widgetId}/metadata'
    else:
        url = f'{prod_server}/v1/dataset/{datasetId}/metadata'
    
    body = {
        'application': metadata['attributes'].get('application'),
        'language': metadata['attributes'].get('language'),
        'description': metadata['attributes'].get('description'),
        'info': metadata['attributes'].get('info'),
    }
    if metadata['attributes'].get('name'):
        body['name'] = metadata['attributes'].get('name')
    
    response = CreateAssets(url, body)
    return response

def recreateVocabulary(datasetId, vocabulary):
    if vocabulary.get('type')!='vocabulary':
        return None
    url = f"{prod_server}/v1/dataset/{datasetId}/vocabulary/{vocabulary['attributes']['name']}"
    body = {
        'application': vocabulary['attributes'].get('application'),
        'tags': vocabulary['attributes'].get('tags')
    }
    
    response = CreateAssets(url, body)
    return response

# %% [markdown]
# ### Get all layers in staging

# %%
url = f'{staging_server}/v1/dataset'
payload={
    'application':'aqueduct',
    'status':'saved',
    'published':'true',
    'includes':'widget,layer,vocabulary,metadata',
    'page[size]':1613982331640
}

stagingData = getUrl(url,payload)
stagingData
# Out:
# {'data': [{'id': '05c330d7-49cf-42d6-bada-e255b8c8e115',
#    'type': 'dataset',
#    'attributes': {'name': 'Global growing crops under high water stress conditions',
#     'slug': 'Global-growing-crops-under-high-water-stress-conditions-1490086842548',
#     'type': None,
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '58333dcfd9f39b189ca44c75',
#     'connectorUrl': 'https://wri-01.carto.com/tables/aqueduct_projections_20150309/public',
#     'sources': [],
#     'tableName': 'aqueduct_projections_20150309',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': False,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2016-12-19T17:17:12.328Z',
#     'updatedAt': '2017-01-31T15:59:55.957Z',
#     'dataLastUpdated': None,
#     'metadata': [],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [{'type': 'vocabulary',
#       'attributes': {'resource': {'id': '05c330d7-49cf-42d6-bada-e255b8c8e115',
#         'type': 'dataset'},
#        'tags': ['global', 'all_crops', 'global,all_crops'],
#        'name': 'legacy',
#        'application': 'aqueduct'}}],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}},
#   {'id': '345cfef3-ee8a-46bc-9bb9-164c406dfd2c',
#    'type': 'dataset',
#    'attributes': {'name': 'Interanual variability',
#     'slug': 'Interanual-variability-1490086842547',
#     'type': None,
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/aqueduct_projections_20150309/public',
#     'sources': [],
#     'tableName': 'aqueduct_projections_20150309',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': False,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2016-12-14T16:34:35.922Z',
#     'updatedAt': '2016-12-14T16:34:36.076Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5891b61b3d81e10b00e6a5b4',
#       'type': 'metadata',
#       'attributes': {'dataset': '345cfef3-ee8a-46bc-9bb9-164c406dfd2c',
#        'application': 'aqueduct',
#        'resource': {'id': '345cfef3-ee8a-46bc-9bb9-164c406dfd2c',
#         'type': 'dataset'},
#        'language': 'en',
#        'name': 'Interanual variability',
#        'description': 'Interannual variability measures the variability in water supply from year to year.',
#        'source': '',
#        'citation': 'See WRI Aqueduct Water Risk Atlas',
#        'license': '',
#        'info': {'organization': 'WRI'},
#        'createdAt': '2017-02-01T10:19:07.624Z',
#        'updatedAt': '2017-02-01T10:19:07.624Z',
#        'status': 'published'}}],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [{'type': 'vocabulary',
#       'attributes': {'resource': {'id': '345cfef3-ee8a-46bc-9bb9-164c406dfd2c',
#         'type': 'dataset'},
#        'tags': ['global',
#         'all_crops',
#         'one_crop',
#         'global,all_crops,one_crop'],
#        'name': 'legacy',
#        'application': 'aqueduct'}}],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}},
#   {'id': 'c4ee894f-2a9f-4681-9c3d-d94cf106f796',
#    'type': 'dataset',
#    'attributes': {'name': 'World Price',
#     'slug': 'World-Price-1490086842551',
#     'type': None,
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '58333dcfd9f39b189ca44c75',
#     'connectorUrl': 'https://wri-01.carto.com/tables/combined01_prepared',
#     'sources': [],
#     'tableName': 'combined01_prepared',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': False,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2017-01-31T11:47:27.811Z',
#     'updatedAt': '2017-01-31T13:05:17.359Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5a214119fe593400133f79f8',
#       'type': 'metadata',
#       'attributes': {'dataset': 'c4ee894f-2a9f-4681-9c3d-d94cf106f796',
#        'application': 'aqueduct',
#        'resource': {'id': 'c4ee894f-2a9f-4681-9c3d-d94cf106f796',
#         'type': 'dataset'},
#        'language': 'en',
#        'name': 'World prices for major commodity crops',
#        'description': 'These estimates represent prices for the major commodity crops when global production meets global demand.',
#        'info': {'sources': [{'source-url': 'https://www.ifpri.org/program/impact-model',
#           'source-name': 'IFPRI IMPACT 2015'}],
#         'units': '2005 USD/mt',
#         'scenario': 'SSP2-MIROC',
#         'resolution': 'global'},
#        'createdAt': '2017-12-01T11:46:33.679Z',
#        'updatedAt': '2019-11-14T08:53:49.114Z',
#        'status': 'published'}}],
#     'widget': [{'id': '9391e42c-f32b-40d9-a282-3083e617464f',
#       'type': 'widget',
#       'attributes': {'name': 'World Price (USD/Ton)',
#        'dataset': 'c4ee894f-2a9f-4681-9c3d-d94cf106f796',
#        'slug': 'world-price-usd-ton',
#        'userId': '5858f37140621f11066fb2f7',
#        'description': '',
#        'source': '',
#        'sourceUrl': None,
#        'authors': '',
#        'application': ['aqueduct'],
#        'verified': False,
#        'default': True,
#        'protected': False,
#        'defaultEditableWidget': False,
#        'published': True,
#        'thumbnailUrl': 'http://wri-api-backups.s3.amazonaws.com/resourcewatch/staging/thumbnails/9391e42c-f32b-40d9-a282-3083e617464f-1573721786503.png',
#        'freeze': False,
#        'env': 'production',
#        'queryUrl': None,
#        'widgetConfig': {'axes': [{'type': 'x',
#           'scale': 'val',
#           'ticks': 7,
#           'tick_size': 0,
#           'title': 'US Dollars per metric ton',
#           'properties': {'labels': {'text': {'template': "{{datum.data | number:'.3s'}}"},
#             'align': {'value': 'center'},
#             'baseline': {'value': 'middle'}},
#            'title': {'dy': {'value': 25}}}},
#          {'grid': True,
#           'type': 'y',
#           'layer': 'back',
#           'scale': 'cat',
#           'tick_size': 80,
#           'properties': {'grid': {'stroke': {'value': '#eeeeee'},
#             'stroke_width': {'value': 1}},
#            'ticks': {'stroke': {'value': '#eeeeee'}},
#            'labels': {'text': {'template': '{{datum.data | slice:0,1 | upper}}{{datum.data | slice:1,100, datum.crop}}'},
#             'type': {'value': 'axis'},
#             'align': {'value': 'left'},
#             'baseline': {'value': 'bottom'},
#             'font_size': {'value': 14}},
#            'major_ticks': {'stroke_width': {'value': 2}}}}],
#         'data': [{'url': "https://wri-01.carto.com/api/v2/sql?q=select round((sum(value))::numeric,2) as val,avg(value) as val_avg, max_value, commodity, impactparameter, region, '2005 usd/Ton' as units from (SELECT  max(value) over (partition by impactparameter) max_value, * FROM combined01_prepared_new where scenario = 'SSP2-MIRO' and impactparameter = 'World price') r {{where}}  and commodity IN  ('maize','rice','soybean','wheat') group by max_value, region, commodity, impactparameter order by impactparameter asc, commodity asc limit 5",
#           'name': 'tabls',
#           'format': {'type': 'json', 'property': 'rows'}},
#          {'name': 'legend',
#           'source': 'tabls',
#           'transform': [{'type': 'aggregate',
#             'groupby': ['t'],
#             'summarize': [{'ops': ['sum'], 'field': 'val'}]}]},
#          {'name': 'separate_line',
#           'values': [{'x': 0, 'y': 0}, {'x': 680, 'y': 0}]}],
#         'marks': [{'from': {'data': 'tabls',
#            'transform': [{'type': 'facet', 'groupby': ['commodity']}]},
#           'type': 'group',
#           'marks': [{'from': {'transform': [{'expr': "format('.3s', datum.val)",
#                'type': 'formula',
#                'field': 'capitalize'}]},
#             'name': 'bars',
#             'type': 'rect',
#             'properties': {'enter': {'x': {'field': 'val', 'scale': 'val'},
#               'y': {'offset': -8},
#               'x2': {'scale': 'val', 'value': 0},
#               'fill': {'field': 'commodity', 'scale': 'color'},
#               'height': {'band': True, 'value': 20},
#               'stroke': {'value': '#fff'},
#               'padding': 5,
#               'stroke_width': {'value': 2}},
#              'update': {'fill_opacity': {'value': 1}}}},
#            {'from': {'mark': 'bars'},
#             'type': 'text',
#             'properties': {'enter': {'x': {'field': 'x2', 'offset': 5},
#               'y': {'field': 'y'},
#               'dy': {'mult': 0.55, 'field': 'height'},
#               'fill': {'value': '#758290'},
#               'text': {'field': 'datum.capitalize'},
#               'align': {'value': 'left'},
#               'baseline': {'value': 'middle'},
#               'font_size': {'value': 12}}},
#             'interactive': False}],
#           'scales': [{'name': 'pos',
#             'type': 'ordinal',
#             'range': 'height',
#             'domain': {'field': 'val'}}],
#           'properties': {'enter': {'y': {'field': 'key', 'scale': 'cat'},
#             'height': {'band': True, 'scale': 'cat'}},
#            'hover': {'text_fill': {'value': '#758290'}}}},
#          {'from': {'data': 'separate_line'},
#           'type': 'line',
#           'properties': {'enter': {'x': {'field': 'x', 'offset': -120},
#             'y': {'field': 'y', 'offset': 235},
#             'stroke': {'value': '#eee'},
#             'stroke_width': {'value': 1}}}}],
#         'width': 480,
#         'height': 200,
#         'scales': [{'name': 'cat',
#           'nice': True,
#           'type': 'ordinal',
#           'range': 'height',
#           'domain': {'data': 'tabls', 'field': 'commodity'},
#           'padding': 0.5},
#          {'name': 'val',
#           'nice': True,
#           'type': 'linear',
#           'range': 'width',
#           'round': True,
#           'domain': {'data': 'tabls', 'field': 'val'}},
#          {'name': 'color',
#           'nice': True,
#           'type': 'ordinal',
#           'range': ['#3d6ac4', '#749be9', '#51d4f0', '#b1f3b7'],
#           'domain': {'data': 'legend', 'field': 't'}},
#          {'name': 'legend-series-x',
#           'nice': True,
#           'type': 'ordinal',
#           'range': [32, 270],
#           'domain': {'data': 'legend', 'field': 't'}},
#          {'name': 'legend-series-y',
#           'nice': True,
#           'type': 'ordinal',
#           'range': [-170],
#           'domain': {'data': 'legend', 'field': 't'}}],
#         'padding': {'top': 15, 'left': 100, 'right': 80, 'bottom': 35},
#         'sql_config': [{'key': 'where',
#           'key_params': [{'key': 'year', 'required': True}]}],
#         'params_config': [{'key': 'iso', 'required': True},
#          {'key': 'year', 'required': True}],
#         'titleConfig': {'baseline': 'World prices for major commodity crops',
#          'future': 'Projected world prices for major commodity crops'},
#         'interaction_config': [{'name': 'tooltip',
#           'config': {'fields': [{'key': 'commodity', 'label': 'Crop'},
#             {'key': 'val',
#              'label': 'Price',
#              'format': '.3s',
#              'suffix': ' usd/ton'}]}}]},
#        'template': False,
#        'layerId': None,
#        'createdAt': '2017-03-03T12:38:04.477Z',
#        'updatedAt': '2019-11-14T08:56:26.467Z'}}],
#     'layer': [],
#     'vocabulary': [{'type': 'vocabulary',
#       'attributes': {'resource': {'id': 'c4ee894f-2a9f-4681-9c3d-d94cf106f796',
#         'type': 'dataset'},
#        'tags': ['global,all_crops', 'global', 'all_crops'],
#        'name': 'legacy',
#        'application': 'aqueduct'}}],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}},
#   {'id': '134caa0a-21f7-451d-a7fe-30db31a424aa',
#    'type': 'dataset',
#    'attributes': {'name': 'Political boundaries (GADM)',
#     'slug': 'Country-geometries-1490086842548',
#     'type': 'tabular',
#     'subtitle': None,
#     'application': ['gfw',
#      'data4sdgs',
#      'aqueduct',
#      'forest-atlas',
#      'gfw-climate'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/gadm28_countries/public',
#     'sources': [],
#     'tableName': 'gadm28_countries',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': True,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2017-01-17T10:18:35.729Z',
#     'updatedAt': '2017-11-10T21:47:04.345Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5888ab163d81e10b00e6a5ae',
#       'type': 'metadata',
#       'attributes': {'dataset': '134caa0a-21f7-451d-a7fe-30db31a424aa',
#        'application': 'aqueduct',
#        'resource': {'id': '134caa0a-21f7-451d-a7fe-30db31a424aa',
#         'type': 'dataset'},
#        'language': 'en',
#        'name': 'Country geometries',
#        'description': "GADM is a spatial database of the location of the world's administrative areas (or adminstrative boundaries) for use in GIS and similar software. Administrative areas in this database are countries and lower level subdivisions such as provinces, departments, counties, etc. GADM describes where these administrative areas are (the spatial features), and for each area it provides some attributes, such as the name and variant names.",
#        'source': 'https://www.gadm.org',
#        'citation': '',
#        'license': '',
#        'info': {'organization': 'WRI'},
#        'createdAt': '2017-01-25T13:41:42.621Z',
#        'updatedAt': '2017-01-25T13:41:42.621Z',
#        'status': 'published'}}],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': ['the_geom', 'the_geom_webmercator', 'iso']}},
#   {'id': '098b33df-6871-4e53-a5ff-b56a7d989f9a',
#    'type': 'dataset',
#    'attributes': {'name': 'Subnational Political Boundaries',
#     'slug': 'Politcial-Boundaries-GADM-adminitrative-level-1-1490086842541',
#     'type': 'tabular',
#     'subtitle': 'GADM',
#     'application': ['aqueduct',
#      'gfw',
#      'rw',
#      'forest-atlas',
#      'data4sdgs',
#      'gfw-climate'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/gadm28_adm1/public',
#     'sources': [],
#     'tableName': 'gadm28_adm1',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'subscribable': {},
#     'mainDateField': None,
#     'env': 'production',
#     'applicationConfig': {'rw': {'layerOrder': ['e1dc5626-c1c2-4d60-a6a9-746a33fe1cb7',
#        'f090245b-1b8f-414d-a3ac-6498db3b354b']}},
#     'geoInfo': True,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2017-03-09T09:33:38.866Z',
#     'updatedAt': '2019-09-04T10:15:25.558Z',
#     'dataLastUpdated': None,
#     'metadata': [],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': ['the_geom', 'the_geom_webmercator']}},
#   {'id': 'cbd0d0f8-edf9-47bc-93ef-71c1a5e5fed7',
#    'type': 'dataset',
#    'attributes': {'name': 'Groundwater decline trend',
#     'slug': 'Groundwater-decline-trend',
#     'type': None,
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '58333dcfd9f39b189ca44c75',
#     'connectorUrl': 'https://wri-rw.carto.com/api/v2/sql?q=SELECT * FROM water_risk_indicators_v3',
#     'sources': [],
#     'tableName': 'water_risk_indicators_v3',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': False,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2017-08-02T07:59:47.977Z',
#     'updatedAt': '2017-08-02T07:59:47.977Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5a2135cefe593400133f79f5',
#       'type': 'metadata',
#       'attributes': {'dataset': 'cbd0d0f8-edf9-47bc-93ef-71c1a5e5fed7',
#        'application': 'aqueduct',
#        'resource': {'id': 'cbd0d0f8-edf9-47bc-93ef-71c1a5e5fed7',
#         'type': 'dataset'},
#        'language': 'en',
#        'name': 'Water Risk - Groundwater table declining trend',
#        'description': 'Measures trends in the decline of the groundwater table. The slope of the decline correlates to the severity of the trend. Baseline values are generated using hydrological modeling from 1990 to 2014.',
#        'source': 'WRI Aqueduct 2018 (forthcoming)',
#        'info': {'sources': [{'source-url': '',
#           'source-name': 'WRI Aqueduct 2018 (forthcoming)'}]},
#        'createdAt': '2017-12-01T10:58:22.381Z',
#        'updatedAt': '2017-12-18T17:59:41.306Z',
#        'status': 'published'}}],
#     'widget': [],
#     'layer': [{'id': '1c825957-f34f-4f49-8c19-20c952722ba9',
#       'type': 'layer',
#       'attributes': {'name': 'Water Risk - Groundwater table declining trend',
#        'slug': 'groundwater-decline-trend',
#        'dataset': 'cbd0d0f8-edf9-47bc-93ef-71c1a5e5fed7',
#        'description': 'Groundwater decline trend',
#        'application': ['aqueduct'],
#        'iso': [''],
#        'provider': 'cartodb',
#        'userId': '58333dcfd9f39b189ca44c75',
#        'default': True,
#        'protected': False,
#        'published': True,
#        'env': 'production',
#        'layerConfig': {'account': 'wri-rw',
#         'params_config': [],
#         'sql_config': [{'key': 'where',
#           'key_params': [{'key': 'iso', 'required': False},
#            {'key': 'crop', 'required': False},
#            {'key': 'irrigation', 'required': False}]}],
#         'body': {'maxzoom': 18,
#          'minzoom': 3,
#          'layers': [{'type': 'cartodb',
#            'options': {'sql': "with r as (SELECT basinid, value, label, aqid FROM water_risk_indicators_v3 where indicator='groundwater_decline_trend') SELECT r.aqid, value, label, the_geom_webmercator from r inner join wri_subcatchements_v3 on r.aqid=wri_subcatchements_v3.aqid",
#             'cartocss': '#water_risk_indicators_v3[value>0.8] {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;polygon-fill: #ff0c19; line-color: #FF1900;} #water_risk_indicators_v3[value<0.8] {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;polygon-fill: #FF9900; line-color: #FF9900;} #water_risk_indicators_v3[value<0.2] {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;polygon-fill: #FFE600; line-color: #FFE600;}#water_risk_indicators_v3[value<=0] {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;polygon-fill: #f4f4f1; line-color: #f4f4f1;} #water_risk_indicators_v3[value<-999] {polygon-opacity: 0; line-width: 05; line-opacity: 0;polygon-fill: transparent; line-color: transparent;}',
#             'cartocss_version': '2.3.0'}},
#           {'type': 'cartodb',
#            'options': {'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}',
#             'cartocss': '#layer {polygon-fill: #eee; polygon-opacity: 1; line-color: #eee; line-width: 1; line-opacity: 1; comp-op: dst-in;}',
#             'cartocss_version': '2.3.0'}}]}},
#        'legendConfig': {'items': [{'color': '#f4f4f1',
#           'value': '<0 cm/yr',
#           'name': 'No Depletion'},
#          {'color': '#FFE600', 'value': '0-2 cm/yr', 'name': 'Low Depletion'},
#          {'color': '#FF9900',
#           'value': '2-8 cm/yr',
#           'name': 'Moderate Depletion'},
#          {'color': '#FF1900', 'value': '>8 cm/yr', 'name': 'High Depletion'}],
#         'type': 'choropleth'},
#        'interactionConfig': {},
#        'applicationConfig': {},
#        'staticImageConfig': {},
#        'createdAt': '2017-08-02T08:54:05.820Z',
#        'updatedAt': '2018-01-19T09:23:34.146Z'}}],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}},
#   {'id': 'd69adfa5-2087-458d-8f8f-388c888ed8ab',
#    'type': 'dataset',
#    'attributes': {'name': 'Growing single crop under high water stress conditions.',
#     'slug': 'Growing-single-crop-under-high-water-stress-conditions-1490086842548',
#     'type': None,
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '58333dcfd9f39b189ca44c75',
#     'connectorUrl': 'https://wri-01.carto.com/tables/aqueduct_projections_20150309/public',
#     'sources': [],
#     'tableName': 'aqueduct_projections_20150309',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': False,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2016-12-19T12:46:20.690Z',
#     'updatedAt': '2017-01-31T15:27:52.828Z',
#     'dataLastUpdated': None,
#     'metadata': [],
#     'widget': [{'id': '641970f9-84da-4560-a715-ad4f70a3b8f4',
#       'type': 'widget',
#       'attributes': {'name': 'Single growing crop under high water stress conditions',
#        'dataset': 'd69adfa5-2087-458d-8f8f-388c888ed8ab',
#        'slug': 'single-growing-crop-under-high-water-stress-conditions',
#        'userId': '5858f37140621f11066fb2f7',
#        'description': '',
#        'source': '',
#        'sourceUrl': '',
#        'authors': '',
#        'application': ['aqueduct'],
#        'verified': False,
#        'default': False,
#        'protected': False,
#        'defaultEditableWidget': False,
#        'published': True,
#        'thumbnailUrl': 'http://wri-api-backups.s3.amazonaws.com/resourcewatch/staging/thumbnails/641970f9-84da-4560-a715-ad4f70a3b8f4-1573122568444.png',
#        'freeze': False,
#        'env': 'production',
#        'queryUrl': 'query/d69adfa5-2087-458d-8f8f-388c888ed8ab?sql=select * from aqueduct_projections_20150309 limit 100',
#        'widgetConfig': {'template_config': [{'key': 'verb'},
#          {'format': '.2s', 'key': 'value'},
#          {'key': 'commodity'},
#          {'key': 'year'}],
#         'params_config': [{'required': True, 'key': 'year'},
#          {'required': True, 'key': 'crop'}],
#         'template_baseline': 'There ##verb## ##value## hectares of irrigated ##commodity## growing under high and extremely high water stress conditions.',
#         'template_future': 'There ##verb## ##value## hectares of irrigated ##commodity## growing under high and extremely high water stress conditions in ##year##.',
#         'type': 'text',
#         'data': {'url': "https://wri-rw.carto.com/api/v2/sql?q=SELECT year::text, crop as commodity, sum(area) as value, CASE WHEN year > 2010 then 'will be' ELSE 'are' END AS verb FROM crops_risk_stats WHERE crop = '{{crop}}' and irrigation = 'irrigated' and indicator = 'water_stress' and year = {{year}} and initcap(split_part(risk, ' (', 1)) IN ( 'High', 'Extremely High', 'Extremely High') GROUP BY crop, year"}},
#        'template': False,
#        'layerId': None,
#        'createdAt': '2016-12-19T12:58:47.689Z',
#        'updatedAt': '2019-11-07T10:29:28.402Z'}},
#      {'id': '809d863c-803e-4392-a6d1-921de3570d2d',
#       'type': 'widget',
#       'attributes': {'name': 'Single growing crop under high water stress conditions - 1543576375138',
#        'dataset': 'd69adfa5-2087-458d-8f8f-388c888ed8ab',
#        'slug': 'Single-growing-crop-under-high-water-stress-conditions-1543576375138',
#        'userId': '57ac9f9e29309063404573a2',
#        'description': '',
#        'source': '',
#        'sourceUrl': '',
#        'authors': '',
#        'application': ['aqueduct'],
#        'verified': False,
#        'default': False,
#        'protected': False,
#        'defaultEditableWidget': False,
#        'published': True,
#        'freeze': False,
#        'env': 'production',
#        'queryUrl': 'query/d69adfa5-2087-458d-8f8f-388c888ed8ab?sql=select * from aqueduct_projections_20150309 limit 100',
#        'widgetConfig': {'data': {'url': "https://wri-rw.carto.com/api/v2/sql?q=with a as(SELECT area, basinid, cell5m, crop FROM crops {{where}} and irrigation='irrigated'), b as (SELECT basinid, ws2028tl, ws3028tl, ws4028tl, wsbs00tl FROM all_crops_stats {{where}} and irrigation='irrigated'), agrr as (select a.basinid, a.crop, b.ws2028tl, b.ws3028tl, b.ws4028tl, b.wsbs00tl, a.area as area_a from a,b where a.basinid=b.basinid), y_2010 as (select crop as commodity, sum(area_a) as area_a from agrr where wsbs00tl IN ('4.Mid-High', '5.High', '6.Extremely high') group by crop), y_2020 as (select crop as commodity, sum(area_a) as area_a from agrr where ws2028tl IN ('4.Mid-High', '5.High', '6.Extremely high') group by crop), y_2030 as (select crop as commodity, sum(area_a) as area_a from agrr where ws3028tl IN ('4.Mid-High', '5.High', '6.Extremely high') group by crop), y_2040 as (select crop as commodity, sum(area_a) as area_a from agrr where ws4028tl IN ('4.Mid-High', '5.High', '6.Extremely high') group by crop), result as (select commodity, area_a as value, 2010 as year from y_2010 union all select commodity, area_a as value, 2020 as year from y_2020 union all select commodity, area_a as value, 2030 as year from y_2030 union all select commodity, area_a as value, 2040 as year from y_2040), final_res as (select year, commodity, value from result where year={{year}}) SELECT case when year > 2010 then 'will be' else 'are' end as verb, case when year > 2010 then 'in ' || to_char(year, '9999') else '' end as year, commodity, value from final_res"},
#         'type': 'text',
#         'template': 'There ##verb## ##value## hectares of irrigated ##commodity## growing under high water stress conditions ##year##.',
#         'sql_config': [{'key': 'where',
#           'key_params': [{'key': 'crop', 'required': True}]}],
#         'params_config': [{'key': 'year', 'required': True},
#          {'key': 'commodity', 'required': True}],
#         'template_config': [{'key': 'verb'},
#          {'key': 'value', 'format': '.2s'},
#          {'key': 'commodity'},
#          {'key': 'year'}]},
#        'template': False,
#        'layerId': None,
#        'createdAt': '2018-11-30T11:12:55.159Z',
#        'updatedAt': '2018-11-30T11:12:55.159Z'}}],
#     'layer': [],
#     'vocabulary': [{'type': 'vocabulary',
#       'attributes': {'resource': {'id': 'd69adfa5-2087-458d-8f8f-388c888ed8ab',
#         'type': 'dataset'},
#        'tags': ['global', 'one_crops', 'global,one_crop', 'one_crop'],
#        'name': 'legacy',
#        'application': 'aqueduct'}}],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}},
#   {'id': '9c450642-f976-40eb-96b4-0c904d519578',
#    'type': 'dataset',
#    'attributes': {'name': 'Drought Severity Soil Moisture',
#     'slug': 'Drought-Severity-Soil-Moisture',
#     'type': None,
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '58333dcfd9f39b189ca44c75',
#     'connectorUrl': 'https://wri-rw.carto.com/api/v2/sql?q=SELECT * FROM water_risk_indicators_v3',
#     'sources': [],
#     'tableName': 'water_risk_indicators_v3',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': False,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2017-08-02T11:06:21.665Z',
#     'updatedAt': '2017-08-02T11:06:21.665Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5a21358bfe593400133f79f4',
#       'type': 'metadata',
#       'attributes': {'dataset': '9c450642-f976-40eb-96b4-0c904d519578',
#        'application': 'aqueduct',
#        'resource': {'id': '9c450642-f976-40eb-96b4-0c904d519578',
#         'type': 'dataset'},
#        'language': 'en',
#        'name': 'Water Risk - Drought severity (soil moisture)',
#        'description': 'Estimates the average magnitude of droughts based on the severity and frequency of periods of time during which soil moisture remains low. Baseline values are generated using hydrological modeling of long-term trends from 1960 to 2014.',
#        'source': 'WRI Aqueduct 2018 (forthcoming)',
#        'info': {'sources': [{'source-url': '',
#           'source-name': 'WRI Aqueduct 2018 (forthcoming)'}]},
#        'createdAt': '2017-12-01T10:57:15.343Z',
#        'updatedAt': '2017-12-18T18:00:05.663Z',
#        'status': 'published'}}],
#     'widget': [],
#     'layer': [{'id': '39c5649f-aaf7-4d32-9493-26441d8f80f0',
#       'type': 'layer',
#       'attributes': {'name': 'Water Risk - Drought severity (soil moisture)',
#        'slug': 'drought-severity-soil-moisture',
#        'dataset': '9c450642-f976-40eb-96b4-0c904d519578',
#        'description': 'Drought Severity Soil Moisture',
#        'application': ['aqueduct'],
#        'iso': [''],
#        'provider': 'cartodb',
#        'userId': '58333dcfd9f39b189ca44c75',
#        'default': True,
#        'protected': False,
#        'published': True,
#        'env': 'production',
#        'layerConfig': {'body': {'layers': [{'options': {'raster_band': 1,
#             'geom_type': 'raster',
#             'geom_column': 'the_raster_webmercator',
#             'cartocss_version': '2.3.0',
#             'cartocss': '#drought_severity_soil_historic_year_2014 {raster-opacity:1; raster-colorizer-default-mode: discrete; raster-colorizer-default-color: transparent; raster-colorizer-epsilon: 0.01; raster-colorizer-stops: stop(0, #808080) stop(0.01, #FFFF99) stop(1, #FFFF99) stop(2, #FFE600) stop(3, #FF9900) stop(4, #FF1900) stop(5, #990000)}',
#             'sql': 'SELECT * FROM rought_severity_soil_historic_year_2014'},
#            'type': 'cartodb'},
#           {'options': {'cartocss_version': '2.3.0',
#             'cartocss': '#layer {polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}',
#             'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'},
#            'type': 'cartodb'}],
#          'minzoom': 3,
#          'maxzoom': 18},
#         'sql_config': [{'key_params': [{'required': False, 'key': 'iso'},
#            {'required': False, 'key': 'crop'},
#            {'required': False, 'key': 'irrigation'}],
#           'key': 'where'}],
#         'params_config': [],
#         'account': 'wri-rw'},
#        'legendConfig': {'disclaimer': [{'color': '#808080',
#           'name': 'Arid and low water use'}],
#         'items': [{'color': '#FFFF99', 'value': '<0.1', 'name': 'Low'},
#          {'color': '#FFE600', 'value': '0.1-0.25', 'name': 'Moderate'},
#          {'color': '#FF9900', 'value': '0.25-0.50', 'name': 'Mid'},
#          {'color': '#FF1900', 'value': '0.5-0.75', 'name': 'Severe'},
#          {'color': '#990000', 'value': '>0.75', 'name': 'Extremely severe'}],
#         'type': 'choropleth'},
#        'interactionConfig': {},
#        'applicationConfig': {},
#        'staticImageConfig': {},
#        'createdAt': '2017-08-02T11:17:34.292Z',
#        'updatedAt': '2018-01-19T09:23:57.410Z'}}],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}},
#   {'id': 'dcc870ef-6137-470c-8bfd-22a9060729fb',
#    'type': 'dataset',
#    'attributes': {'name': 'Seasonal variability change over time for rainfed crops',
#     'slug': 'Seasonal-variability-change-over-time-for-rainfed-crops',
#     'type': None,
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/crops/public',
#     'sources': [],
#     'tableName': 'crops',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': False,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2017-03-31T09:57:12.864Z',
#     'updatedAt': '2017-03-31T09:57:13.195Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5a214174fe593400133f79f9',
#       'type': 'metadata',
#       'attributes': {'dataset': 'dcc870ef-6137-470c-8bfd-22a9060729fb',
#        'application': 'aqueduct',
#        'resource': {'id': 'dcc870ef-6137-470c-8bfd-22a9060729fb',
#         'type': 'dataset'},
#        'language': 'en',
#        'name': 'Average global change in seasonal variability for rainfed crops through 2040',
#        'description': 'This figure displays the average seasonal variability score (0-5) of water in areas in which selected crops are grown. This only includes rainfed growing areas.',
#        'info': {'sources': [{'source-url': 'https://www.wri.org/publication/aqueduct-water-stress-projections-decadal-projections-water-supply-and-demand-using',
#           'source-name': 'WRI Aqueduct 2015'},
#          {'source-url': 'https://www.wri.org/publication/aqueduct-30',
#           'source-name': 'WRI Aqueduct 2019'},
#          {'source-url': 'http://mapspam.info/',
#           'source-name': 'MapSPAM 2010'}]},
#        'createdAt': '2017-12-01T11:48:04.276Z',
#        'updatedAt': '2019-11-14T08:47:12.392Z',
#        'status': 'published'}}],
#     'widget': [{'id': 'abf5c0f9-4042-4ea6-9582-1b34209cb4ba',
#       'type': 'widget',
#       'attributes': {'name': 'Average global change in seasonal variability for rainfed crops through 2040',
#        'dataset': 'dcc870ef-6137-470c-8bfd-22a9060729fb',
#        'slug': 'seasonal-variability-change-over-time-for-rainfed-crops',
#        'userId': '5858f37140621f11066fb2f7',
#        'description': None,
#        'source': None,
#        'sourceUrl': None,
#        'authors': None,
#        'application': ['aqueduct'],
#        'verified': False,
#        'default': True,
#        'protected': False,
#        'defaultEditableWidget': False,
#        'published': True,
#        'thumbnailUrl': 'http://wri-api-backups.s3.amazonaws.com/resourcewatch/staging/thumbnails/abf5c0f9-4042-4ea6-9582-1b34209cb4ba-1573554228469.png',
#        'freeze': False,
#        'env': 'production',
#        'queryUrl': 'query/dcc870ef-6137-470c-8bfd-22a9060729fb?sql=select * from crops',
#        'widgetConfig': {'axes': [{'type': 'x',
#           'scale': 'x',
#           'ticks': {'value': 0}},
#          {'grid': True,
#           'type': 'y',
#           'layer': 'back',
#           'title': 'Seasonal Variability',
#           'scale': 'y',
#           'properties': {'title': {'fill': {'value': '#758290'},
#             'x': {'value': -45}},
#            'grid': {'stroke': {'value': '#eeeeee'},
#             'strokeWidth': {'value': 1}},
#            'labels': {'align': {'value': 'center'},
#             'baseline': {'value': 'bottom'}}},
#           'tickSizeEnd': 0}],
#         'data': [{'url': "https://wri-rw.carto.com/api/v2/sql?q=with alpha as (SELECT crop, year, value FROM crops_risk_rankings WHERE indicator='seasonal_variability' and irrigation='rainfed' ORDER BY year asc), betha as (SELECT value, year, CASE when crop IN ('barley','maize','small millet', 'pearl millet','rice','sorghum','wheat','other cereals') then 'Cereals' when crop IN ('bean', 'cowpea', 'chickpea', 'pigeonpea', 'lentil', 'other pulses') then 'Pulses and legumes' when crop IN ('cassava','potato','sweet potato','yams', 'other roots') then 'Roots and tubers' when crop IN ('banana','plantain', 'tropical fruit', 'temperate fruit') then 'Fruit and nuts' when crop IN ('soybean', 'groundnut', 'coconut', 'oilpalm', 'sunflower', 'rapeseed', 'sesameseed', 'other oil crops') then 'Oilseed crops'  when crop IN ('sugarcane', 'sugarbeet') then 'Sugar crops' when crop IN ('cotton', 'other fibre crops') then 'Fibres'  when crop IN ('arabica coffee', 'robusta coffee', 'cocoa', 'tea', 'tobacco') then 'Stimulants'  when crop IN ('vegetables') then 'Vegetables' when crop IN ('rest of crops') then 'Other crops' END as grupo FROM alpha ORDER BY year asc, grupo) SELECT avg(value) as water_risk, year, grupo as cat FROM betha WHERE grupo is not null and year in (2014, 2030, 2040) GROUP BY grupo, year ORDER BY year, CASE grupo WHEN 'Cereals' THEN 1 WHEN 'Pulses and legumes' THEN 2 WHEN 'Roots and tubers' THEN 3 WHEN 'Fruit and nuts' THEN 4 WHEN 'Oilseed crops' THEN 5 WHEN 'Sugar crops' THEN 6 WHEN 'Fibres' THEN 7 WHEN 'Stimulants' THEN 8 WHEN 'Vegetables' THEN 9 WHEN 'Other crops' THEN 10ELSE 11 END",
#           'name': 'tables',
#           'format': {'type': 'json', 'property': 'rows'}},
#          {'name': 'axis',
#           'source': 'tables',
#           'transform': [{'type': 'aggregate', 'groupby': 'year'}]},
#          {'values': [{'x2': 2014, 'y': 'baseline', 'x': 2014},
#            {'x2': 2030, 'y': '2030', 'x': 2030},
#            {'x2': 2040, 'y': '2040', 'x': 2040}],
#           'name': 'axis-x'},
#          {'name': 'legend',
#           'source': 'tables',
#           'transform': [{'type': 'aggregate',
#             'groupby': ['cat'],
#             'summarize': [{'as': ['counts'],
#               'ops': ['count'],
#               'field': 'year'}]},
#            {'type': 'rank'},
#            {'expr': '(datum.rank - 1) % 3',
#             'type': 'formula',
#             'field': 'xPos'},
#            {'expr': 'floor(datum.rank / 3.1) * 20',
#             'type': 'formula',
#             'field': 'yPos'}]}],
#         'marks': [{'from': {'data': 'legend'},
#           'type': 'text',
#           'properties': {'enter': {'x': {'field': 'xPos',
#              'scale': 'legend-series-x',
#              'offset': -70},
#             'y': {'field': 'yPos', 'offset': 200},
#             'fill': {'value': 'grey'},
#             'text': {'field': 'cat'}}}},
#          {'from': {'data': 'legend'},
#           'type': 'symbol',
#           'properties': {'enter': {'x': {'field': 'xPos',
#              'scale': 'legend-series-x',
#              'offset': -80},
#             'y': {'field': 'yPos', 'offset': 196},
#             'fill': {'field': 'cat', 'scale': 'color'},
#             'text': {'field': 'cat', 'scale': 'color'},
#             'shape': {'value': 'square'}}}},
#          {'from': {'data': 'tables',
#            'transform': [{'type': 'facet', 'groupby': ['cat']}]},
#           'type': 'group',
#           'marks': [{'type': 'line',
#             'properties': {'enter': {'x': {'field': 'year', 'scale': 'x'},
#               'y': {'field': 'water_risk', 'scale': 'y'},
#               'stroke': {'field': 'cat', 'scale': 'color'},
#               'strokeWidth': {'value': '2'}}}}]},
#          {'interactive': False,
#           'properties': {'update': {'font_size': {'value': 12},
#             'angle': {'value': 0},
#             'align': {'value': 'center'},
#             'text': {'template': '{{datum.y | slice:0,1 |upper}}{{datum.y | slice:1,100, datum.crop}}'},
#             'fill': {'value': '#758290'},
#             'y': {'offset': 18, 'value': 0, 'scale': 'y'},
#             'x': {'offset': 0, 'scale': 'x', 'field': 'x2'}}},
#           'type': 'text',
#           'name': 'label',
#           'from': {'data': 'axis-x'}}],
#         'height': 140,
#         'scales': [{'name': 'x',
#           'nice': 'year',
#           'type': 'linear',
#           'zero': False,
#           'range': 'width',
#           'domain': {'data': 'tables', 'field': 'year'}},
#          {'name': 'y',
#           'type': 'linear',
#           'range': [150, 0],
#           'domain': {'data': 'tables', 'field': 'water_risk'}},
#          {'name': 'color',
#           'type': 'ordinal',
#           'range': 'cropCatColor',
#           'domain': {'fields': [{'data': 'legend', 'field': 'cat'}]}},
#          {'name': 'legend-series-x',
#           'type': 'ordinal',
#           'range': 'width',
#           'domain': [0, 1, 2],
#           'points': True,
#           'padding': 1},
#          {'name': 'legend-series-y',
#           'type': 'ordinal',
#           'range': [-170, -170, -170, -170],
#           'domain': {'data': 'legend', 'field': 'cat'}}],
#         'padding': {'top': 22, 'left': 80, 'right': 40, 'bottom': 125},
#         'signals': [{'name': 'onMousemove',
#           'streams': [{'expr': "{ xval: +iscale('x', eventX()), yval: +iscale('y', eventY())}",
#             'type': 'mousemove'}]}],
#         'interaction_config': [{'name': 'tooltip',
#           'type': 'signal',
#           'config': {'table': {'from': 'tables',
#             'title': {'key': 'year', 'parse': {}},
#             'bisect': 'year',
#             'columns': [{'key': 'cat', 'parse': {}},
#              {'key': 'water_risk', 'parse': {'format': '.2f'}}],
#             'headers': ['Category', 'Seasonal Variability']}}}]},
#        'template': False,
#        'layerId': None,
#        'createdAt': '2017-03-31T10:51:57.369Z',
#        'updatedAt': '2019-11-12T10:23:48.314Z'}}],
#     'layer': [],
#     'vocabulary': [{'type': 'vocabulary',
#       'attributes': {'resource': {'id': 'dcc870ef-6137-470c-8bfd-22a9060729fb',
#         'type': 'dataset'},
#        'tags': ['global', 'all_crops'],
#        'name': 'legacy',
#        'application': 'aqueduct'}}],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}},
#   {'id': '5be16fea-5b1a-4daf-a9e9-9dc1f6ea6d4e',
#    'type': 'dataset',
#    'attributes': {'name': 'Global water stress',
#     'slug': 'Global-water-stress-1490086842547',
#     'type': 'tabular',
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '58333dcfd9f39b189ca44c75',
#     'connectorUrl': 'https://wri-01.carto.com/tables/crops/public',
#     'sources': [],
#     'tableName': 'crops',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': True,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2016-12-14T17:36:03.722Z',
#     'updatedAt': '2017-10-20T09:09:18.067Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5a37f16417f51700112b78c3',
#       'type': 'metadata',
#       'attributes': {'dataset': '5be16fea-5b1a-4daf-a9e9-9dc1f6ea6d4e',
#        'application': 'aqueduct',
#        'resource': {'id': '5be16fea-5b1a-4daf-a9e9-9dc1f6ea6d4e',
#         'type': 'dataset'},
#        'language': 'en',
#        'name': 'Projected percentage of crop area by level of water stress and volume of demand',
#        'description': 'This figure displays the percent of all irrigated crop area facing each level of water stress (vertical axis) and the volume of the demand (width of bars) for maize, rice, soybean, and wheat for the year selected.',
#        'info': {'sources': [{'source-url': 'https://www.wri.org/publication/aqueduct-water-stress-projections-decadal-projections-water-supply-and-demand-using',
#           'source-name': 'WRI Aqueduct 2015'},
#          {'source-url': 'https://www.wri.org/publication/aqueduct-30',
#           'source-name': 'WRI Aqueduct 2019'},
#          {'source-url': 'https://www.ifpri.org/program/impact-model',
#           'source-name': 'IFPRI IMPACT Model 2015'},
#          {'source-url': 'http://mapspam.info/',
#           'source-name': 'MapSPAM 2010'}]},
#        'columns': {},
#        'createdAt': '2017-12-18T16:48:36.673Z',
#        'updatedAt': '2019-11-14T09:57:13.763Z',
#        'status': 'published'}}],
#     'widget': [{'id': '7b29a2a5-515a-4e22-846f-03ad3d2c0a13',
#       'type': 'widget',
#       'attributes': {'name': 'Percentage of crop area by level of water stress and household demand',
#        'dataset': '5be16fea-5b1a-4daf-a9e9-9dc1f6ea6d4e',
#        'slug': 'widget-default',
#        'userId': '5858f37140621f11066fb2f7',
#        'description': '',
#        'source': '',
#        'sourceUrl': '',
#        'authors': '',
#        'application': ['aqueduct'],
#        'verified': False,
#        'default': False,
#        'protected': False,
#        'defaultEditableWidget': False,
#        'published': True,
#        'thumbnailUrl': 'http://wri-api-backups.s3.amazonaws.com/resourcewatch/staging/thumbnails/7b29a2a5-515a-4e22-846f-03ad3d2c0a13-1573725532401.png',
#        'freeze': False,
#        'env': 'production',
#        'queryUrl': 'query/5be16fea-5b1a-4daf-a9e9-9dc1f6ea6d4e?sql=select * from crops limit 100',
#        'widgetConfig': {'interaction_config': [{'config': {'fields': [{'label': 'Crop',
#              'key': 'crop'},
#             {'suffix': '',
#              'format': '.2f',
#              'label': 'Household demand (thousand/mt)',
#              'key': 'value'},
#             {'label': 'Risk', 'key': 'risk'},
#             {'suffix': '%',
#              'format': '.2f',
#              'label': 'Risk percentage',
#              'key': 'area_perc'}]},
#           'name': 'tooltip'}],
#         'params_config': [{'required': True, 'key': 'year'},
#          {'required': True, 'key': 'iso'}],
#         'sql_config': [],
#         'titleConfig': {'baseline': 'Percentage of irrigated crop area by level of water stress and volume of demand',
#          'future': 'Projected percentage of irrigated crop area by level of water stress and volume of demand in {{year}}'},
# ...
#             'y': {'scale': 'legendy'}},
#            'symbols': {'stroke': {'value': 'rgba(255,255,255,0)'},
#             'shape': {'value': 'square'},
#             'size': [{'value': 100}],
#             'x': {'scale': 'legendx'},
#             'y': {'scale': 'legendy'}}}}],
#         'titleConfig': {'future': 'Percentage of Global {{commodity}} Production by Groundwater Table decline',
#          'baseline': 'Projected Percentage of Global {{commodity}} Production by Groundwater Table decline in {{year}}'}},
#        'template': False,
#        'createdAt': '2019-11-15T08:56:00.808Z',
#        'updatedAt': '2019-11-20T13:38:03.647Z'}}],
#     'layer': [],
#     'vocabulary': [{'type': 'vocabulary',
#       'attributes': {'resource': {'id': '66ac87ee-5807-4150-8cdc-6d51d5847d47',
#         'type': 'dataset'},
#        'tags': ['global', 'one_crop'],
#        'name': 'legacy',
#        'application': 'aqueduct'}}],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}},
#   {'id': '19fcbe42-69d7-48fb-a64b-ae1469dd14d3',
#    'type': 'dataset',
#    'attributes': {'name': 'Percentage of country crop production area by groundwater table decline and year',
#     'slug': 'Percentage-of-country-crop-production-area-by-groundwater-table-decline-and-year',
#     'type': None,
#     'subtitle': None,
#     'application': ['aqueduct'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '5dc97303c1fef200109a149a',
#     'connectorUrl': 'https://wri-rw.carto.com/tables/crops_risk_stats/public',
#     'sources': [],
#     'tableName': 'crops_risk_stats',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': False,
#     'protected': False,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': '',
#     'taskId': None,
#     'createdAt': '2019-11-15T09:44:27.696Z',
#     'updatedAt': '2019-11-15T09:44:28.062Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5dd51fbb68b94e00103b7bad',
#       'type': 'metadata',
#       'attributes': {'dataset': '19fcbe42-69d7-48fb-a64b-ae1469dd14d3',
#        'application': 'aqueduct',
#        'resource': {'id': '19fcbe42-69d7-48fb-a64b-ae1469dd14d3',
#         'type': 'dataset'},
#        'language': 'en',
#        'description': 'This figure displays the percentage of crop production by level of groundwater table decline for the timeframe selected.',
#        'info': {'sources': [{'source-url': 'https://www.wri.org/publication/aqueduct-30',
#           'source-name': 'WRI Aqueduct 2019'},
#          {'source-url': 'http://mapspam.info/',
#           'source-name': 'MapSPAM 2010'}]},
#        'createdAt': '2019-11-20T11:12:59.775Z',
#        'updatedAt': '2019-11-20T15:41:19.322Z',
#        'status': 'published'}}],
#     'widget': [{'id': 'b759392b-96be-440f-80f5-c14929aac11b',
#       'type': 'widget',
#       'attributes': {'name': 'Percentage of crop production area by groundwater table decline in {{year}}',
#        'dataset': '19fcbe42-69d7-48fb-a64b-ae1469dd14d3',
#        'slug': 'Percentage-of-crop-production-area-by-groundwater-table-decline-in-year_1',
#        'userId': '5dc97303c1fef200109a149a',
#        'description': '',
#        'source': '',
#        'authors': '',
#        'application': ['aqueduct'],
#        'verified': False,
#        'default': True,
#        'protected': False,
#        'defaultEditableWidget': False,
#        'published': True,
#        'thumbnailUrl': 'http://wri-api-backups.s3.amazonaws.com/resourcewatch/staging/thumbnails/b759392b-96be-440f-80f5-c14929aac11b-1574255588039.png',
#        'freeze': False,
#        'env': 'production',
#        'widgetConfig': {'interaction_config': [{'config': {'fields': [{'suffix': ' Tons',
#              'format': '.2s',
#              'label': 'Crop production',
#              'key': 'perc_value'},
#             {'label': 'Risk', 'key': 'risk'},
#             {'suffix': '',
#              'format': '.1%',
#              'label': 'Risk percentage',
#              'key': 'risk_perc'}]},
#           'name': 'tooltip'}],
#         'padding': {'bottom': 100, 'right': 80, 'left': 130, 'top': 22},
#         'height': 100,
#         'params_config': [{'required': True, 'key': 'year'},
#          {'key': 'iso', 'required': True},
#          {'key': 'crop', 'required': True},
#          {'key': 'countryName', 'required': True}],
#         'data': [{'name': 'stats',
#           'url': "https://wri-rw.carto.com/api/v2/sql?q=with a as (SELECT sum(area) as area_perc, indicator, irrigation, sum(prod) as perc_value, risk FROM crops_risk_stats WHERE year={{year}} and crop='{{crop}}' and iso='{{iso}}' GROUP BY indicator, irrigation, risk ORDER BY indicator, indicator, risk), b as (SELECT initcap(split_part(risk, ' (', 1)) as risk, replace(initcap(indicator), '_', ' ') as indicator, area_perc, perc_value, irrigation FROM a WHERE indicator='groundwater_table_decline' and irrigation='irrigated'), c as (SELECT indicator, area_perc, perc_value, irrigation,   CASE when risk IN ('No Data') then '1.No Data' when risk IN ('Low') then '2.Low' when risk IN ('Low - Medium') then '3.Low-Mid' when risk IN ('Medium - High') then '4.Mid-High' when risk IN ('High') then '5.High' when risk IN ('Extremely High') then '6.Extremely High' when risk IN ('Insignificant Trend') then 'Insignificant Trend' END as risk, CASE when risk IN ('No Data') then -9999 when risk IN ('Low') then 0 when risk IN ('Low - Medium') then 1 when risk IN ('Medium - High') then 2 when risk IN ('High') then 3 when risk IN ('Extremely High') then 4 when risk IN ('Insignificant Trend') then 5 END as value_m FROM b) SELECT indicator, area_perc, perc_value, irrigation, risk, value_m, row_number() over (partition by indicator order by value_m asc) as index  FROM c",
#           'format': {'type': 'json', 'property': 'rows'},
#           'transform': [{'type': 'stack',
#             'field': 'perc_value',
#             'offset': 'normalize',
#             'output': {'end': 'val_e', 'start': 'val_s'},
#             'groupby': ['indicator'],
#             'sortby': ['irrigation', 'indicator', 'index']},
#            {'by': 'risk', 'type': 'sort'},
#            {'expr': 'datum.val_e-datum.val_s',
#             'field': 'risk_perc',
#             'type': 'formula'}]},
#          {'name': 'legend_data',
#           'values': [{'index': 1, 'label': '1.No Data'},
#            {'index': 2, 'label': '2.Low'},
#            {'index': 3, 'label': '3.Low-Mid'},
#            {'index': 4, 'label': '4.Mid-High'},
#            {'index': 5, 'label': '5. High'},
#            {'index': 6, 'label': '6.Extremely High'},
#            {'index': 7, 'label': 'Insignificant Trend'}],
#           'transform': [{'by': 'index', 'type': 'sort'},
#            {'expr': 'length(datum.label)',
#             'field': 'size',
#             'type': 'formula'}]},
#          {'name': 'legend_sum',
#           'source': 'legend_data',
#           'transform': [{'summarize': [{'field': 'size',
#               'ops': ['max'],
#               'as': ['max']},
#              {'field': 'label', 'ops': ['count'], 'as': ['count']}],
#             'type': 'aggregate'}]},
#          {'name': 'legend',
#           'source': 'legend_data',
#           'transform': [{'output': {'right': 'count', 'left': 'label'},
#             'with': 'legend_sum',
#             'diagonal': False,
#             'type': 'cross'},
#            {'expr': 'datum.label.label',
#             'field': 'label_risk',
#             'type': 'formula'},
#            {'expr': 'ceil(datum.count.count/4)',
#             'field': 'x_abs',
#             'type': 'formula'},
#            {'expr': '(datum.label.index-1)%3',
#             'field': 'posx',
#             'type': 'formula'},
#            {'expr': '(ceil(datum.label.index/3))-1',
#             'field': 'posy',
#             'type': 'formula'},
#            {'expr': 'datum.posy*20', 'field': 'pos_y', 'type': 'formula'},
#            {'expr': 'datum.posx*datum.count.max*7',
#             'field': 'pos_x',
#             'type': 'formula'}]}],
#         'signals': [{'name': 'tooltip',
#           'streams': [{'type': 'rect:mouseover', 'expr': 'datum'},
#            {'type': 'rect:mouseout', 'expr': '{}'}]},
#          {'name': 'pos',
#           'init': {'opac': 0},
#           'streams': [{'type': 'rect:mouseover',
#             'expr': '{xval: +eventX(),yval: +eventY(), opac:0.8}'},
#            {'type': 'rect:mouseout', 'expr': '{opac:0}'}]},
#          {'streams': [{'expr': "{ x: iscale('x', eventX()), item: eventItem() }",
#             'type': 'mousemove'}],
#           'name': 'onMousemove'}],
#         'scales': [{'name': 'x',
#           'type': 'linear',
#           'nice': True,
#           'domain': {'data': 'stats', 'field': 'val_e'},
#           'range': 'width'},
#          {'name': 'color',
#           'type': 'ordinal',
#           'range': ['#4E4E4E',
#            '#FFFF99',
#            '#FFE600',
#            '#FF9900',
#            '#FF1900',
#            '#990000',
#            '#808080'],
#           'domain': {'data': 'legend', 'field': 'label_risk'}},
#          {'name': 'xlabels',
#           'type': 'ordinal',
#           'domain': {'fields': [{'data': 'stats', 'field': 'risk'}]},
#           'range': {'fields': [{'data': 'stats', 'field': 'index'}]}},
#          {'reverse': True,
#           'name': 'y_n',
#           'type': 'ordinal',
#           'range': 'height',
#           'domain': {'data': 'stats', 'field': 'indicator'}},
#          {'name': 'legendx',
#           'type': 'ordinal',
#           'domain': {'data': 'legend', 'field': 'label_risk'},
#           'range': {'data': 'legend', 'field': 'pos_x'}},
#          {'name': 'legendy',
#           'type': 'ordinal',
#           'domain': {'data': 'legend', 'field': 'label_risk'},
#           'range': [0, 0, 0, 20, 20, 20, 40, 40, 40]}],
#         'axes': [{'type': 'y',
#           'scale': 'y_n',
#           'titleOffset': 0,
#           'layer': 'front',
#           'grid': False,
#           'tickSize': 1.5,
#           'properties': {'axis': {'stroke': {'value': '#E6E6E6'},
#             'opacity': {'value': 0},
#             'strokeWidth': {'value': 1.5}},
#            'ticks': {'stroke': {'value': '#EEEEEE'},
#             'strokeOpacity': {'value': 1}},
#            'grid': {'stroke': {'value': '#EEEEEE'},
#             'strokeOpacity': {'value': 1}},
#            'labels': {'font': {'value': '"Montserrat", sans-serif'},
#             'fill': {'value': '#9BA2AA'},
#             'fontSize': {'value': 10},
#             'dy': {'value': -10},
#             'baseline': {'value': 'middle'},
#             'align': {'value': 'right'},
#             'angle': {'value': 0},
#             'text': {'template': '{{datum.data}}'}}}},
#          {'type': 'x',
#           'scale': 'x',
#           'titleOffset': 20,
#           'title': '% of production in mt',
#           'layer': 'front',
#           'grid': False,
#           'format': '%',
#           'ticks': 5,
#           'tickSize': 2,
#           'properties': {'axis': {'stroke': {'value': '#E6E6E6'},
#             'opacity': {'value': 1},
#             'strokeWidth': {'value': 1.5}},
#            'ticks': {'stroke': {'value': '#EEEEEE'},
#             'strokeOpacity': {'value': 1}},
#            'labels': {'font': {'value': '"Montserrat", sans-serif'},
#             'fill': {'value': '#9BA2AA'},
#             'fontSize': {'value': 10},
#             'align': {'value': 'center'},
#             'baseline': {'value': 'top'}},
#            'title': {'font': {'value': '"Montserrat", sans-serif'},
#             'fill': {'value': '#9BA2AA'},
#             'fontSize': {'value': 10},
#             'align': {'value': 'right'},
#             'baseline': {'value': 'top'}}}}],
#         'marks': [{'marks': [{'name': 'columns',
#             'type': 'rect',
#             'properties': {'enter': {'x': {'scale': 'x', 'field': 'val_s'},
#               'x2': {'scale': 'x', 'field': 'val_e'},
#               'y': {'scale': 'y', 'field': 'indicator'},
#               'height': {'scale': 'y', 'band': True, 'offset': -10},
#               'fill': {'scale': 'color', 'field': 'risk'},
#               'fillOpacity': {'value': 1}},
#              'update': {'fillOpacity': {'value': 1}},
#              'hover': {'fillOpacity': {'value': 0.5}}}}],
#           'axes': [{'type': 'y',
#             'scale': 'y',
#             'titleOffset': 0,
#             'layer': 'front',
#             'grid': False,
#             'tickSize': 1.5,
#             'properties': {'axis': {'stroke': {'value': '#E6E6E6'},
#               'opacity': {'value': 0},
#               'strokeWidth': {'value': 1.5}},
#              'grid': {'stroke': {'value': '#EEEEEE'},
#               'strokeOpacity': {'value': 1}},
#              'ticks': {'stroke': {'value': '#EEEEEE'},
#               'strokeOpacity': {'value': 1}},
#              'labels': {'font': {'value': '"Montserrat", sans-serif'},
#               'fill': {'value': '#9BA2AA'},
#               'fontSize': {'value': 10},
#               'align': {'value': 'right'},
#               'baseline': {'value': 'bottom'},
#               'dy': {'value': 10},
#               'text': {'template': '{{datum.data}}'}}}}],
#           'scales': [{'name': 'y',
#             'type': 'ordinal',
#             'range': 'height',
#             'domain': {'field': 'irrigation'}}],
#           'properties': {'enter': {'height': {'band': True, 'scale': 'y_n'},
#             'y': {'field': 'key', 'scale': 'y_n'}}},
#           'from': {'transform': [{'groupby': ['indicator'], 'type': 'facet'}],
#            'data': 'stats'},
#           'type': 'group'}],
#         'legends': [{'fill': 'color',
#           'properties': {'legend': {'x': {'field': {'group': 'width'},
#              'mult': 0.01},
#             'y': {'field': {'group': 'height'}, 'mult': 1.5}},
#            'labels': {'fill': {'value': '#9BA2AA'},
#             'baseline': {'value': 'middle'},
#             'text': {'template': '{{datum.data}}'},
#             'x': {'scale': 'legendx', 'offset': 10},
#             'y': {'scale': 'legendy'}},
#            'symbols': {'stroke': {'value': 'rgba(255,255,255,0)'},
#             'shape': {'value': 'square'},
#             'size': [{'value': 100}],
#             'x': {'scale': 'legendx'},
#             'y': {'scale': 'legendy'}}}}],
#         'titleConfig': {'future': 'Projected percentage of {{crop}} production by groundwater table decline in {{countryName}} in {{year}}',
#          'baseline': 'Percentage of {{crop}} production by groundwater table decline in {{countryName}}'}},
#        'template': False,
#        'createdAt': '2019-11-15T09:52:06.468Z',
#        'updatedAt': '2019-11-20T13:13:07.996Z'}}],
#     'layer': [],
#     'vocabulary': [{'type': 'vocabulary',
#       'attributes': {'resource': {'id': '19fcbe42-69d7-48fb-a64b-ae1469dd14d3',
#         'type': 'dataset'},
#        'tags': ['country', 'one_crop'],
#        'name': 'legacy',
#        'application': 'aqueduct'}}],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': []}}],
#  'links': {'self': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&published=true&status=saved&page[number]=1&page[size]=1613982331640',
#   'first': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&published=true&status=saved&page[number]=1&page[size]=1613982331640',
#   'last': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&published=true&status=saved&page[number]=1&page[size]=1613982331640',
#   'prev': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&published=true&status=saved&page[number]=1&page[size]=1613982331640',
#   'next': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&published=true&status=saved&page[number]=1&page[size]=1613982331640'},
#  'meta': {'total-pages': 1, 'total-items': 63, 'size': 1613982331640}}

# %% [markdown]
# ### Clean layers in production

# %%
url = f'{prod_server}/v1/dataset'
payload = {
    'application':'aqueduct',
    'status':'saved',
    'published':'true',
    'includes':'widget,layer,vocabulary,metadata',
    'page[size]':1613982331640
}

prodData = getUrl(url,payload)

#save a backup of production data just in case we need to recreate it again

#with open(f'AQ_prod_backup_{datetime.now().strftime("%Y%m%d-%H%M%S")}.json', 'w') as outfile:
#    json.dump(prodData, outfile)

for dataset in prodData['data']:
    try:
        status = DeleteAssets(f"{prod_server}/v1/dataset/{dataset['id']}")
    except re.exceptions.HTTPError as err:
        pass

# %%
url = f'{prod_server}/v1/dataset'
payload = {
    'application':'aqueduct',
    'status':'saved',
    'published':'true',
    'includes':'widget,layer,vocabulary,metadata',
    'page[size]':1613982331640
}
getUrl(url,payload)
# Out:
# {'data': [{'id': '134caa0a-21f7-451d-a7fe-30db31a424aa',
#    'type': 'dataset',
#    'attributes': {'name': 'Political boundaries (GADM)',
#     'slug': 'Country-geometries-1490086842548',
#     'type': 'tabular',
#     'subtitle': None,
#     'application': ['gfw',
#      'data4sdgs',
#      'aqueduct',
#      'forest-atlas',
#      'gfw-climate'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/gadm28_countries/public',
#     'sources': [],
#     'tableName': 'gadm28_countries',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': True,
#     'protected': True,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2017-01-17T10:18:35.729Z',
#     'updatedAt': '2018-11-21T13:54:56.454Z',
#     'dataLastUpdated': None,
#     'metadata': [{'id': '5888ab163d81e10b00e6a5ae',
#       'type': 'metadata',
#       'attributes': {'dataset': '134caa0a-21f7-451d-a7fe-30db31a424aa',
#        'application': 'aqueduct',
#        'resource': {'id': '134caa0a-21f7-451d-a7fe-30db31a424aa',
#         'type': 'dataset'},
#        'language': 'en',
#        'name': 'Country geometries',
#        'description': "GADM is a spatial database of the location of the world's administrative areas (or adminstrative boundaries) for use in GIS and similar software. Administrative areas in this database are countries and lower level subdivisions such as provinces, departments, counties, etc. GADM describes where these administrative areas are (the spatial features), and for each area it provides some attributes, such as the name and variant names.",
#        'source': 'https://www.gadm.org',
#        'citation': '',
#        'license': '',
#        'info': {'organization': 'WRI'},
#        'createdAt': '2017-01-25T13:41:42.621Z',
#        'updatedAt': '2017-01-25T13:41:42.621Z',
#        'status': 'published'}}],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': ['the_geom', 'the_geom_webmercator', 'iso']}},
#   {'id': 'b3d076cc-b150-4ccb-a93e-eca05d9ac2bf',
#    'type': 'dataset',
#    'attributes': {'name': 'soc.064.02 Political Boundaries (Second Subnational Level)',
#     'slug': 'Politcial-Boundaries-GADM-adminitrative-level-2-1490086842547',
#     'type': 'tabular',
#     'subtitle': 'GADM',
#     'application': ['aqueduct',
#      'gfw',
#      'forest-atlas',
#      'data4sdgs',
#      'gfw-climate'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/gadm28_adm2/public',
#     'sources': [],
#     'tableName': 'gadm28_adm2',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': True,
#     'protected': True,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': None,
#     'taskId': None,
#     'createdAt': '2017-03-13T12:21:47.444Z',
#     'updatedAt': '2018-11-21T13:54:57.848Z',
#     'dataLastUpdated': None,
#     'metadata': [],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': ['the_geom', 'the_geom_webmercator']}},
#   {'id': '8f22dec5-2aea-49d6-8a7b-c494dbb8095c',
#    'type': 'dataset',
#    'attributes': {'name': 'Political boundaries Admin 1 level (GADM 3.6)',
#     'slug': 'Political-boundaries-Admin-1-level-GADM-36',
#     'type': 'tabular',
#     'subtitle': None,
#     'application': ['gfw',
#      'data4sdgs',
#      'aqueduct',
#      'forest-atlas',
#      'gfw-climate'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/gadm36_adm1/public',
#     'sources': [],
#     'tableName': 'gadm36_adm1',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': True,
#     'protected': True,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': '',
#     'taskId': None,
#     'createdAt': '2018-11-21T14:03:02.332Z',
#     'updatedAt': '2018-11-21T14:03:02.332Z',
#     'dataLastUpdated': None,
#     'metadata': [],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': ['the_geom',
#      'the_geom_webmercator',
#      'iso',
#      'gid_1',
#      'name_1']}},
#   {'id': 'a8dc9474-ba42-4ae3-a7d3-d8df5f1e78df',
#    'type': 'dataset',
#    'attributes': {'name': 'Political boundaries (GADM 3.6)',
#     'slug': 'Political-boundaries-GADM-36',
#     'type': 'tabular',
#     'subtitle': None,
#     'application': ['gfw',
#      'data4sdgs',
#      'aqueduct',
#      'forest-atlas',
#      'gfw-climate'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/gadm36_countries/public',
#     'sources': [],
#     'tableName': 'gadm36_countries',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': True,
#     'protected': True,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': '',
#     'taskId': None,
#     'createdAt': '2018-11-21T14:03:02.096Z',
#     'updatedAt': '2018-11-21T14:03:02.096Z',
#     'dataLastUpdated': None,
#     'metadata': [],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': ['the_geom', 'the_geom_webmercator', 'iso']}},
#   {'id': '7cc6ac21-c8ef-4dd8-a181-8967721a15a4',
#    'type': 'dataset',
#    'attributes': {'name': 'Political boundaries Admin 2 level (GADM 3.6)',
#     'slug': 'Political-boundaries-Admin-2-level-GADM-36',
#     'type': 'tabular',
#     'subtitle': None,
#     'application': ['gfw',
#      'data4sdgs',
#      'aqueduct',
#      'forest-atlas',
#      'gfw-climate'],
#     'dataPath': None,
#     'attributesPath': None,
#     'connectorType': 'rest',
#     'provider': 'cartodb',
#     'userId': '57a0aa1071e394dd32ffe137',
#     'connectorUrl': 'https://wri-01.carto.com/tables/gadm36_adm2/public',
#     'sources': [],
#     'tableName': 'gadm36_adm2',
#     'status': 'saved',
#     'published': True,
#     'overwrite': False,
#     'mainDateField': None,
#     'env': 'production',
#     'geoInfo': True,
#     'protected': True,
#     'legend': {'date': [],
#      'region': [],
#      'country': [],
#      'nested': [],
#      'integer': [],
#      'short': [],
#      'byte': [],
#      'double': [],
#      'float': [],
#      'half_float': [],
#      'scaled_float': [],
#      'boolean': [],
#      'binary': [],
#      'text': [],
#      'keyword': []},
#     'clonedHost': {},
#     'errorMessage': '',
#     'taskId': None,
#     'createdAt': '2018-11-21T14:03:02.558Z',
#     'updatedAt': '2018-11-21T14:03:02.558Z',
#     'dataLastUpdated': None,
#     'metadata': [],
#     'widget': [],
#     'layer': [],
#     'vocabulary': [],
#     'widgetRelevantProps': [],
#     'layerRelevantProps': ['the_geom',
#      'the_geom_webmercator',
#      'iso',
#      'gid_1',
#      'name_1',
#      'gid_2',
#      'name_2']}}],
#  'links': {'self': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&status=saved&published=true&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&page[number]=1&page[size]=1613982331640',
#   'first': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&status=saved&published=true&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&page[number]=1&page[size]=1613982331640',
#   'last': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&status=saved&published=true&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&page[number]=1&page[size]=1613982331640',
#   'prev': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&status=saved&published=true&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&page[number]=1&page[size]=1613982331640',
#   'next': 'http://api.resourcewatch.org/v1/dataset?application=aqueduct&status=saved&published=true&includes=widget%2Clayer%2Cvocabulary%2Cmetadata&page[number]=1&page[size]=1613982331640'},
#  'meta': {'total-pages': 1, 'total-items': 5, 'size': 1613982331640}}

# %% [markdown]
# ### Copy resources from staging to production

# %%
try:
    resources=[]

    for dataset in stagingData['data']:

        newDataset = recreateDataset(dataset)

        resources.append({
            'type': 'dataset',
            'stagingId':dataset.get('id'),
            'productionId': newDataset['data'].get('id')
        })

        for vocabulary in dataset['attributes'].get('vocabulary'):
            newVocabulary = recreateVocabulary(newDataset['data'].get('id'), vocabulary)
            resources.append({
            'type': 'vocabulary',
            'stagingId':vocabulary.get('id'),
            'productionId': newVocabulary['data']
        })

        for layer in dataset['attributes'].get('layer'):
            newLayer = recreateLayer(newDataset['data'].get('id'), layer)
            resources.append({
            'type': 'layer',
            'stagingId':layer.get('id'),
            'productionId': newLayer['data'].get('id')
        })

        for widget in dataset['attributes'].get('widget'):
            newWidget = recreateWidget(newDataset['data'].get('id'), widget)
            resources.append({
            'type': 'widget',
            'stagingId':widget.get('id'),
            'productionId': newWidget['data'].get('id')
        })

        for metadata in dataset['attributes'].get('metadata'):
            newMetadata = recreateMetadata(newDataset['data'].get('id'), metadata)
            resources.append({
            'type': 'metadata',
            'stagingId':metadata.get('id'),
            'productionId': newMetadata['data']
        })
except:
    pass
# Out:
# {'data': {'id': '79260642-1758-46ee-a73e-297cf036fd7a', 'type': 'layer', 'attributes': {'name': 'Water Risk - Groundwater table declining trend', 'slug': 'Water-Risk-Groundwater-table-declining-trend', 'dataset': '3d010bec-30aa-4a2b-aba2-11dbf2750b55', 'application': ['aqueduct'], 'iso': [''], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'account': 'wri-rw', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'iso', 'required': False}, {'key': 'crop', 'required': False}, {'key': 'irrigation', 'required': False}]}], 'body': {'maxzoom': 18, 'minzoom': 3, 'layers': [{'type': 'cartodb', 'options': {'sql': "with r as (SELECT basinid, value, label, aqid FROM water_risk_indicators_v3 where indicator='groundwater_decline_trend') SELECT r.aqid, value, label, the_geom_webmercator from r inner join wri_subcatchements_v3 on r.aqid=wri_subcatchements_v3.aqid", 'cartocss': '#water_risk_indicators_v3[value>0.8] {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;polygon-fill: #ff0c19; line-color: #FF1900;} #water_risk_indicators_v3[value<0.8] {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;polygon-fill: #FF9900; line-color: #FF9900;} #water_risk_indicators_v3[value<0.2] {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;polygon-fill: #FFE600; line-color: #FFE600;}#water_risk_indicators_v3[value<=0] {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;polygon-fill: #f4f4f1; line-color: #f4f4f1;} #water_risk_indicators_v3[value<-999] {polygon-opacity: 0; line-width: 05; line-opacity: 0;polygon-fill: transparent; line-color: transparent;}', 'cartocss_version': '2.3.0'}}, {'type': 'cartodb', 'options': {'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}', 'cartocss': '#layer {polygon-fill: #eee; polygon-opacity: 1; line-color: #eee; line-width: 1; line-opacity: 1; comp-op: dst-in;}', 'cartocss_version': '2.3.0'}}]}}, 'legendConfig': {'items': [{'color': '#f4f4f1', 'value': '<0 cm/yr', 'name': 'No Depletion'}, {'color': '#FFE600', 'value': '0-2 cm/yr', 'name': 'Low Depletion'}, {'color': '#FF9900', 'value': '2-8 cm/yr', 'name': 'Moderate Depletion'}, {'color': '#FF1900', 'value': '>8 cm/yr', 'name': 'High Depletion'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:25:39.598Z', 'updatedAt': '2021-02-24T09:25:39.598Z'}}}
# {'data': {'id': '47ba5b7a-5158-4081-83a9-090531eb9434', 'type': 'layer', 'attributes': {'name': 'Water Risk - Drought severity (soil moisture)', 'slug': 'Water-Risk-Drought-severity-soil-moisture', 'dataset': 'd4539813-81f4-42c9-8090-e84a5ecab20a', 'application': ['aqueduct'], 'iso': [''], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'raster_band': 1, 'geom_type': 'raster', 'geom_column': 'the_raster_webmercator', 'cartocss_version': '2.3.0', 'cartocss': '#drought_severity_soil_historic_year_2014 {raster-opacity:1; raster-colorizer-default-mode: discrete; raster-colorizer-default-color: transparent; raster-colorizer-epsilon: 0.01; raster-colorizer-stops: stop(0, #808080) stop(0.01, #FFFF99) stop(1, #FFFF99) stop(2, #FFE600) stop(3, #FF9900) stop(4, #FF1900) stop(5, #990000)}', 'sql': 'SELECT * FROM rought_severity_soil_historic_year_2014'}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '#layer {polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}], 'params_config': [], 'account': 'wri-rw'}, 'legendConfig': {'disclaimer': [{'color': '#808080', 'name': 'Arid and low water use'}], 'items': [{'color': '#FFFF99', 'value': '<0.1', 'name': 'Low'}, {'color': '#FFE600', 'value': '0.1-0.25', 'name': 'Moderate'}, {'color': '#FF9900', 'value': '0.25-0.50', 'name': 'Mid'}, {'color': '#FF1900', 'value': '0.5-0.75', 'name': 'Severe'}, {'color': '#990000', 'value': '>0.75', 'name': 'Extremely severe'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:25:44.556Z', 'updatedAt': '2021-02-24T09:25:44.556Z'}}}
# {'data': {'id': '9d3c06b0-67ff-42d2-8aff-4eb271716cf9', 'type': 'layer', 'attributes': {'name': 'All Crops', 'slug': 'All-Crops', 'dataset': '217c2eb0-e042-468a-8dbe-3c6630b34c52', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'account': 'wri-rw', 'params_config': [], 'sql_config': [{'key': 'and', 'key_params': [{'key': 'iso'}, {'key': 'irrigation'}]}], 'body': {'maxzoom': 18, 'minzoom': 3, 'layers': [{'type': 'cartodb', 'options': {'sql': "SELECT * FROM crops where rank='1' and crop != 'all cereals' and crop <> 'all pulses' {{and}}", 'cartocss': "#layer { polygon-fill: ramp([crop], (#531332,#741A46, #B72A6E, #D23782, #D95997, #E17AAC, #0A1B5C, #0E2581, #1230A5, #163ACA, #234AE7, #4364EA, #1C4A3C, #276855, #32866D, #3FA989, #CCB100, #FFE01B, #6e23bd), ('barley','maize', 'millet', 'rice', 'sorghum', 'wheat', 'beans' ,'cowpeas', 'chickpeas', 'groundnut', 'lentils', 'pigeonpeas', 'cassava','potato', 'sweet potato','yams' ,'banana' ,'plantain', 'soybean'), '='); line-color: ramp([crop], (#531332,#741A46, #B72A6E, #D23782, #D95997, #E17AAC, #0A1B5C, #0E2581, #1230A5, #163ACA, #234AE7, #4364EA, #1C4A3C, #276855, #32866D, #3FA989, #CCB100, #FFE01B, #6e23bd,), ('barley','maize', 'millet', 'rice', 'sorghum', 'wheat', 'beans' ,'cowpeas', 'chickpeas', 'groundnut', 'lentils', 'pigeonpeas', 'cassava','potato', 'sweet potato','yams' ,'banana' ,'plantain', 'soybean'), '=');}", 'cartocss_version': '2.3.0'}}]}}, 'legendConfig': {'type': 'group', 'items': [{'name': 'Cereals', 'color': '#d95997', 'items': [{'name': 'Barley', 'color': '#531332'}, {'name': 'Maize', 'color': '#741A46'}, {'name': 'Millet', 'color': '#B72A6E'}, {'name': 'Rice', 'color': '#D23782'}, {'name': 'Sorghum', 'color': '#D95997'}, {'name': 'Wheat', 'color': '#E17AAC'}]}, {'name': 'Pulses and legumes', 'color': '#1230a5', 'items': [{'name': 'Beans', 'color': '#0A1B5C'}, {'name': 'Cowpeas', 'color': '#0E2581'}, {'name': 'Chickpeas', 'color': '#1230A5'}, {'name': 'Groundnut', 'color': '#163ACA'}, {'name': 'Lentils', 'color': '#234AE7'}, {'name': 'Pigeonpeas', 'color': '#4364EA'}]}, {'name': 'Roots And Tubers', 'color': '#32866d', 'items': [{'name': 'Cassava', 'color': '#1C4A3C'}, {'name': 'Potato', 'color': '#276855'}, {'name': 'Sweet potato', 'color': '#32866D'}, {'name': 'Yams', 'color': '#3FA989'}]}, {'name': 'Fruit and nuts', 'color': '#ffe01b', 'items': [{'name': 'Banana', 'color': '#CCB100'}, {'name': 'Plantain', 'color': '#FFE01B'}]}, {'name': 'Oilseed crops', 'color': '#6e23bd', 'items': [{'name': 'Soybean', 'color': '#6e23bd'}]}]}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:25:51.174Z', 'updatedAt': '2021-02-24T09:25:51.174Z'}}}
# {'data': {'id': '2029e219-567d-4a49-88cc-79d42ad8f940', 'type': 'layer', 'attributes': {'name': 'One Crop', 'slug': 'One-Crop', 'dataset': '217c2eb0-e042-468a-8dbe-3c6630b34c52', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': False, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': '#crops [ prod <= {{bucket[4]}} ] {line-color: {{color}};line-width: 0;line-opacity: 1; polygon-fill: {{color}};polygon-opacity: 1;} #crops [ prod <= {{bucket[3]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.8;polygon-fill: {{color}};polygon-opacity: 0.80;} #crops [ prod <= {{bucket[2]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.6; polygon-fill: {{color}};polygon-opacity: 0.60;} #crops [ prod <= {{bucket[1]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.4; polygon-fill: {{color}};polygon-opacity: 0.40;} #crops [ prod <= {{bucket[0]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.2; polygon-fill: {{color}}; polygon-opacity: 0.20;}', 'sql': 'SELECT * FROM crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}], 'params_config': [], 'account': 'wri-rw'}, 'legendConfig': {'type': 'choropleth', 'items': [], 'units': 'metric tons of production', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'iso', 'required': False}, {'key': 'crop', 'required': False}, {'key': 'irrigation', 'required': False}]}], 'sql_query': 'with r as (SELECT sum(prod) val, cell5m FROM crops {{where}} group by cell5m) select CDB_JenksBins(array_agg(val::numeric),5) as bucket from r where val is not null'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:25:51.814Z', 'updatedAt': '2021-02-24T09:25:51.814Z'}}}
# {'data': {'id': '533e0d69-8bb5-45c0-a036-642bf7b977df', 'type': 'layer', 'attributes': {'name': 'Country mask', 'slug': 'Country-mask', 'dataset': 'ea9dacf1-c11e-4e6a-ad63-8804111a75ba', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'account': 'wri-01', 'params_config': [{'key': 'iso', 'required': True}], 'sql_config': [], 'body': {'maxzoom': 18, 'minzoom': 3, 'layers': [{'type': 'cartodb', 'options': {'sql': 'SELECT * FROM country_mask', 'cartocss': "#country_mask{polygon-fill:#000;polygon-opacity:.1;line-color:#000;line-opacity:.1;line-width:0}#country_mask[code='{{iso}}']{polygon-fill:#FFF;polygon-opacity:0;line-opacity:1}", 'cartocss_version': '2.3.0'}}]}}, 'legendConfig': {}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:02.298Z', 'updatedAt': '2021-02-24T09:26:02.299Z'}}}
# {'data': {'id': '73d7f503-33bc-4c61-a7df-6c9a6ae629d7', 'type': 'layer', 'attributes': {'name': 'Water stress', 'slug': 'Water-stress_3', 'dataset': '59fa37a0-cc20-4ef2-8934-ac2a315329df', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': False, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': '#aqueduct_projections_20150309 {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;}  #aqueduct_projections_20150309[value>0.8] {polygon-fill: #990000; line-color: #990000;} #aqueduct_projections_20150309[value<0.81] {polygon-fill: #FF1900; line-color: #FF1900;} #aqueduct_projections_20150309[value<0.4] {polygon-fill: #FF9900; line-color: #FF9900;} #aqueduct_projections_20150309[value<0.2] {polygon-fill: #FFE600; line-color: #FFE600;} #aqueduct_projections_20150309[value<0.1] {polygon-fill: #FFFF99; line-color: #FFFF99;} #aqueduct_projections_20150309[value= 0] {polygon-fill: #4a596a; line-color: #4a596a;}', 'sql': 'with r as (SELECT basinid, value, label FROM water_risk_indicators  {{where2}}) SELECT r.basinid, value, label, the_geom_webmercator from r inner join wri_subcatchements_v2 on r.basinid=wri_subcatchements_v2.basinid'}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '  #layer{polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}, {'key_params': [{'required': False, 'key': 'indicator'}, {'required': False, 'key': 'model'}, {'required': False, 'key': 'period'}, {'required': False, 'key': 'type'}, {'required': False, 'key': 'year'}], 'key': 'where2'}], 'params_config': [], 'account': 'wri-rw', 'absolute': True}, 'legendConfig': {'disclaimer': [{'color': '#808080', 'name': 'Arid and low water use'}], 'items': [{'color': '#FFFF99', 'value': '(<10%)', 'name': 'Low'}, {'color': '#FFE600', 'value': '(10-20%)', 'name': 'Low-medium'}, {'color': '#FF9900', 'value': '(20-40%)', 'name': 'Medium-high'}, {'color': '#FF1900', 'value': '(40-80%)', 'name': 'High'}, {'color': '#990000', 'value': '(>80%)', 'name': 'Extremely high'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:06.074Z', 'updatedAt': '2021-02-24T09:26:06.074Z'}}}
# {'data': {'id': '11d4266c-160b-45ae-bcaa-b43d4a923ca7', 'type': 'layer', 'attributes': {'name': 'Projected change in Water Stress', 'slug': 'Projected-change-in-Water-Stress', 'dataset': '59fa37a0-cc20-4ef2-8934-ac2a315329df', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': False, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': "#aqueduct_projections_20150309{ polygon-fill: #0099CD; polygon-opacity: 1; line-width: 0; line-opacity: 1;} #aqueduct_projections_20150309 [ label = '2.8x or greater decrease'] {  polygon-fill: #0099CD;} #aqueduct_projections_20150309 [ label = '2x decrease'] {  polygon-fill: #74AFD1;} #aqueduct_projections_20150309 [ label = '1.4x decrease'] {  polygon-fill: #AAC7D8;} #aqueduct_projections_20150309 [ label = 'Near normal'] {  polygon-fill: #DEDEDD;} #aqueduct_projections_20150309 [ label = '1.4x increase'] {  polygon-fill: #F8AB95;} #aqueduct_projections_20150309 [ label = '2x increase'] {  polygon-fill: #F27454;} #aqueduct_projections_20150309 [ label = '2.8x or greater increase'] {  polygon-fill: #ED2924;} #aqueduct_projections_20150309 [ label = 'No data'] {  polygon-fill: #4F4F4F;}", 'sql': 'with r as (SELECT basinid, value, label FROM water_risk_indicators  {{where2}}) SELECT r.basinid, value, label, the_geom_webmercator from r inner join wri_subcatchements_v2 on r.basinid=wri_subcatchements_v2.basinid;'}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '  #layer{polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}, {'key_params': [{'required': True, 'key': 'indicator'}, {'required': True, 'key': 'model'}, {'required': True, 'key': 'period'}, {'required': True, 'key': 'year'}, {'required': True, 'key': 'type'}], 'key': 'where2'}], 'params_config': [], 'from_baseline': True, 'account': 'wri-rw'}, 'legendConfig': {'items': [{'color': '#0099CD', 'name': '2.8x or greater decrease'}, {'color': '#74AFD1', 'name': '2x decrease'}, {'color': '#AAC7D8', 'name': '1.4x decrease'}, {'color': '#DEDEDD', 'name': 'Near normal'}, {'color': '#F8AB95', 'name': '1.4x increase'}, {'color': '#F27454', 'name': '2x increase'}, {'color': '#ED2924', 'name': '2.8x or greater increase'}, {'color': '#4F4F4F', 'name': 'No data'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:06.389Z', 'updatedAt': '2021-02-24T09:26:06.389Z'}}}
# {'data': {'id': '892944ce-d01d-488e-9d78-bd3cd108d933', 'type': 'layer', 'attributes': {'name': 'Water Stress new data', 'slug': 'Water-Stress-new-data', 'dataset': '59fa37a0-cc20-4ef2-8934-ac2a315329df', 'application': ['aqueduct'], 'iso': [''], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': '#aqueduct_projections_20150309 {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;} #aqueduct_projections_20150309[cat>4] {polygon-fill: #990000; line-color: #990000;} #aqueduct_projections_20150309[cat<=4]{polygon-fill: #FF1900; line-color: #FF1900;} #aqueduct_projections_20150309[cat<=3] {polygon-fill: #FF9900; line-color: #FF9900;} #aqueduct_projections_20150309[cat<=2] {polygon-fill: #FFE600; line-color: #FFE600;} #aqueduct_projections_20150309[cat<=1]{polygon-fill: #FFFF99; line-color: #FFFF99;}#aqueduct_projections_20150309[cat= -1] {polygon-fill: #f4f4f1; line-color: #f4f4f1;}', 'sql': "with r as (SELECT basinid, cat, label FROM water_risk_indicators_v3 where indicator = 'water_stess' and period = 'year') SELECT cartodb_id, r.basinid, cat, label, the_geom_webmercator from r inner join wri_subcatchements_v3 on r.basinid=wri_subcatchements_v3.basinid"}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '#layer {polygon-fill: #FFffff; polygon-opacity: 1; line-color: #FFffff; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}, {'key_params': [{'required': True, 'key': 'indicator'}], 'key': 'where2'}], 'params_config': [], 'account': 'wri-rw'}, 'legendConfig': {'disclaimer': [{'color': '#808080', 'name': 'Arid and low water use'}], 'items': [{'color': '#FFFF99', 'value': '(<10%)', 'name': 'Low'}, {'color': '#FFE600', 'value': '(10-20%)', 'name': 'Low-medium'}, {'color': '#FF9900', 'value': '(20-40%)', 'name': 'Medium-high'}, {'color': '#FF1900', 'value': '(40-80%)', 'name': 'High'}, {'color': '#990000', 'value': '(>80%)', 'name': 'Extremely high'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:07.034Z', 'updatedAt': '2021-02-24T09:26:07.034Z'}}}
# {'data': {'id': '38e9e3bf-34c8-4661-8b83-603cdf9365f1', 'type': 'layer', 'attributes': {'name': 'Water Risk - Inter-annual variability', 'slug': 'Water-Risk-Inter-annual-variability', 'dataset': '6cad7987-bbe3-424e-8855-e3e7cec6deba', 'application': ['aqueduct'], 'iso': [''], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'raster_band': 1, 'geom_type': 'raster', 'geom_column': 'the_raster_webmercator', 'cartocss_version': '2.3.0', 'cartocss': '#drought_severity_soil_historic_year_2014 {raster-opacity:1; raster-colorizer-default-mode: discrete; raster-colorizer-default-color: transparent; raster-colorizer-epsilon: 0.01; raster-colorizer-stops: stop(0, #f4f4f1) stop(0.01, #FFFF99) stop(1, #FFFF99) stop(2, #FFE600) stop(3, #FF9900) stop(4, #FF1900) stop(5, #990000)}', 'sql': 'SELECT * FROM nterannual_variability_historic_year_2014'}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '#layer {polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}], 'params_config': [], 'account': 'wri-rw'}, 'legendConfig': {'disclaimer': [{'color': '#808080', 'name': 'Arid and low water use'}], 'items': [{'color': '#FFFF99', 'value': '<0.25', 'name': 'Low'}, {'color': '#FFE600', 'value': '0.25-0.5', 'name': 'Low-medium'}, {'color': '#FF9900', 'value': '0.5-0.75', 'name': 'Medium-high'}, {'color': '#FF1900', 'value': '0.75-1.0', 'name': 'High'}, {'color': '#990000', 'value': '>1.0', 'name': 'Extremely high'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:20.590Z', 'updatedAt': '2021-02-24T09:26:20.590Z'}}}
# {'data': {'id': 'c529744b-74da-47d8-afd3-6806913238c7', 'type': 'layer', 'attributes': {'name': 'Groundwater stress', 'slug': 'Groundwater-stress', 'dataset': '29125f9d-5001-484f-a7a8-0c7a5b21fb2c', 'application': ['aqueduct'], 'iso': [''], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': '#water_risk_indicators_v3 {polygon-opacity: 1; line-width: 0.5; line-opacity: 1;}  #water_risk_indicators_v3[value>0.81] {polygon-fill: #990000; line-color: #990000;}#water_risk_indicators_v3[value<0.81] {polygon-fill: #FF1900; line-color: #FF1900;} #water_risk_indicators_v3[value<0.4] {polygon-fill: #FF9900; line-color: #FF9900;}#water_risk_indicators_v3[value<0.2] {polygon-fill: #FFE600; line-color: #FFE600;}#water_risk_indicators_v3[value<0.1] {polygon-fill: #FFFF99; line-color: #FFFF99;}#water_risk_indicators_v3[value= 0] {polygon-fill: #f4f4f1; line-color: #f4f4f1;}', 'sql': "with r as (SELECT basinid, value, label, aqid FROM water_risk_indicators_v3 where indicator='groundwater_stress') SELECT r.aqid, value, label, the_geom_webmercator from r inner join wri_subcatchements_v3 on r.aqid=wri_subcatchements_v3.aqid"}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '#layer {polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}], 'params_config': [], 'account': 'wri-rw'}, 'legendConfig': {'disclaimer': [{'color': '#808080', 'name': 'Arid and low water use'}], 'items': [{'color': '#FFFF99', 'value': '<1', 'name': 'Low'}, {'color': '#FFE600', 'value': '1-5', 'name': 'Low-medium'}, {'color': '#FF9900', 'value': '5-10', 'name': 'Medium-high'}, {'color': '#FF1900', 'value': '10-20', 'name': 'High'}, {'color': '#990000', 'value': '>20', 'name': 'Extremely high'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:22.419Z', 'updatedAt': '2021-02-24T09:26:22.419Z'}}}
# {'data': {'id': '2382c97b-45f4-4eec-91f5-5727b839f6dc', 'type': 'layer', 'attributes': {'name': 'Seasonal variability new data', 'slug': 'Seasonal-variability-new-data', 'dataset': '1f8e22c4-e5cc-4806-8521-deb435d5c209', 'application': ['aqueduct'], 'iso': [''], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': "#layer { polygon-fill: ramp([label], (#f4f4f1, #FFFF99, #FFE600, #FF9900, #FF1900, #990000), ('1.No Data','2.Low','3.Mid-low','4.Mid-High',  '5.High',  '6.Extremely high'), '=');} #layer::outline { line-width: 0.5; line-color: ramp([label], (#f4f4f1, #FFFF99, #FFE600, #FF9900, #FF1900, #990000), ('1.No Data','2.Low','3.Mid-low','4.Mid-High',  '5.High',  '6.Extremely high'), '='); line-opacity: 1; }", 'sql': 'with r as (SELECT basinid, value, label FROM water_risk_indicators  {{where2}}) SELECT r.basinid, value, label, the_geom_webmercator from r inner join wri_subcatchements_v2 on r.basinid=wri_subcatchements_v2.basinid'}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '#layer{polygon-fill: #ffffff; polygon-opacity: 1; line-color: #ffffff; line-width: 1; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}, {'key_params': [{'required': True, 'key': 'indicator'}, {'required': True, 'key': 'period'}, {'required': True, 'key': 'type'}, {'required': True, 'key': 'year'}], 'key': 'where2'}], 'params_config': [{'required': True, 'key': 'water_column'}], 'account': 'wri-rw'}, 'legendConfig': {'disclaimer': [{'color': '#808080', 'name': 'Arid and low water use'}], 'items': [{'color': '#FFFF99', 'value': '< 0.33', 'name': 'Low'}, {'color': '#FFE600', 'value': '0.33-0.66', 'name': 'Low-medium'}, {'color': '#FF9900', 'value': '0.66-1.00', 'name': 'Medium-high'}, {'color': '#FF1900', 'value': '1.0-1.33', 'name': 'High'}, {'color': '#990000', 'value': '>1.33', 'name': 'Extremely high'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:26.886Z', 'updatedAt': '2021-02-24T09:26:26.886Z'}}}
# {'data': {'id': 'dd3205ff-9679-4ffe-ad5d-60ab58d305f9', 'type': 'layer', 'attributes': {'name': 'Projected change in seasonal variability', 'slug': 'Projected-change-in-seasonal-variability', 'dataset': '1f8e22c4-e5cc-4806-8521-deb435d5c209', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': False, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': "#layer { polygon-fill: ramp([label], (#4F4F4F, #0099CD, #74AFD1, #AAC7D8, #DEDEDD, #F8AB95,#F27454,#ED2924), ('No data','1.3x or greater decrease','1.2x decrease','1.1x decrease',  'Near normal',  '1.1x increase','1.2x increase','1.3x or greater increase'), '=');} #layer::outline { line-width: 0.5; line-color: ramp([label], (#4F4F4F, #0099CD, #74AFD1, #AAC7D8, #DEDEDD, #F8AB95,#F27454,#ED2924), ('No data','1.3x or greater decrease','1.2x decrease','1.1x decrease',  'Near normal',  '1.1x increase','1.2x increase','1.3x or greater increase'), '='); line-opacity: 1; }", 'sql': 'with r as (SELECT basinid, value, label FROM water_risk_indicators  {{where2}}) SELECT r.basinid, value, label, the_geom_webmercator from r inner join wri_subcatchements_v2 on r.basinid=wri_subcatchements_v2.basinid'}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '  #layer{polygon-fill: #ffffff; polygon-opacity: 1; line-color: #ffffff; line-width: 1; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}, {'key_params': [{'required': True, 'key': 'indicator'}, {'required': True, 'key': 'model'}, {'required': True, 'key': 'period'}, {'required': True, 'key': 'type'}, {'required': True, 'key': 'year'}], 'key': 'where2'}], 'params_config': [{'required': True, 'key': 'water_column'}], 'from_baseline': True, 'account': 'wri-rw'}, 'legendConfig': {'items': [{'color': '#0099CD', 'name': '1.3x or greater decrease'}, {'color': '#74AFD1', 'name': '1.2x decrease'}, {'color': '#AAC7D8', 'name': '1.1x decrease'}, {'color': '#DEDEDD', 'name': 'Near normal'}, {'color': '#F8AB95', 'name': '1.1x increase'}, {'color': '#F27454', 'name': '1.2x increase'}, {'color': '#ED2924', 'name': '1.3x or greater increase'}, {'color': '#4F4F4F', 'name': 'No data'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:27.488Z', 'updatedAt': '2021-02-24T09:26:27.488Z'}}}
# {'data': {'id': '783bfe13-1e2d-405a-8455-a2bbd997faa9', 'type': 'layer', 'attributes': {'name': 'Seasonal variability', 'slug': 'Seasonal-variability', 'dataset': '1f8e22c4-e5cc-4806-8521-deb435d5c209', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': False, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': '#layer {polygon-fill: ramp([label], (#f4f4f1, #FFFF99, #FFE600, #FF9900, #FF1900, #990000), ("1.No Data","2.Low","3.Mid-low","4.Mid-High", "5.High", "6.Extremely high"), "=");} #layer::outline { line-width: 1; line-color:  ramp([label], (#f4f4f1, #FFFF99, #FFE600, #FF9900, #FF1900, #990000), ("1.No Data","2.Low","3.Mid-low","4.Mid-High", "5.High", "6.Extremely high"), "="); line-opacity: 1; }', 'sql': 'with r as (SELECT basinid, value, label FROM water_risk_indicators  {{where2}}) SELECT r.basinid, value, label, the_geom_webmercator from r inner join wri_subcatchements_v2 on r.basinid=wri_subcatchements_v2.basinid;'}, 'type': 'cartodb'}, {'options': {'cartocss_version': '2.3.0', 'cartocss': '  #layer{polygon-fill: #FFffff; polygon-opacity: 1; line-color: #FFffff; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'sql': 'select cartodb_id, the_geom_webmercator from crops {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': False, 'key': 'irrigation'}], 'key': 'where'}, {'key_params': [{'required': True, 'key': 'indicator'}, {'required': True, 'key': 'model'}, {'required': True, 'key': 'period'}, {'required': True, 'key': 'type'}, {'required': True, 'key': 'year'}], 'key': 'where2'}], 'params_config': [{'required': True, 'key': 'water_column'}], 'absolute': True, 'account': 'wri-rw'}, 'legendConfig': {'disclaimer': [{'color': '#808080', 'name': 'Arid and low water use'}], 'items': [{'color': '#FFFF99', 'value': '< 0.33', 'name': 'Low'}, {'color': '#FFE600', 'value': '0.33-0.66', 'name': 'Low-medium'}, {'color': '#FF9900', 'value': '0.66-1.00', 'name': 'Medium-high'}, {'color': '#FF1900', 'value': '1.0-1.33', 'name': 'High'}, {'color': '#990000', 'value': '>1.33', 'name': 'Extremely high'}], 'type': 'choropleth'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:26:28.096Z', 'updatedAt': '2021-02-24T09:26:28.096Z'}}}
# {'data': {'id': 'f67f5553-cc70-441c-9d1a-59044d552d58', 'type': 'layer', 'attributes': {'name': 'All Crops', 'slug': 'All-Crops_1', 'dataset': '4a2b250e-25ab-4da3-9b83-dc318995eee1', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': "#layer { polygon-fill: ramp([crop], (#4B0082, #800080, #C71585, #DB7093, #FF1493, #FF69B4, #FFB6C1, #FFC0CB, #00008B, #0000CD, #0000FF, #1E90FF, #00BFFF, #87CEFA, #800000, #8B0000, #A52A2A, #B22222, #DC143C, #FFD700, #FFA500, #FF8C00, #FF6347, #006400, #228B22, #6B8E23, #556B2F, #808000, #2E8B57, #3CB371, #8FBC8F, #FFDAB9, #FFE4B5, #E6E6FA, #FFF0F5, #A0522D, #8B4513, #D2691E, #CD853F, #DAA520, #008000, #2F4F4F), ('wheat', 'rice', 'maize', 'barley', 'pearl millet', 'small millet', 'sorghum', 'other cereals', 'bean', 'chickpea', 'cowpea', 'pigeonpea', 'lentil', 'other pulses', 'potato', 'sweet potato', 'yams', 'cassava', 'other roots', 'banana', 'plantain', 'tropical fruit', 'temperate fruit', 'soybean', 'groundnut', 'coconut', 'oilpalm', 'sunflower', 'rapeseed', 'sesameseed', 'other oil crops', 'sugarcane', 'sugarbeet', 'cotton', 'other fibre crops', 'arabica coffee', 'robusta coffee', 'cocoa', 'tea', 'tobacco', 'vegetables', 'rest of crops'), '='); line-color: ramp([crop], (#4B0082, #800080, #C71585, #DB7093, #FF1493, #FF69B4, #FFB6C1, #FFC0CB, #00008B, #0000CD, #0000FF, #1E90FF, #00BFFF, #87CEFA, #800000, #8B0000, #A52A2A, #B22222, #DC143C, #FFD700, #FFA500, #FF8C00, #FF6347, #006400, #228B22, #6B8E23, #556B2F, #808000, #2E8B57, #3CB371, #8FBC8F, #FFDAB9, #FFE4B5, #E6E6FA, #FFF0F5, #A0522D, #8B4513, #D2691E, #CD853F, #DAA520, #008000, #2F4F4F), ('wheat', 'rice', 'maize', 'barley', 'pearl millet', 'small millet', 'sorghum', 'other cereals', 'bean', 'chickpea', 'cowpea', 'pigeonpea', 'lentil', 'other pulses', 'potato', 'sweet potato', 'yams', 'cassava', 'other roots', 'banana', 'plantain', 'tropical fruit', 'temperate fruit', 'soybean', 'groundnut', 'coconut', 'oilpalm', 'sunflower', 'rapeseed', 'sesameseed', 'other oil crops', 'sugarcane', 'sugarbeet', 'cotton', 'other fibre crops', 'arabica coffee', 'robusta coffee', 'cocoa', 'tea', 'tobacco', 'vegetables', 'rest of crops'), '=');}", 'sql': "SELECT * FROM merged_allcrops_dissolve_v1 WHERE iso<>'all' {{and}}"}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'key': 'iso', 'required': False}, {'key': 'irrigation', 'required': False}], 'key': 'and'}], 'params_config': [], 'account': 'wri-rw'}, 'legendConfig': {'items': [{'items': [{'color': '#4B0082', 'name': 'Wheat'}, {'color': '#800080', 'name': 'Rice'}, {'color': '#C71585', 'name': 'Maize'}, {'color': '#DB7093', 'name': 'Barley'}, {'color': '#FF1493', 'name': 'Pearl millet'}, {'color': '#FF69B4', 'name': 'Small millet'}, {'color': '#FFB6C1', 'name': 'Sorghum'}, {'color': '#FFC0CB', 'name': 'Other cereals'}], 'color': '#C71585', 'name': 'Cereals'}, {'items': [{'color': '#00008B', 'name': 'Beans'}, {'color': '#0000CD', 'name': 'Chickpeas'}, {'color': '#0000FF', 'name': 'Cowpeas'}, {'color': '#1E90FF', 'name': 'Pigeonpeas'}, {'color': '#00BFFF', 'name': 'Lentils'}, {'color': '#87CEFA', 'name': 'Other pulses'}], 'color': '#0000FF', 'name': 'Pulses and legumes'}, {'items': [{'color': '#800000', 'name': 'Potato'}, {'color': '#8B0000', 'name': 'Sweet potato'}, {'color': '#A52A2A', 'name': 'Yams'}, {'color': '#B22222', 'name': 'Cassava'}, {'color': '#DC143C', 'name': 'Other roots'}], 'color': '#A52A2A', 'name': 'Roots And Tubers'}, {'items': [{'color': '#FFD700', 'name': 'Banana'}, {'color': '#FFA500', 'name': 'Plantain'}, {'color': '#FF8C00', 'name': 'Tropical fruit'}, {'color': '#FF6347', 'name': 'Temperate fruit'}], 'color': '#FFA500', 'name': 'Fruit and nuts'}, {'items': [{'color': '#006400', 'name': 'Soybean'}, {'color': '#228B22', 'name': 'Groundnut' ...
# {'data': {'id': '32e964db-a2a0-4329-9bb1-470ebc99b622', 'type': 'layer', 'attributes': {'name': 'One Crop', 'slug': 'One-Crop_1', 'dataset': '4a2b250e-25ab-4da3-9b83-dc318995eee1', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'body': {'layers': [{'options': {'cartocss_version': '2.3.0', 'cartocss': '#crops_projected [ prod_total > {{bucket[4]}} ] {line-color: {{color}};line-width: 0;line-opacity: 1; polygon-fill: {{color}};polygon-opacity: 1;} #crops_projected [ prod_total <= {{bucket[4]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.8; polygon-fill: {{color}};polygon-opacity: 0.8;} #crops_projected [ prod_total <= {{bucket[3]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.6;polygon-fill: {{color}}; polygon-opacity: 0.60;} #crops_projected [ prod_total <= {{bucket[2]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.4; polygon-fill: {{color}}; polygon-opacity: 0.40;} #crops_projected [ prod_total <= {{bucket[1]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.2; polygon-fill: {{color}};polygon-opacity: 0.20;} #crops_projected [ prod_total <= {{bucket[0]}} ] {line-color: {{color}};line-width: 0;line-opacity: 0.1; polygon-fill: {{color}}; polygon-opacity: 0.10;}', 'sql': 'SELECT * FROM crops_projected {{where}}'}, 'type': 'cartodb'}], 'minzoom': 3, 'maxzoom': 18}, 'sql_config': [{'key_params': [{'required': False, 'key': 'iso'}, {'required': False, 'key': 'crop'}, {'required': True, 'key': 'irrigation'}], 'key': 'where'}], 'params_config': [], 'account': 'wri-rw'}, 'legendConfig': {'type': 'choropleth', 'items': [], 'units': 'metric tons of production', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'iso', 'required': True}, {'key': 'crop', 'required': True}, {'key': 'irrigation', 'required': True}]}], 'sql_query': 'select array_agg(bucket::numeric) as bucket from (select json_array_elements(bucket::json)::text as bucket FROM crop_buckets_v2 {{where}}) s'}, 'interactionConfig': {'output': [{'column': 'name_cntr', 'format': None, 'prefix': '', 'property': 'Country', 'suffix': '', 'type': 'string'}, {'column': 'prod_total', 'format': None, 'prefix': '', 'property': 'Production', 'suffix': 'mt', 'type': 'string'}]}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:02.061Z', 'updatedAt': '2021-02-24T09:27:02.061Z'}}}
# {'data': {'id': '8074ac9b-9cca-4aaf-a112-26166a8e9c7d', 'type': 'layer', 'attributes': {'name': 'Water Stress', 'slug': 'Water-Stress', 'dataset': '113258c9-14fc-4624-8b5c-76b064ac1ae9', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'account': 'wri-rw', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'iso', 'required': False}, {'key': 'crop', 'required': False}, {'key': 'irrigation', 'required': False}, {'key': 'rank', 'required': False}]}], 'body': {'maxzoom': 18, 'minzoom': 3, 'layers': [{'type': 'cartodb', 'options': {'sql': "SELECT s.aq30_id as cartodb_id, coalesce(bws_cat, -9999) as  water_risk,  coalesce(NULLIF(bws_label,''), 'No Data') as label, r.the_geom, r.the_geom_webmercator FROM water_risk_indicators_annual s LEFT JOIN y2018m12d06_rh_master_shape_v01 r on s.aq30_id=r.aq30_id WHERE s.pfaf_id != -9999 and s.gid_1 != '-9999'", 'cartocss': '#water_risk_indicators_annual{ polygon-fill:transparent; polygon-opacity: 1; line-color:transparent; line-width: 1; line-opacity: 1; } #water_risk_indicators_annual [water_risk=4] { polygon-fill:#990000; line-color:#990000 } #water_risk_indicators_annual [water_risk=3] { polygon-fill:  #FF1900; line-color:  #FF1900 } #water_risk_indicators_annual [water_risk=2] { polygon-fill: #FF9900; line-color: #FF9900 } #water_risk_indicators_annual [water_risk=1] { polygon-fill: #FFE600; line-color:  #FFE600 } #water_risk_indicators_annual [water_risk=0] { polygon-fill: #FFFF99; line-color:  #FFFF99 } #water_risk_indicators_annual [water_risk=-1] { polygon-fill: #808080; line-color:  #808080 } #water_risk_indicators_annual [water_risk<-1] { polygon-fill: #4E4E4E; line-color:  #4E4E4E }', 'cartocss_version': '2.3.0'}}, {'type': 'cartodb', 'options': {'sql': 'SELECT cartodb_id, the_geom_webmercator FROM crops_projected {{where}}', 'cartocss': '#layer{polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'cartocss_version': '2.3.0'}}]}}, 'legendConfig': {'type': 'choropleth', 'items': [{'name': 'Low', 'value': '(<10%)', 'color': '#FFFF99'}, {'name': 'Low-medium', 'value': '(10-20%)', 'color': '#FFE600'}, {'name': 'Medium-high', 'value': '(20-40%)', 'color': '#FF9900'}, {'name': 'High', 'value': '(40-80%)', 'color': '#FF1900'}, {'name': 'Extremely high', 'value': '(>80%)', 'color': '#990000'}], 'disclaimer': [{'name': 'Arid and low water use', 'color': '#808080'}, {'name': 'No data', 'color': '#4E4E4E'}]}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:03.695Z', 'updatedAt': '2021-02-24T09:27:03.695Z'}}}
# {'data': {'id': '160be93f-8c21-428a-b4c7-214b7ea4232d', 'type': 'layer', 'attributes': {'name': 'Water Depletion', 'slug': 'Water-Depletion', 'dataset': '113258c9-14fc-4624-8b5c-76b064ac1ae9', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'account': 'wri-rw', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'iso', 'required': False}, {'key': 'crop', 'required': False}, {'key': 'irrigation', 'required': False}, {'key': 'rank', 'required': False}]}], 'body': {'maxzoom': 18, 'minzoom': 3, 'layers': [{'type': 'cartodb', 'options': {'sql': "SELECT s.aq30_id as cartodb_id, coalesce(bwd_cat, -9999) as  water_risk,  coalesce(NULLIF(bwd_label,''), 'No Data') as label, r.the_geom, r.the_geom_webmercator FROM water_risk_indicators_annual s LEFT JOIN y2018m12d06_rh_master_shape_v01 r on s.aq30_id=r.aq30_id WHERE s.pfaf_id != -9999 and s.gid_1 != '-9999'", 'cartocss': '#water_risk_indicators_annual{ polygon-fill:transparent; polygon-opacity: 1; line-color:transparent; line-width: 1; line-opacity: 1; } #water_risk_indicators_annual [water_risk=4] { polygon-fill:#990000; line-color:#990000 } #water_risk_indicators_annual [water_risk=3] { polygon-fill:  #FF1900; line-color:  #FF1900 } #water_risk_indicators_annual [water_risk=2] { polygon-fill: #FF9900; line-color: #FF9900 } #water_risk_indicators_annual [water_risk=1] { polygon-fill: #FFE600; line-color:  #FFE600 } #water_risk_indicators_annual [water_risk=0] { polygon-fill: #FFFF99; line-color:  #FFFF99 } #water_risk_indicators_annual [water_risk=-1] { polygon-fill: #808080; line-color:  #808080 } #water_risk_indicators_annual [water_risk<-1] { polygon-fill: #4E4E4E; line-color:  #4E4E4E }', 'cartocss_version': '2.3.0'}}, {'type': 'cartodb', 'options': {'sql': 'SELECT cartodb_id, the_geom_webmercator FROM crops_projected {{where}}', 'cartocss': ' #layer{polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'cartocss_version': '2.3.0'}}]}}, 'legendConfig': {'type': 'choropleth', 'items': [{'name': 'Low', 'value': '(<5%)', 'color': '#FFFF99'}, {'name': 'Low-medium', 'value': '(5-25%)', 'color': '#FFE600'}, {'name': 'Medium-high', 'value': '(25-50%)', 'color': '#FF9900'}, {'name': 'High', 'value': '(50-75%)', 'color': '#FF1900'}, {'name': 'Extremely high', 'value': '(>75%)', 'color': '#990000'}], 'disclaimer': [{'name': 'Arid and low water use', 'color': '#808080'}, {'name': 'No data', 'color': '#4E4E4E'}]}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:04.027Z', 'updatedAt': '2021-02-24T09:27:04.027Z'}}}
# {'data': {'id': 'b687f3e4-e362-4a8d-9a69-a610710efd6b', 'type': 'layer', 'attributes': {'name': 'Groundwater Table Decline', 'slug': 'Groundwater-Table-Decline', 'dataset': '113258c9-14fc-4624-8b5c-76b064ac1ae9', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'account': 'wri-rw', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'iso', 'required': False}, {'key': 'crop', 'required': False}, {'key': 'irrigation', 'required': False}, {'key': 'rank', 'required': False}]}], 'body': {'maxzoom': 18, 'minzoom': 3, 'layers': [{'type': 'cartodb', 'options': {'sql': "SELECT s.aq30_id as cartodb_id, coalesce(NULLIF(gtd_label,''), 'No Data') as label, r.the_geom, r.the_geom_webmercator, (CASE WHEN gtd_label = 'Insignificant Trend' THEN -1 ELSE coalesce(gtd_cat, -9999)END) as water_risk FROM water_risk_indicators_annual s LEFT JOIN y2018m12d06_rh_master_shape_v01 r on s.aq30_id=r.aq30_id WHERE s.pfaf_id != -9999 and s.gid_1 != '-9999' and r.aqid != -9999", 'cartocss': '#water_risk_indicators_annual{ polygon-fill:transparent; polygon-opacity: 1; line-color:transparent; line-width: 1; line-opacity: 1; } #water_risk_indicators_annual [water_risk=4] { polygon-fill:#990000; line-color:#990000 } #water_risk_indicators_annual [water_risk=3] { polygon-fill:  #FF1900; line-color:  #FF1900 } #water_risk_indicators_annual [water_risk=2] { polygon-fill: #FF9900; line-color: #FF9900 } #water_risk_indicators_annual [water_risk=1] { polygon-fill: #FFE600; line-color:  #FFE600 } #water_risk_indicators_annual [water_risk=0] { polygon-fill: #FFFF99; line-color:  #FFFF99 } #water_risk_indicators_annual [water_risk=-1] { polygon-fill: #808080; line-color:  #808080 } #water_risk_indicators_annual [water_risk<-1] { polygon-fill: #4E4E4E; line-color:  #4E4E4E }', 'cartocss_version': '2.3.0'}}, {'type': 'cartodb', 'options': {'sql': 'SELECT cartodb_id, the_geom_webmercator FROM crops_projected {{where}}', 'cartocss': ' #layer{polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}', 'cartocss_version': '2.3.0'}}]}}, 'legendConfig': {'type': 'choropleth', 'items': [{'name': 'Low', 'value': '(<0 cm/y)', 'color': '#FFFF99'}, {'name': 'Low-medium', 'value': '(0-2 cm/y)', 'color': '#FFE600'}, {'name': 'Medium-high', 'value': '(2-4 cm/y)', 'color': '#FF9900'}, {'name': 'High', 'value': '(4-8 cm/y)', 'color': '#FF1900'}, {'name': 'Extremely high', 'value': '(>8 cm/y)', 'color': '#990000'}], 'disclaimer': [{'name': 'Insignificant trend', 'color': '#808080'}, {'name': 'No data', 'color': '#4E4E4E'}]}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:04.714Z', 'updatedAt': '2021-02-24T09:27:04.714Z'}}}
# ...
# {'data': {'id': '9c8fb8c5-5f28-4646-bcfc-9dd9a57199b9', 'type': 'layer', 'attributes': {'name': 'Drought risk', 'slug': 'Drought-risk_3', 'dataset': '495049a5-a009-4eca-aa8b-ed6f49e2dacb', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'account': 'wri-rw', 'params_config': [], 'sql_config': [{'key': 'and', 'key_params': [{'key': 'year', 'required': True}, {'key': 'scenario', 'required': True}]}, {'key': 'where', 'key_params': [{'key': 'iso', 'required': False}, {'key': 'crop', 'required': False}, {'key': 'irrigation', 'required': False}, {'key': 'rank', 'required': False}]}], 'body': {'maxzoom': 18, 'minzoom': 3, 'layers': [{'type': 'cartodb', 'options': {'sql': "with province as (SELECT * FROM aqueduct_results_v01_province_v06 WHERE indicator_name = 'drr' and weight = 'Tot'), \n      country as (SELECT 1000000 + cartodb_id as cartodb_id, the_geom, the_geom_webmercator, null as gid_1, gid_0 as iso, name_0, \n                         null as name_1, null as indicator_name, null::numeric as score, null::numeric as cat, null as label, null as isoc  \n                  FROM gadm_wri_0)\n\nSELECT * FROM country\nUNION ALL\nSELECT a.cartodb_id, a.the_geom, a.the_geom_webmercator,  r.gid_1, null as iso, coalesce(NULLIF(r.name_0,''), 'No Data') as name_0, \n       coalesce(NULLIF(r.name_1,''), 'No Data') as name_1, r.indicator_name, r.score, \n       coalesce(r.cat, -9999) as cat, \n       (CASE WHEN label = 'NoData' THEN 'No Data' ELSE coalesce(NULLIF(r.label,''), 'No Data') END) as label, r.gid_0 as isoc\nFROM gadm_wri a  \nLEFT JOIN province r on a.gid_1 = r.gid_1", 'cartocss': "#layer{ polygon-comp-op:dst-atop; line-comp-op:dst-atop; polygon-fill:transparent;line-color:transparent;polygon-opacity: 1;  line-width: 1; line-opacity: 1;} #layer{ polygon-fill:ramp([cat], (#990000,#FF1900,#FF9900, #FFE600,#FFFF99,#4E4E4E,#4E4E4E), (4,3,2,1,0,-1,-9999), '='); \n        line-color:ramp([cat], (#990000,#FF1900,#FF9900, #FFE600,#FFFF99,#4E4E4E,#4E4E4E), (4,3,2,1,0,-1,-9999), '=');}\n\n#layer[iso!=null] {\n  polygon-fill:transparent; polygon-opacity: 1;\n line-color:#CFCFCB; line-width: 1; line-opacity: 1;polygon-comp-op:dst-over; \n\n}\n\n#layer[isoc='{{iso}}'] {\n line-color:#CFCFCB; line-width: 1; line-opacity: 1;  polygon-comp-op:dst-atop;\n\n}\n\n#layer[iso='{{iso}}'] { line-color:  #2e2c2c ;line-width: 1.5; polygon-opacity: 0;   line-comp-op:dst-over;}", 'cartocss_version': '2.3.0'}}]}}, 'legendConfig': {'type': 'choropleth', 'items': [{'name': 'Low', 'value': '(0.0-0.2)', 'color': '#FFFF99'}, {'name': 'Low-medium', 'value': '(0.2-0.4)', 'color': '#FFE600'}, {'name': 'Medium', 'value': '(0.4-0.6)', 'color': '#FF9900'}, {'name': 'Medium-high', 'value': '(0.6-0.8)', 'color': '#FF1900'}, {'name': 'High', 'value': '(0.8-1.0)', 'color': '#990000'}], 'disclaimer': [{'name': 'No data', 'color': '#4E4E4E'}]}, 'interactionConfig': {'output': [{'column': 'name_0', 'format': None, 'prefix': '', 'property': 'Country', 'suffix': '', 'type': 'string'}, {'column': 'name_1', 'format': None, 'prefix': '', 'property': 'Province', 'suffix': '', 'type': 'string'}, {'column': 'label', 'format': None, 'prefix': '', 'property': 'Category', 'suffix': '', 'type': 'string'}, {'column': 'score', 'format': None, 'prefix': '', 'property': 'Score', 'suffix': '', 'type': 'numeric'}]}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:21.691Z', 'updatedAt': '2021-02-24T09:27:21.691Z'}}}
# {'data': {'id': '5395f32b-1d18-4202-ac32-23b3ec8f8c25', 'type': 'layer', 'attributes': {'name': 'Riverine flood risk', 'slug': 'Riverine-flood-risk_3', 'dataset': '495049a5-a009-4eca-aa8b-ed6f49e2dacb', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'account': 'wri-rw', 'params_config': [], 'sql_config': [{'key': 'and', 'key_params': [{'key': 'year', 'required': True}, {'key': 'scenario', 'required': True}]}, {'key': 'where', 'key_params': [{'key': 'iso', 'required': False}, {'key': 'crop', 'required': False}, {'key': 'irrigation', 'required': False}, {'key': 'rank', 'required': False}]}], 'body': {'maxzoom': 18, 'minzoom': 3, 'layers': [{'type': 'cartodb', 'options': {'sql': "with province as (SELECT * FROM aqueduct_results_v01_province_v06 WHERE indicator_name = 'rfr' and weight = 'Pop'), \n      country as (SELECT 1000000 + cartodb_id as cartodb_id, the_geom, the_geom_webmercator, null as gid_1, gid_0 as iso, name_0, \n                         null as name_1, null as indicator_name, null::numeric as score, null::numeric as cat, null as label, null as isoc  \n                  FROM gadm_wri_0)\n\nSELECT * FROM country\nUNION ALL\nSELECT a.cartodb_id, a.the_geom, a.the_geom_webmercator,  r.gid_1, null as iso, coalesce(NULLIF(r.name_0,''), 'No Data') as name_0, \n       coalesce(NULLIF(r.name_1,''), 'No Data') as name_1, r.indicator_name, r.score, \n       coalesce(r.cat, -9999) as cat, \n       (CASE WHEN label = 'NoData' THEN 'No Data' ELSE coalesce(NULLIF(r.label,''), 'No Data') END) as label, r.gid_0 as isoc\nFROM gadm_wri a  \nLEFT JOIN province r on a.gid_1 = r.gid_1", 'cartocss': "#layer{ polygon-comp-op:dst-atop; line-comp-op:dst-atop; polygon-fill:transparent;line-color:transparent;polygon-opacity: 1;  line-width: 1; line-opacity: 1;} #layer{ polygon-fill:ramp([cat], (#990000,#FF1900,#FF9900, #FFE600,#FFFF99,#4E4E4E,#4E4E4E), (4,3,2,1,0,-1,-9999), '='); \n        line-color:ramp([cat], (#990000,#FF1900,#FF9900, #FFE600,#FFFF99,#4E4E4E,#4E4E4E), (4,3,2,1,0,-1,-9999), '=');}\n\n#layer[iso!=null] {\n  polygon-fill:transparent; polygon-opacity: 1;\n line-color:#CFCFCB; line-width: 1; line-opacity: 1;polygon-comp-op:dst-over; \n\n}\n\n#layer[isoc='{{iso}}'] {\n line-color:#CFCFCB; line-width: 1; line-opacity: 1;  polygon-comp-op:dst-atop;\n\n}\n\n#layer[iso='{{iso}}'] { line-color:  #2e2c2c ;line-width: 1.5; polygon-opacity: 0;   line-comp-op:dst-over;}", 'cartocss_version': '2.3.0'}}]}}, 'legendConfig': {'disclaimer': [{'color': '#4E4E4E', 'name': 'No data'}], 'items': [{'color': '#FFFF99', 'value': '(0-1)', 'name': 'Low'}, {'color': '#FFE600', 'value': '(1-2)', 'name': 'Low-medium'}, {'color': '#FF9900', 'value': '(2-3)', 'name': 'Medium-high'}, {'color': '#FF1900', 'value': '(3-4)', 'name': 'High'}, {'color': '#990000', 'value': '(4-5)', 'name': 'Extremely-high'}], 'type': 'choropleth'}, 'interactionConfig': {'output': [{'column': 'name_0', 'format': None, 'prefix': '', 'property': 'Country', 'suffix': '', 'type': 'string'}, {'column': 'name_1', 'format': None, 'prefix': '', 'property': 'Province', 'suffix': '', 'type': 'string'}, {'column': 'label', 'format': None, 'prefix': '', 'property': 'Category', 'suffix': '', 'type': 'string'}, {'column': 'score', 'format': None, 'prefix': '', 'property': 'Score', 'suffix': '', 'type': 'numeric'}]}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:22.329Z', 'updatedAt': '2021-02-24T09:27:22.329Z'}}}
# {'data': {'id': 'e41613c3-32ee-45e9-b3fe-8685b289cb8e', 'type': 'layer', 'attributes': {'name': 'Food Demand', 'slug': 'Food-Demand', 'dataset': '6880e51c-fda2-4de5-8456-e981d548853a', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'type': 'leaflet', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'year', 'required': True}, {'key': 'commodity', 'required': False}]}], 'body': {'url': "https://wri-rw.carto.com/api/v2/sql?q=with s as (SELECT iso, region, value, commodity FROM combined01_prepared {{where}} and impactparameter='Food Demand' and scenario='SSP2-MIRO' and iso is not null and commodity <> 'All Cereals' and commodity <> 'All Pulses' ), r as (SELECT iso, region, sum(value) as value FROM s group by iso, region), d as (SELECT centroid as geometry, iso, value, region FROM impact_regions_159 t inner join r on new_region=iso) select json_build_object('type','FeatureCollection','features',json_agg(json_build_object('geometry',cast(geometry as json),'properties', json_build_object('value',value,'country',region,'iso',iso, 'unit', 'thousand metric tons'),'type','Feature'))) as data from d", 'use_cors': False}}, 'legendConfig': {'items': [{'color': 'rgba(53, 89, 161, 0.85)', 'name': 'Food demand'}], 'units': 'thousand metric tons', 'description': 'Food demand for crop represents the demand for, or availability of, food in the domestic sector, by country.', 'type': 'cluster'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:23.816Z', 'updatedAt': '2021-02-24T09:27:23.816Z'}}}
# {'data': {'id': '3a0eae9d-eb02-478c-8997-c8e29ce69db0', 'type': 'layer', 'attributes': {'name': 'Pop. at risk of hunger', 'slug': 'Pop-at-risk-of-hunger', 'dataset': 'cfbe4903-2aaa-47e1-b26b-70a600363f5b', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'type': 'leaflet', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'year', 'required': True}, {'key': 'commodity', 'required': False}]}], 'body': {'url': "https://wri-rw.carto.com/api/v2/sql?q=with s as (SELECT iso, region, value, commodity FROM combined01_prepared {{where}} and impactparameter='Net trade' and scenario='SSP2-MIRO' and iso is not null and commodity <> 'All Cereals' and commodity <> 'All Pulses' ), r as (SELECT iso, region, sum(value) as value FROM s group by iso, region), d as (SELECT centroid as geometry, iso, value, region FROM impact_regions_159 t inner join r on new_region=iso) select json_build_object('type','FeatureCollection','features',json_agg(json_build_object('geometry',cast(geometry as json),'properties', json_build_object('value',value,'country',region,'iso',iso, 'unit', 'thousand metric tons'),'type','Feature'))) as data from d", 'use_cors': False}}, 'legendConfig': {'items': [{'color': 'rgba(28, 128, 28, 0.85)', 'name': 'Net exporter'}, {'color': 'rgba(222, 34, 57, 0.85)', 'name': 'Net importer'}], 'units': 'thousand metric tons', 'description': 'Crop net trade represents the amount of the crop(s) that is traded by country, where positive values indicate greater exports than imports.', 'type': 'cluster', 'scenario': 'SSP2-MIROC'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:25.599Z', 'updatedAt': '2021-02-24T09:27:25.599Z'}}}
# {'data': {'id': 'bd4a831a-e43b-429b-9eb3-593176718812', 'type': 'layer', 'attributes': {'name': 'Kcal per capita', 'slug': 'Kcal-per-capita', 'dataset': 'c6d487f0-42ad-4513-ac99-108d4c51dab1', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'type': 'leaflet', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'year', 'required': True}]}], 'body': {'url': "https://wri-rw.carto.com/api/v2/sql?q=with s as (SELECT iso, region, value, commodity FROM combined01_prepared {{where}} and impactparameter='Kcal per capita' and scenario='SSP2-MIRO' and iso is not null ), r as (SELECT iso, region, sum(value) as value FROM s group by iso, region), d as (SELECT centroid as geometry, iso, value, region FROM impact_regions_159 t inner join r on new_region=iso) select json_build_object('type','FeatureCollection','features',json_agg(json_build_object('geometry',cast(geometry as json),'properties', json_build_object('value',value,'country',region,'iso',iso, 'unit', 'Kilocalories per person'),'type','Feature'))) as data from d", 'use_cors': False}}, 'legendConfig': {'items': [{'color': 'rgba(53, 89, 161, 0.85)', 'name': 'Kcal per person'}], 'units': 'kcal/person/day', 'description': 'Kilocalories per person represents the average availability of calories per person, by country. Note that it is not crop specific.', 'type': 'cluster'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:27.010Z', 'updatedAt': '2021-02-24T09:27:27.010Z'}}}
# {'data': {'id': '91659d99-2160-4f80-9475-06e0ddbba862', 'type': 'layer', 'attributes': {'name': 'Pop. at risk of hunger', 'slug': 'Pop-at-risk-of-hunger_1', 'dataset': '57748f05-aa1d-476f-9044-9ae9ca8a09c5', 'application': ['aqueduct'], 'iso': [], 'provider': 'cartodb', 'userId': '57a0aa1071e394dd32ffe137', 'default': True, 'protected': False, 'published': True, 'env': 'production', 'layerConfig': {'type': 'leaflet', 'params_config': [], 'sql_config': [{'key': 'where', 'key_params': [{'key': 'year', 'required': True}]}], 'body': {'url': "https://wri-rw.carto.com/api/v2/sql?q=with s as (SELECT iso, region, value, commodity FROM combined01_prepared {{where}} and impactparameter='Share Pop. at risk of hunger' and scenario='SSP2-MIRO' and iso is not null ), r as (SELECT iso, region, sum(value) as value FROM s group by iso, region), d as (SELECT centroid as geometry, iso, value, region FROM impact_regions_159 t inner join r on new_region=iso) select json_build_object('type','FeatureCollection','features',json_agg(json_build_object('geometry',cast(geometry as json),'properties', json_build_object('value',value,'country',region,'iso',iso, 'unit', 'percentage'),'type','Feature'))) as data from d", 'use_cors': False}}, 'legendConfig': {'items': [{'color': 'rgba(53, 89, 161, 0.85)', 'name': 'Pop. at risk of hunger'}], 'units': '%', 'description': "Pop. at risk of hunger represents the percentage of each country's population at risk of suffering from malnourishment. Note that it is not crop specific.", 'type': 'cluster'}, 'interactionConfig': {}, 'applicationConfig': {}, 'staticImageConfig': {}, 'createdAt': '2021-02-24T09:27:28.577Z', 'updatedAt': '2021-02-24T09:27:28.577Z'}}}

# %%
with open(f'AQ_prod_staging_match_{datetime.now().strftime("%Y%m%d-%H%M%S")}.json', 'w') as outfile:
    json.dump(resources, outfile)

# %% [markdown]
# ## Also layers ids need to be updated in the food app every time this operation happens.

# %% [markdown]
# ## Don't forget to run the migration of AQ flood layers as they are also contained in the same app.

# %% [markdown]
# [AQ3-EE_layers_to_RW_API.ipynb](./AQ3-EE_layers_to_RW_API.ipynb)
# ## and dataset id changed everytime this is rerun
