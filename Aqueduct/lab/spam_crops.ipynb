# %% [markdown]
# # Table of Contents
#  <p>

# %%
import requests
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
from IPython.display import display

# %% [markdown]
# This script will be use to download all csv related SPAM crops. We are only fetching for the csv as we alredy have the geometries.
#
# The next figure will hold all configurations needed to download the data.To do so we will need to compund this url:
# ```
# http://spam05.harvestchoice.org/v2r0/csv/<areas>/spam2005v2r0_<areas>_<crop>_<types>.csv.gz
# ```
# example:
# http://spam05.harvestchoice.org/v2r0/csv/physical-area/spam2005v2r0_physical-area_cereals_other_total.csv.gz
#
# So we will need to identify wich variables we need.
# * [Areas](http://mapspam.info/methodology/#physical_area) list of available SPAM outputs:
#
# |name| available for download |description|
# |:---|:---|:---|
# |PHYSICAL AREA| physical-area|Physical area is measured in hectare, and represents the actual area where a crop is grown, not counting how often production was harvested from it. Physical area is calculated for each  production system and crop, and the sum of all physical areas of the four production systems constitute the total physical area for that crop. The sum of the physical areas of all crops in a pixel may not be larger than the pixel size.|
# |HARVESTED AREA|harvested-area|Also measured in hectare, harvested area is at least as large as physical area, but sometimes more, since it also accounts for multiple harvests of a crop on the same plot. Like for physical area, the harvested area is calculated for each production system, and the sum of all harvested areas of all production systems in a pixel amount to the total harvested area of the pixel.|
# |PRODUCTION| production|Production, for each production system and crop, is calculated by multiplying area harvested with yield. It is measured in metric tons. The total production of a crop includes the production of all production systems of that crop.|
# |YIELD| yield|Yield is a measure of productivity, the amount of production per harvested area, and is measured in kilogram/hectare. The total yield of a crop, when considering all production systems, is not the sum of the individual yields, but the weighted average of the 4 yields|
#
# * [Crops](http://mapspam.info/wp-content/uploads/4-Methodology-Crops-of-SPAM-2005-2015-02-26.csv): list of available crops
#
# * [types](http://mapspam.info/methodology/#irrigation_areas): list of available production systems
#
# |name| available for download |
# |:---|:---|
# |Irrigated|irrigated|
# |Rainfed|rainfed|
# |Total|total|

# %%
baseUrl = 'http://spam05.harvestchoice.org/v2r0/csv/'
basefile = os.getcwd().split('work')[0] + '/work/data/aqueduct/dst/spam/crops/'
filename = 'harvested-area_banana_total.csv.gz'
areas = ['production']
crops = ['cereals_other', 'pulses_other', 'banana', 'barley', 'bean', 'cassava', 'chickpea', 'cowpea', 'groundnut', 
         'lentil', 'maize', 'millet_pearl', 'millet_small', 'pigeonpea', 'plantain', 'potato', 'rice', 'sorghum', 'soybean', 'sweet_potato',
         'wheat', 'yam']  
types = ['irrigated','rainfed']

# %%
for typez in range(0,len(types)):
    for area in range(0,len(areas)):
        for crop in range(0,len(crops)):
            dataUrl=baseUrl+areas[area]+'/'+'spam2005v2r0'+'_'+areas[area]+'_'+crops[crop]+'_'+types[typez]+'.csv.gz'
            response = requests.get(dataUrl, stream=True)
            filename=areas[area]+'_'+crops[crop]+'_'+types[typez]+'.csv.gz'
            print(filename)
            with open(filename, 'wb') as handle:
                for chunk in tqdm(response.iter_content(chunk_size=128)):
                    handle.write(chunk)
# Out:
# 111it [00:00, 794.86it/s]
# production_cereals_other_irrigated.csv.gz
# 53645it [00:08, 6128.52it/s]
# 111it [00:00, 767.37it/s]
# production_pulses_other_irrigated.csv.gz
# 52560it [00:05, 10373.13it/s]
# 111it [00:00, 760.83it/s]
# production_banana_irrigated.csv.gz
# 50645it [00:08, 6063.28it/s]
# 111it [00:00, 770.28it/s]
# production_barley_irrigated.csv.gz
# 52481it [00:04, 12243.70it/s]
# 111it [00:00, 769.95it/s]
# production_bean_irrigated.csv.gz
# 53254it [00:03, 14073.16it/s]
# 0it [00:00, ?it/s]
# production_cassava_irrigated.csv.gz
# 50323it [00:06, 8368.06it/s]
# 111it [00:00, 769.71it/s]
# production_chickpea_irrigated.csv.gz
# 51361it [00:03, 13121.17it/s]
# 111it [00:00, 761.50it/s]
# production_cowpea_irrigated.csv.gz
# 50148it [00:03, 13971.75it/s]
# 111it [00:00, 770.32it/s]
# production_groundnut_irrigated.csv.gz
# 51250it [00:03, 14586.63it/s]
# 0it [00:00, ?it/s]
# production_lentil_irrigated.csv.gz
# 51120it [00:03, 13937.97it/s]
# 111it [00:00, 790.91it/s]
# production_maize_irrigated.csv.gz
# 56738it [00:03, 15677.61it/s]
# 111it [00:00, 762.69it/s]
# production_millet_pearl_irrigated.csv.gz
# 50327it [00:03, 14906.72it/s]
# 0it [00:00, ?it/s]
# production_millet_small_irrigated.csv.gz
# 49985it [00:03, 14594.17it/s]
# 0it [00:00, ?it/s]
# production_pigeonpea_irrigated.csv.gz
# 50490it [00:03, 14543.33it/s]
# 111it [00:00, 774.35it/s]
# production_plantain_irrigated.csv.gz
# 49987it [00:05, 8388.88it/s]
# 111it [00:00, 768.85it/s]
# production_potato_irrigated.csv.gz
# 55106it [00:04, 13070.74it/s]
# 111it [00:00, 675.76it/s]
# production_rice_irrigated.csv.gz
# 55226it [00:07, 7338.62it/s]
# 111it [00:00, 681.65it/s]
# production_sorghum_irrigated.csv.gz
# 52031it [00:07, 6973.06it/s]
# 111it [00:00, 767.66it/s]
# production_soybean_irrigated.csv.gz
# 52412it [00:07, 7095.57it/s]
# 0it [00:00, ?it/s]
# production_sweet_potato_irrigated.csv.gz
# 50412it [00:05, 8506.92it/s]
# 111it [00:00, 771.78it/s]
# production_wheat_irrigated.csv.gz
# 55599it [00:04, 12278.10it/s]
# 111it [00:00, 766.12it/s]
# production_yam_irrigated.csv.gz
# 49871it [00:04, 12105.58it/s]
# 111it [00:00, 764.26it/s]
# production_cereals_other_rainfed.csv.gz
# 58994it [00:03, 15058.15it/s]
# 111it [00:00, 629.19it/s]
# production_pulses_other_rainfed.csv.gz
# 57724it [00:03, 15919.92it/s]
# 111it [00:00, 767.73it/s]
# production_banana_rainfed.csv.gz
# 54729it [00:07, 7328.11it/s]
# 0it [00:00, ?it/s]
# production_barley_rainfed.csv.gz
# 59759it [00:04, 12178.98it/s]
# 111it [00:00, 769.70it/s]
# production_bean_rainfed.csv.gz
# 59323it [00:06, 8927.57it/s]
# 111it [00:00, 771.44it/s]
# production_cassava_rainfed.csv.gz
# 56768it [00:04, 13122.11it/s]
# 111it [00:00, 686.76it/s]
# production_chickpea_rainfed.csv.gz
# 52635it [00:10, 5029.07it/s]
# 111it [00:00, 772.37it/s]
# production_cowpea_rainfed.csv.gz
# 51770it [00:08, 6459.46it/s]
# 111it [00:00, 772.98it/s]
# production_groundnut_rainfed.csv.gz
# 56398it [00:04, 11747.52it/s]
# 111it [00:00, 767.94it/s]
# production_lentil_rainfed.csv.gz
# 52613it [00:03, 15989.49it/s]
# 111it [00:00, 606.30it/s]
# production_maize_rainfed.csv.gz
# 65212it [00:08, 8071.88it/s]
# 111it [00:00, 767.67it/s]
# production_millet_pearl_rainfed.csv.gz
# 53003it [00:04, 12368.10it/s]
# 111it [00:00, 766.16it/s]
# production_millet_small_rainfed.csv.gz
# 52311it [00:03, 14346.03it/s]
# 0it [00:00, ?it/s]
# production_pigeonpea_rainfed.csv.gz
# 51188it [00:03, 14279.71it/s]
# 0it [00:00, ?it/s]
# production_plantain_rainfed.csv.gz
# 52012it [00:03, 14758.38it/s]
# 111it [00:00, 767.36it/s]
# production_potato_rainfed.csv.gz
# 60788it [00:05, 10682.15it/s]
# 0it [00:00, ?it/s]
# production_rice_rainfed.csv.gz
# 57014it [00:03, 14367.94it/s]
# 111it [00:00, 638.09it/s]
# production_sorghum_rainfed.csv.gz
# 58351it [00:03, 16078.31it/s]
# 111it [00:00, 766.05it/s]
# production_soybean_rainfed.csv.gz
# 58898it [00:03, 16568.72it/s]
# 111it [00:00, 765.50it/s]
# production_sweet_potato_rainfed.csv.gz
# 55648it [00:03, 16058.77it/s]
# 0it [00:00, ?it/s]
# production_wheat_rainfed.csv.gz
# 62736it [00:03, 17009.47it/s]
# 111it [00:00, 766.92it/s]
# production_yam_rainfed.csv.gz
# 51896it [00:03, 14419.81it/s]

# %%
! gunzip *.gz #command line to uncompress and deleted compresed files

# %%
test = pd.read_csv('production_cereals_other_irrigated.csv', sep=',', index_col=False)
test.head()
# Out:
#       cell5m  alloc_key iso3 prod_level  ocer_i unit     name_adm1 name_adm2  \
# 0  1895787.0    4393628  CHN    CH08078     0.0   mt  Heilongjiang  Mohexian
# 1  1895788.0    4393629  CHN    CH08078     0.0   mt  Heilongjiang  Mohexian
# 2  1895793.0    4393634  CHN    CH08078     0.0   mt  Heilongjiang  Mohexian
# 3  1895796.0    4393637  CHN    CH08078     0.0   mt  Heilongjiang  Mohexian
# 4  1895797.0    4393638  CHN    CH08078     0.0   mt  Heilongjiang  Mohexian
#
#               crea_date name_cntr
# 0  02/16/15 09:39:14 PM     China
# 1  02/16/15 09:39:14 PM     China
# 2  02/16/15 09:39:14 PM     China
# 3  02/16/15 09:39:14 PM     China
# 4  02/16/15 09:39:14 PM     China

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820517 entries, 0 to 820516
# Data columns (total 10 columns):
# cell5m        820517 non-null float64
# alloc_key     820517 non-null int64
# iso3          820517 non-null object
# prod_level    820517 non-null object
# ocer_i        820517 non-null float64
# unit          820517 non-null object
# name_adm1     820517 non-null object
# name_adm2     820517 non-null object
# crea_date     820517 non-null object
# name_cntr     820517 non-null object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 62.6+ MB

# %%
test.columns.values
# Out:
# array(['cell5m', 'alloc_key', 'iso3', 'prod_level', 'ocer_i', 'unit',
#        'name_adm1', 'name_adm2', 'crea_date', 'name_cntr'], dtype=object)

# %% [markdown]
# ##### After downloading the data we will unzip, and merge them together into one file.

# %%
baseUrl = './production'
## This will loop over all csv files and will extract the information required to merge them together into total_crops.csv.
data=[]
for typez in range(0,len(types)):
    for crop in range(0,len(crops)):
        dataUrl=baseUrl+'_'+crops[crop]+'_'+types[typez]+'.csv'
        print(dataUrl)
        a=pd.read_csv(dataUrl, sep=',')
        a['irrigation'] = np.where(a['cell5m']>0, types[typez], types[typez])
        a['crop'] = np.where(a['cell5m']>0, crops[crop], crops[crop])
        a.columns.values[4] = 'value'
        a.loc[a['value'] > 0]
        data.append(a)

output = pd.concat(data)

output.to_csv(basefile+'/dst/data_filtered.csv', sep=',')
# Out:
# ./production_cereals_other_irrigated.csv
# ./production_pulses_other_irrigated.csv
# ./production_banana_irrigated.csv
# ./production_barley_irrigated.csv
# ./production_bean_irrigated.csv
# ./production_cassava_irrigated.csv
# ./production_chickpea_irrigated.csv
# ./production_cowpea_irrigated.csv
# ./production_groundnut_irrigated.csv
# ./production_lentil_irrigated.csv
# ./production_maize_irrigated.csv
# ./production_millet_pearl_irrigated.csv
# ./production_millet_small_irrigated.csv
# ./production_pigeonpea_irrigated.csv
# ./production_plantain_irrigated.csv
# ./production_potato_irrigated.csv
# ./production_rice_irrigated.csv
# ./production_sorghum_irrigated.csv
# ./production_soybean_irrigated.csv
# ./production_sweet_potato_irrigated.csv
# ./production_wheat_irrigated.csv
# ./production_yam_irrigated.csv
# ./production_cereals_other_rainfed.csv
# ./production_pulses_other_rainfed.csv
# ./production_banana_rainfed.csv
# ./production_barley_rainfed.csv
# ./production_bean_rainfed.csv
# ./production_cassava_rainfed.csv
# ./production_chickpea_rainfed.csv
# ./production_cowpea_rainfed.csv
# ./production_groundnut_rainfed.csv
# ./production_lentil_rainfed.csv
# ./production_maize_rainfed.csv
# ./production_millet_pearl_rainfed.csv
# ./production_millet_small_rainfed.csv
# ./production_pigeonpea_rainfed.csv
# ./production_plantain_rainfed.csv
# ./production_potato_rainfed.csv
# ./production_rice_rainfed.csv
# ./production_sorghum_rainfed.csv
# ./production_soybean_rainfed.csv
# ./production_sweet_potato_rainfed.csv
# ./production_wheat_rainfed.csv
# ./production_yam_rainfed.csv

# %%
# !rm *.csv                               #command line

# %% [markdown]
# ##### Here we will select all cells that have physical area bigger that 10 ha and will save it onto data_filtered.csv

# %%
a = pd.read_csv(basefile+'/dst/data_filtered.csv', sep=',', index_col=False)

# %%
a.head()
# Out:
#    Unnamed: 0     cell5m  alloc_key iso3 prod_level  value unit     name_adm1  \
# 0           0  1895787.0    4393628  CHN    CH08078    0.0   mt  Heilongjiang
# 1           1  1895788.0    4393629  CHN    CH08078    0.0   mt  Heilongjiang
# 2           2  1895793.0    4393634  CHN    CH08078    0.0   mt  Heilongjiang
# 3           3  1895796.0    4393637  CHN    CH08078    0.0   mt  Heilongjiang
# 4           4  1895797.0    4393638  CHN    CH08078    0.0   mt  Heilongjiang
#
#   name_adm2             crea_date name_cntr irrigation           crop
# 0  Mohexian  02/16/15 09:39:14 PM     China  irrigated  cereals_other
# 1  Mohexian  02/16/15 09:39:14 PM     China  irrigated  cereals_other
# 2  Mohexian  02/16/15 09:39:14 PM     China  irrigated  cereals_other
# 3  Mohexian  02/16/15 09:39:14 PM     China  irrigated  cereals_other
# 4  Mohexian  02/16/15 09:39:14 PM     China  irrigated  cereals_other

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36102748 entries, 0 to 36102747
# Data columns (total 13 columns):
# Unnamed: 0    int64
# cell5m        float64
# alloc_key     int64
# iso3          object
# prod_level    object
# value         float64
# unit          object
# name_adm1     object
# name_adm2     object
# crea_date     object
# name_cntr     object
# irrigation    object
# crop          object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 3.5+ GB

# %%
a.value.max()
# Out:
# 328704.70000000001

# %%
a.value.min()
# Out:
# 0.0

# %%
zzz = a[a['value'] >= 10]

# %%
zzz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3775486 entries, 1192 to 35996882
# Data columns (total 8 columns):
# cell5m        float64
# alloc_key     int64
# iso3          object
# value         float64
# unit          object
# crea_date     object
# irrigation    object
# crop          object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 259.2+ MB

# %%
#del zzz['Unnamed: 0']
#del zzz['prod_level']
#del zzz['name_adm1']
#del zzz['name_adm2']
#del zzz['name_cntr']
del zzz['crea_date']
zzz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3775486 entries, 1192 to 35996882
# Data columns (total 7 columns):
# cell5m        float64
# alloc_key     int64
# iso3          object
# value         float64
# unit          object
# irrigation    object
# crop          object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 230.4+ MB

# %%
zzz.to_csv(basefile+'/dst/data_filtered_prod.csv', sep=',')

# %%
# !ls
# Out:
# AQ-1_Combined01_Ifript.ipynb         crop table.ipynb
# AQ1.- Layers definition.ipynb        crop_list_match.ipynb
# AQ1.-Widgets_queries.ipynb           data_download.ipynb
# AQ1.-data_model.ipynb                geometry_intersection.ipynb
# AQ1_widget_exploration.ipynb         geometry_intersection.py
# AQ_2_Layer_definition.ipynb          ifript_data_treatment.ipynb
# AQ_2_Points_intersection.ipynb       insert_query.ipynb
# AQ_2_Weights.ipynb                   spam_crops.ipynb
# HL5Y510A14UMVLTW6EINVGT83ATDHN25.png spam_download_script.ipynb
# UV3K4WUEWQH3FWH5DTUJ264URNNLE9QC.png water_risk_cleanup.ipynb
# analysis_microservice.ipynb

# %%
r = pd.read_csv(basefile+'/dst/data_filtered_prod.csv', sep=',', index_col=False)
# Out:
# /Users/vizzuality/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3,4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# 162542   United States Of America  irrigated  barley
# 162543   United States Of America  irrigated  barley
# 162544   United States Of America  irrigated  barley
# 162545   United States Of America  irrigated  barley
# 162546   United States Of America  irrigated  barley
# ...                           ...        ...     ...
# 4681425                     China    rainfed   wheat
# 4681426                     China    rainfed   wheat
# 4681427                     China    rainfed   wheat
# 4681428                     China    rainfed   wheat
# 4681429                     China    rainfed   wheat
# 4681430                     China    rainfed   wheat
# 4681431                     China    rainfed   wheat
# 4681432                     China    rainfed   wheat
# 4681433                     China    rainfed   wheat
# 4681435                     China    rainfed   wheat
# 4681436                     China    rainfed   wheat
# 4681439                     China    rainfed   wheat
# 4681449                     China    rainfed   wheat
# 4681450                     China    rainfed   wheat
# 4681451                     China    rainfed   wheat
# 4681453                     China    rainfed   wheat
# 4681454                     China    rainfed   wheat
# 4681456                     China    rainfed   wheat
# 4681462                     China    rainfed   wheat
# 4681463                     China    rainfed   wheat
# 4681465                     China    rainfed   wheat
# 4681471                     China    rainfed   wheat
# 4681472                     China    rainfed   wheat
# 4681473                     China    rainfed   wheat
# 4681476                     China    rainfed   wheat
# 4681477                     China    rainfed   wheat
# 4681478                     China    rainfed   wheat
# 4681479                     China    rainfed   wheat
# 4681480                     China    rainfed   wheat
# 4681481                     China    rainfed   wheat
#
# [392817 rows x 15 columns]

# %%
aa = r[r.value >= 10]

# %%
aa
# Out:
#          Unnamed: 0  Unnamed: 0.1       cell5m alloc_key iso3 prod_level  \
# 0              2875        2875.0    4158520.0   9632681  SOM    SO18002
# 1             22857       22857.0    4780536.0  11072617  KEN    KE03005
# 2             48803       48803.0    2893110.0   6703031  PAK    PK04004
# 3             49579       49579.0    2901754.0   6723035  PAK    PK04009
# 4             49968       49968.0    2906073.0   6733034  PAK    PK04009
# 5             49969       49969.0    2906074.0   6733035  PAK    PK04009
# 6             50355       50355.0    2910393.0   6743034  PAK    PK05001
# 7             50356       50356.0    2910394.0   6743035  PAK    PK04009
# 8             50704       50704.0    2914712.0   6753033  PAK    PK05028
# 9             50705       50705.0    2914713.0   6753034  PAK    PK05028
# 10            51400       51400.0    2923336.0   6773017  PAK    PK04011
# 11            51771       51771.0    2927669.0   6783030  PAK    PK05001
# 12            52157       52157.0    2931989.0   6793030  PAK    PK05001
# 13            55353       55353.0    2966569.0   6873050  PAK    PK05009
# 14            55759       55759.0    2970891.0   6883052  PAK    PK05009
# 15            55760       55760.0    2970892.0   6883053  PAK    PK05009
# 16            55761       55761.0    2970893.0   6883054  PAK    PK05032
# 17            56159       56159.0    2975214.0   6893055  PAK    PK05032
# 18            56160       56160.0    2975215.0   6893056  PAK    PK05032
# 19            56565       56565.0    2979535.0   6903056  PAK    PK05032
# 20            56972       56972.0    2983855.0   6913056  PAK    PK05032
# 21            56973       56973.0    2983856.0   6913057  PAK    PK05032
# 22            56974       56974.0    2983857.0   6913058  PAK    PK05032
# 23            56975       56975.0    2983858.0   6913059  PAK    PK05032
# 17                             Pakistan  irrigated  banana
# 18                             Pakistan  irrigated  banana
# 19                             Pakistan  irrigated  banana
# 20                             Pakistan  irrigated  banana
# 21                             Pakistan  irrigated  banana
# 22                             Pakistan  irrigated  banana
# 23                             Pakistan  irrigated  banana
# 24                             Pakistan  irrigated  banana
# 25                             Pakistan  irrigated  banana
# 26                             Pakistan  irrigated  banana
# 27                             Pakistan  irrigated  banana
# 28                             Pakistan  irrigated  banana
# 29                             Pakistan  irrigated  banana
# ...                                 ...        ...     ...
# 5668022  Democratic Republic Of The Con    rainfed     yam
# 5668023  Democratic Republic Of The Con    rainfed     yam
# 5668024  Democratic Republic Of The Con    rainfed     yam
# 5668025  Democratic Republic Of The Con    rainfed     yam
# 5668026  Democratic Republic Of The Con    rainfed     yam
# 5668027  Democratic Republic Of The Con    rainfed     yam
# 5668028  Democratic Republic Of The Con    rainfed     yam
# 5668029  Democratic Republic Of The Con    rainfed     yam
# 5668030  Democratic Republic Of The Con    rainfed     yam
# 5668031  Democratic Republic Of The Con    rainfed     yam
# 5668032  Democratic Republic Of The Con    rainfed     yam
# 5668033  Democratic Republic Of The Con    rainfed     yam
# 5668034  Democratic Republic Of The Con    rainfed     yam
# 5668035  Democratic Republic Of The Con    rainfed     yam
# 5668036  Democratic Republic Of The Con    rainfed     yam
# 5668037  Democratic Republic Of The Con    rainfed     yam
# 5668038  Democratic Republic Of The Con    rainfed     yam
# 5668039  Democratic Republic Of The Con    rainfed     yam
# 5668040  Democratic Republic Of The Con    rainfed     yam
# 5668041  Democratic Republic Of The Con    rainfed     yam
# 5668042  Democratic Republic Of The Con    rainfed     yam
# 5668043  Democratic Republic Of The Con    rainfed     yam
# 5668044  Democratic Republic Of The Con    rainfed     yam
# 5668045  Democratic Republic Of The Con    rainfed     yam
# 5668046  Democratic Republic Of The Con    rainfed     yam
# 5668047  Democratic Republic Of The Con    rainfed     yam
# 5668048  Democratic Republic Of The Con    rainfed     yam
# 5668049  Democratic Republic Of The Con    rainfed     yam
# 5668050  Democratic Republic Of The Con    rainfed     yam
# 5668051  Democratic Republic Of The Con    rainfed     yam
#
# [5057526 rows x 14 columns]

# %%
def split_table(dataset_url, name):
    """
    this function splits a table in x datasets to make it uploable to a carto account
    """
    size=1000000
    dataset_data=[]
    format_file = dataset_url.split('.')[1]
    geometry_formats=['shp']
    nongeo_formats=['csv']
    print('---------------------')
    if format_file in nongeo_formats:
        dataset = pd.read_csv(dataset_url, sep=',')
        rows, columns = dataset.shape
        ra=list(range(0, rows+1, size))
        print(ra)
        if (rows%size)>0:
            ra.append(rows+1)
        print('---------------------')
        for i, data in enumerate(ra):
            if i<(len(ra)-1):
                split_dataset_name = 'split'+'_'+name+'_'+str(i)+'.csv'
                full_d_path = basefile+'dst/'+split_dataset_name
                s = dataset.iloc[ra[i]:ra[i+1]]
                display(s.info()),
                s.to_csv(full_d_path)
                dataset_data.append({"part_name":split_dataset_name,"path":full_d_path})
        return {"table_name":name,"parts":dataset_data}
    elif format_file in geometry_formats:
        dataset = gpd.read_file(dataset_url)
        rows, columns = dataset.shape
        ra=list(range(0, rows+1, size))
        print(ra)
        if (rows%size)>0:
            ra.append(rows+1)
        print('---------------------')
        for i, data in enumerate(ra):
            if i<(len(ra)-1):
                split_dataset_name = 'split'+'_'+name+'_'+str(i)+'.shp'
                full_d_path = basefile+'dst/'+split_dataset_name
                dataset.iloc[:,ra[i]:ra[i+1]].to_file(full_d_path)
                dataset_data.append({"part_name":split_dataset_name,"path":full_d_path})
        return {"table_name":name,"parts":dataset_data}
    else:
        raise ValueError
        print('format not supported')

# %%
 split_table(basefile+'/dst/data_filtered_prod.csv', 'data_filtered_prod')
# Out:
# ---------------------
# [0, 1000000, 2000000, 3000000]
# ---------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
# Unnamed: 0    1000000 non-null int64
# cell5m        1000000 non-null float64
# alloc_key     1000000 non-null int64
# iso3          1000000 non-null object
# value         1000000 non-null float64
# unit          1000000 non-null object
# irrigation    1000000 non-null object
# crop          1000000 non-null object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 61.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 1000000 to 1999999
# Data columns (total 8 columns):
# Unnamed: 0    1000000 non-null int64
# cell5m        1000000 non-null float64
# alloc_key     1000000 non-null int64
# iso3          1000000 non-null object
# value         1000000 non-null float64
# unit          1000000 non-null object
# irrigation    1000000 non-null object
# crop          1000000 non-null object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 61.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 2000000 to 2999999
# Data columns (total 8 columns):
# Unnamed: 0    1000000 non-null int64
# cell5m        1000000 non-null float64
# alloc_key     1000000 non-null int64
# iso3          1000000 non-null object
# value         1000000 non-null float64
# unit          1000000 non-null object
# irrigation    1000000 non-null object
# crop          1000000 non-null object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 61.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775486 entries, 3000000 to 3775485
# Data columns (total 8 columns):
# Unnamed: 0    775486 non-null int64
# cell5m        775486 non-null float64
# alloc_key     775486 non-null int64
# iso3          775486 non-null object
# value         775486 non-null float64
# unit          775486 non-null object
# irrigation    775486 non-null object
# crop          775486 non-null object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 47.3+ MB
# None
# {'parts': [{'part_name': 'split_data_filtered_prod_0.csv',
#    'path': '/Users/alicia/Projects/jupyter-geotools-alpine//work/data/aqueduct/dst/spam/crops/dst/split_data_filtered_prod_0.csv'},
#   {'part_name': 'split_data_filtered_prod_1.csv',
#    'path': '/Users/alicia/Projects/jupyter-geotools-alpine//work/data/aqueduct/dst/spam/crops/dst/split_data_filtered_prod_1.csv'},
#   {'part_name': 'split_data_filtered_prod_2.csv',
#    'path': '/Users/alicia/Projects/jupyter-geotools-alpine//work/data/aqueduct/dst/spam/crops/dst/split_data_filtered_prod_2.csv'},
#   {'part_name': 'split_data_filtered_prod_3.csv',
#    'path': '/Users/alicia/Projects/jupyter-geotools-alpine//work/data/aqueduct/dst/spam/crops/dst/split_data_filtered_prod_3.csv'}],
#  'table_name': 'data_filtered_prod'}

# %%
aa.to_csv('data_filtered.csv', sep=',')
