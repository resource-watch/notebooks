# %%
import pandas as pd
import json
import requests
import numpy as np
import LMIPy

# %% [markdown]
# # Layers definition
#
# **SPAM 2010 crop structure:**
#
# |Cereals | Pulses And Legumes | Roots And Tubers | Fruit And Nuts | Oilseed Crops | Sugar Crops | Fibres | Stimulants | Vegetables |Other Crops |
# |:---|:---|:---|:---|:---|:---|:---|:---|:---|:---|
# | wheat         | bean         | potato       | banana          | soybean         | sugarcane | cotton            | arabica coffee | vegetables | rest of crops |
# | rice          | chickpea     | sweet potato | plantain        | groundnut       | sugarbeet | other fibre crops | robusta coffee | -          | -             |
# | maize         | cowpea       | yams         | tropical fruit  | coconut         | -         | -                 | cocoa          | -          | -             |
# | barley        | pigeonpea    | cassava      | temperate fruit | oilpalm         | -         | -                 | tea            | -          | -             |
# | pearl millet  | lentil       | other roots  | -               | sunflower       | -         | -                 | tobacco        | -          | -             |
# | small millet  | other pulses | -            | -               | rapeseed        | -         | -                 | -              | -          | -             |
# | sorghum       | -            | -            | -               | sesameseed      | -         | -                 | -              | -          | -             |
# | other cereals | -            | -            | -               | other oil crops | -         | -                 | -              | -          | -             |

# %% [markdown]
# ## Crop layers (Water Risk & Food Security unselected)
#
# * **Account:** wri-rw
# * **Table Name:** crops_projected
# * **Dataset_id:** [a57a457a-cee7-44a6-af0a-5c27176e0ec0](https://staging-api.globalforestwatch.org/v1/dataset/a57a457a-cee7-44a6-af0a-5c27176e0ec0)
#
# ### All crops layer
#
# * **Layer_id:** [a533c717-8473-412c-add8-89b0a008e3ac](https://staging-api.globalforestwatch.org/v1/layer/a533c717-8473-412c-add8-89b0a008e3ac)
#
# `Sql:`
# ```sql
# SELECT * FROM crops_projected WHERE rank='1'
# ```
#
# `Sql Template:`
# ```sql
# SELECT * FROM crops_projected WHERE rank='1' {{and}}
# ```
#
# `sql_config:`
# ```json
# "sql_config": [{
#     "key": "and",
#     "key_params": [
#         {
#             "required": False,
#             "key": "iso"
#         },
#         {
#             "required": False,
#             "key": "irrigation"
#         }
#     ]
# }],
# ```
#
# `Cartocss:`
# ```css
# #layer {
#     polygon-fill: ramp([crop], (#4B0082, #800080, #C71585, #DB7093, #FF1493, #FF69B4, #FFB6C1, #FFC0CB, #00008B, #0000CD, #0000FF, #1E90FF, #00BFFF, #800000, #8B0000, #A52A2A, #B22222, #DC143C, #FFD700, #FFA500, #FF8C00, #FF6347, #006400, #228B22, #6B8E23, #556B2F, #808000, #2E8B57, #3CB371, #8FBC8F, #FFDAB9, #FFE4B5, #E6E6FA, #FFF0F5, #A0522D, #8B4513, #D2691E, #CD853F, #DAA520, #008000, #2F4F4F), ('wheat', 'rice', 'maize', 'barley', 'pearl millet', 'small millet', 'sorghum', 'other cereals', 'bean', 'chickpea', 'cowpea', 'pigeonpea', 'other pulses', 'potato', 'sweet potato', 'yams', 'cassava', 'other roots', 'banana', 'plantain', 'tropical fruit', 'temperate fruit', 'soybean', 'groundnut', 'coconut', 'oilpalm', 'sunflower', 'rapeseed', 'sesameseed', 'other oil crops', 'sugarcane', 'sugarbeet', 'cotton', 'other fibre crops', 'arabica coffee', 'robusta coffee', 'cocoa', 'tea', 'tobacco', 'vegetables', 'rest of crops'), '=');
#     line-color: ramp([crop], (#4B0082, #800080, #C71585, #DB7093, #FF1493, #FF69B4, #FFB6C1, #FFC0CB, #00008B, #0000CD, #0000FF, #1E90FF, #00BFFF, #800000, #8B0000, #A52A2A, #B22222, #DC143C, #FFD700, #FFA500, #FF8C00, #FF6347, #006400, #228B22, #6B8E23, #556B2F, #808000, #2E8B57, #3CB371, #8FBC8F, #FFDAB9, #FFE4B5, #E6E6FA, #FFF0F5, #A0522D, #8B4513, #D2691E, #CD853F, #DAA520, #008000, #2F4F4F), ('wheat', 'rice', 'maize', 'barley', 'pearl millet', 'small millet', 'sorghum', 'other cereals', 'bean', 'chickpea', 'cowpea', 'pigeonpea', 'other pulses', 'potato', 'sweet potato', 'yams', 'cassava', 'other roots', 'banana', 'plantain', 'tropical fruit', 'temperate fruit', 'soybean', 'groundnut', 'coconut', 'oilpalm', 'sunflower', 'rapeseed', 'sesameseed', 'other oil crops', 'sugarcane', 'sugarbeet', 'cotton', 'other fibre crops', 'arabica coffee', 'robusta coffee', 'cocoa', 'tea', 'tobacco', 'vegetables', 'rest of crops'), '=');}
# ```
#
# `legenConfig:`
# ```json
# "legendConfig": {
#     "type": "group",
#     "items": [
#         {
#             "name": "Cereals",
#             "color": "#C71585",
#             "items": [
#                 {
#                     "name": "Wheat",
#                     "color": "#4B0082"
#                 },
#                 {
#                     "name": "Rice",
#                     "color": "#800080"
#                 },
#                 {
#                     "name": "Maize",
#                     "color": "#C71585"
#                 },
#                 {
#                     "name": "Barley",
#                     "color": "#DB7093"
#                 },
#                 {
#                     "name": "Pearl millet",
#                     "color": "#FF1493"
#                 },
#                 {
#                     "name": "Small millet",
#                     "color": "#FF69B4"
#                 },
#                 {
#                     "name": "Sorghum",
#                     "color": "#FFB6C1"
#                 },
#                 {
#                     "name": "Other cereals",
#                     "color": "#FFC0CB"
#                 }
#             ]
#         },
#         {
#             "name": "Pulses and legumes",
#             "color": "#0000FF",
#             "items": [
#                 {
#                     "name": "Beans",
#                     "color": "#00008B"
#                 },
#                 {
#                     "name": "Chickpeas",
#                     "color": "#0000CD"
#                 },
#                 {
#                     "name": "Cowpeas",
#                     "color": "#0000FF"
#                 },
#                 {
#                     "name": "Pigeonpeas",
#                     "color": "#1E90FF"
#                 },
#                 {
#                     "name": "Other pulses",
#                     "color": "#00BFFF"
#                 }
#              ]
#         },
#         {
#             "name": "Roots And Tubers",
#             "color": "#A52A2A",
#             "items": [
#                 {
#                     "name": "Potato",
#                     "color": "#800000"
#                 },
#                 {
#                     "name": "Sweet potato",
#                     "color": "#8B0000"
#                 },
#                 {
#                     "name": "Yams",
#                     "color": "#A52A2A"
#                 },
#                 {
#                     "name": "Cassava",
#                     "color": "#B22222"
#                 },
#                 {
#                     "name": "Other roots",
#                     "color": "#DC143C"
#                 }
#             ]
#         },
#         {
#             "name": "Fruit and nuts",
#             "color": "#FFA500",
#             "items": [
#                 {
#                     "name": "Banana",
#                     "color": "#FFD700"
#                 },
#                 {
#                     "name": "Plantain",
#                     "color": "#FFA500"
#                 },
#                 {
#                     "name": "Tropical fruit",
#                     "color": "#FF8C00"
#                 },
#                 {
#                     "name": "Temperate fruit",
#                     "color": "#FF6347"
#                 }
#             ]
#         },
#         {
#             "name": "Oilseed crops",
#             "color": "#6B8E23",
#             "items": [
#                 {
#                     "name": "Soybean",
#                     "color": "#006400"
#                 },
#                 {
#                     "name": "Groundnut",
#                     "color": "#228B22"
#                 },
#                 {
#                     "name": "Coconut",
#                     "color": "#6B8E23"
#                 },
#                 {
#                     "name": "Oilpalm",
#                     "color": "#556B2F"
#                 },
#                 {
#                     "name": "Sunflower",
#                     "color": "#808000"
#                 },
#                 {
#                     "name": "Rapeseed",
#                     "color": "#2E8B57"
#                 },
#                 {
#                     "name": "Sesameseed",
#                     "color": "#3CB371"
#                 },
#                 {
#                     "name": "Other oil crops",
#                     "color": "#8FBC8F"
#                 }
#             ]
#         },
#         {
#             "name": "Sugar crops",
#             "color": "#FFDAB9",
#             "items": [
#                 {
#                     "name": "Sugarcane",
#                     "color": "#FFDAB9"
#                 },
#                 {
#                     "name": "Sugarbeet",
#                     "color": "#FFE4B5"
#                 }
#             ]
#         },
#         {
#             "name": "Fibres",
#             "color": "#E6E6FA",
#             "items": [
#                 {
#                     "name": "Cotton",
#                     "color": "#E6E6FA"
#                 },
#                 {
#                     "name": "Other fibre crops",
#                     "color": "#FFF0F5"
#                 }
#             ]
#         },
#         {
#             "name": "Stimulants",
#             "color": "#8B4513",
#             "items": [
#                 {
#                     "name": "Arabica coffee",
#                     "color": "#A0522D"
#                 },
#                 {
#                     "name": "Robusta coffee",
#                     "color": "#8B4513"
#                 },
#                 {
#                     "name": "Cocoa",
#                     "color": "#D2691E"
#                 },
#                 {
#                     "name": "Tea",
#                     "color": "#CD853F"
#                 },
#                 {
#                     "name": "Tobacco",
#                     "color": "#DAA520"
#                 }
#             ]
#         },
#         {
#             "name": "Vegetables",
#             "color": "#008000",
#             "items": [
#                 {
#                     "name": "Vegetables",
#                     "color": "#008000"
#                 }
#             ]
#         },
#         {
#             "name": "Other crops",
#             "color": "#2F4F4F",
#             "items": [
#                 {
#                     "name": "Rest of crops",
#                     "color": "#2F4F4F"
#                 }
#             ]
#         }
#     ]
# },
# ```
#
# `interactionConfig:`
# ```json
# "interactionConfig": {
#   "output": [
#       {
#             "column": "name_cntr",
#             "format": None,
#             "prefix": "",
#             "property": "Country",
#             "suffix": "",
#             "type": "string"
#        },
#       {
#             "column": "crop",
#             "format": None,
#             "prefix": "",
#             "property": "Crop",
#             "suffix": "",
#             "type": "string"
#        }
#     ]
# }
# ```
#
# ### One crop layer
#
# * **Layer_id:** [064a524f-0e58-41fb-b948-f7bb66f43ef0](https://staging-api.globalforestwatch.org/v1/layer/064a524f-0e58-41fb-b948-f7bb66f43ef0)
#
# `Sql:`
# ```sql
# SELECT * FROM crops_projected WHERE crop = 'banana' and iso = 'ESP' and irrigation = 'rainfed'
# ```
#
# `Sql Template:`
# ```sql
# SELECT * FROM crops_projected {{where}}
# ```
#
# `sql_config:`
# ```json
# "sql_config": [{
#     "key": "where",
#     "key_params": [
#         {
#             "required": False,
#             "key": "iso"
#         },
#         {
#             "required": False,
#             "key": "irrigation"
#         },
#         {
#             "required": True,
#             "key": "crop"
#         }
#     ]
# }],
# ```
#
# `legenConfig:`
# ```json
# "legendConfig": {
#     "type": "choropleth",
#     "items": [],
#     "units": "metric tons of production",
#     "params_config": [],
#     "sql_config": [
#         {
#             "key": "where",
#             "key_params": [
#                 {
#                     "key": "iso",
#                     "required": False
#                 },
#                 {
#                     "key": "crop",
#                     "required": True
#                 },
#                 {
#                     "key": "irrigation",
#                     "required": False
#                 }
#             ]
#         }
#     ],
#     "sql_query": "with r as (SELECT sum(prod) val, cell5m FROM crops_projected {{where}} group by cell5m) select CDB_JenksBins(array_agg(val::numeric),5) as bucket from r where val is not null"
# }
# ```
#
# `interactionConfig:`
# ```json
# "interactionConfig": {
#   "output": [
#       {
#             "column": "name_cntr",
#             "format": None,
#             "prefix": "",
#             "property": "Country",
#             "suffix": "",
#             "type": "string"
#        },
#       {
#             "column": "prod",
#             "format": None,
#             "prefix": "",
#             "property": "Production",
#             "suffix": "mt",
#             "type": "string"
#        }
#     ]
# }
# ```

# %% [markdown]
# ## Water risk layers
# ### **Baseline**
#
# * **Account:** wri-rw
# * **Table Names:** water_risk_indicators_annual, y2018m12d06_rh_master_shape_v01, crops_projected
# * **Dataset_id:** [f0559cb4-320c-4f69-a62f-e1595623806f](https://staging-api.globalforestwatch.org/v1/dataset/f0559cb4-320c-4f69-a62f-e1595623806f)
#
# **Indicator names**
#
# |Indicator full 	                 |Indicator short    |
# |------------------------------------|-------------------|
# |Baseline Water Stress               |bws                |
# |Baseline Water Depletion            |bwd                |
# |Groundwater Table Decline           |gtd                |
# |Interannual Variability             |iav                |
# |Seasonal Variability                |sev                |
# |Drought Risk                        |drr                |
# |Riverine Flood Risk                 |rfr                |
# |Coastal Flood Risk                  |cfr                |
# |Untreated Collected Wastewater      |ucw                |
# |Coastal Eutrophication Potential    |cep                |
# |Unimproved/no drinking water        |udw                |
# |Unimproved/no sanitation            |usa                |
# |RepRisk Index                       |rri                |
#
# #### Water Stress
#
# * **Layer_id:** [1a1d4f61-f1b3-4c1a-bfb5-9d0444ecdd56](https://staging-api.globalforestwatch.org/v1/layer/1a1d4f61-f1b3-4c1a-bfb5-9d0444ecdd56)
#
# **Water Stress**:
#
# `Sql:`
# ```sql
# SELECT s.aq30_id as cartodb_id, coalesce(bws_cat, -9999) as  water_risk,  coalesce(NULLIF(bws_label,''), 'No Data') as label, r.the_geom, r.the_geom_webmercator
# FROM water_risk_indicators_annual s
# LEFT JOIN y2018m12d06_rh_master_shape_v01 r on s.aq30_id=r.aq30_id
# WHERE s.pfaf_id != -9999 and s.gid_1 != '-9999'
# ```
#
# `Cartocss :`
#
# ```css
# #water_risk_indicators_annual{
#   polygon-fill:transparent;
#   polygon-opacity: 1;
#   line-color:transparent;
#   line-width: 1;
#   line-opacity: 1;
# }
#
# #water_risk_indicators_annual [water_risk=4] { polygon-fill:#990000; line-color:#990000 }
# #water_risk_indicators_annual [water_risk=3] { polygon-fill:  #FF1900; line-color:  #FF1900 }
# #water_risk_indicators_annual [water_risk=2] { polygon-fill: #FF9900; line-color: #FF9900 }
# #water_risk_indicators_annual [water_risk=1] { polygon-fill: #FFE600; line-color:  #FFE600 }
# #water_risk_indicators_annual [water_risk=0] { polygon-fill: #FFFF99; line-color:  #FFFF99 }
# #water_risk_indicators_annual [water_risk=-1] { polygon-fill: #808080; line-color:  #808080 }
# #water_risk_indicators_annual [water_risk<-1] { polygon-fill: #4E4E4E; line-color:  #4E4E4E }
# ```
#
# **Crops**
#
# `Sql :`
# ```sql
# SELECT * FROM crops_baseline {{where}}
# ```
#
# `Cartocss:`
#
# ```css
# #layer{polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}
# ```
#
# `sql_config:`
# ```json
# "sql_config": [{
#     "key": "where",
#     "key_params": [
#         {
#             "required": False
#             "key": "iso"
#         },
#         {
#             "required": False
#             "key": "irrigation"
#         },
#         {
#             "required": False
#             "key": "crop"
#         },
#         {
#             "required": False
#             "key": "rank"
#         }
#     ]
# }],
#
# ```
# `legenConfig:`
# ```json
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#808080",
#             "name": "Arid and low water use"
#         },
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<10%)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(10-20%)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(20-40%)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(40-80%)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>80%)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# `interactionConfig:`
# ```json
# "interactionConfig": {
#   "output": [
#       {
#             "column": "label",
#             "format": None,
#             "prefix": "",
#             "property": "Category",
#             "suffix": "",
#             "type": "string"
#        },
#       {
#             "column": "name_cntr",
#             "format": None,
#             "prefix": "",
#             "property": "Country",
#             "suffix": "",
#             "type": "string"
#        },
#       {
#             "column": "crop",
#             "format": None,
#             "prefix": "",
#             "property": "Crop",
#             "suffix": "",
#             "type": "string"
#        }
#     ]
# }
# ```
#
# #### Water Depletion
#
# * **Layer_id:** [1f918367-a7b7-44b2-a1eb-4e288969563f](https://staging-api.globalforestwatch.org/v1/layer/1f918367-a7b7-44b2-a1eb-4e288969563f)
#
# Change `bws` with `bwd` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#808080",
#             "name": "Arid and low water use"
#         },
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<5%)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(5-25%)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(25-50%)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(50-75%)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>75%)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Groundwater Table Decline
#
# * **Layer_id:** [2b180d04-237e-4ed9-b7a7-a643751f0ff0](https://staging-api.globalforestwatch.org/v1/layer/2b180d04-237e-4ed9-b7a7-a643751f0ff0)
#
# Change `bws` with `gtd` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#808080",
#             "name": "Insignificant trend"
#         },
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<0 cm/y)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(0-2 cm/y)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(2-4 cm/y)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(4-8 cm/y)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>8 cm/y)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Interannual Variability
#
# * **Layer_id:** [45501a04-43ed-4026-8fa1-694ed709e08a](https://staging-api.globalforestwatch.org/v1/layer/45501a04-43ed-4026-8fa1-694ed709e08a)
#
# Change `bws` with `iav` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<0.25)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(0.25-0.50)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(0.50-0.75)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(0.75-1.00)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>1.00)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Seasonal Variability
#
# * **Layer_id:** [64f65bd0-6dc5-4ce8-9421-a8e0a1eab40c](https://staging-api.globalforestwatch.org/v1/layer/64f65bd0-6dc5-4ce8-9421-a8e0a1eab40c)
#
# Change `bws` with `sev` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<0.33)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(0.33-0.66)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(0.66-1.00)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(1.00-1.33)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>1.33)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Drought Risk
#
# * **Layer_id:** [57124c97-e121-4673-9b24-3a3c9e342477](https://staging-api.globalforestwatch.org/v1/layer/57124c97-e121-4673-9b24-3a3c9e342477)
#
# Change `bws` with `drr` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(0.0-0.2)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(0.2-0.4)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(0.4-0.6)",
#             "name": "Medium"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(0.6-0.8)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#990000",
#             "value": "(0.8-1.0)",
#             "name": "High"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Riverine Flood Risk
#
# * **Layer_id:** [5c8093ce-025e-47a7-a6c8-060e4a061a73](https://staging-api.globalforestwatch.org/v1/layer/5c8093ce-025e-47a7-a6c8-060e4a061a73)
#
# Change `bws` with `rfr` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(0 to 1 in 1,000)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(1 in 1,000 to 2 in 1,000)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(2 in 1,000 to 6 in 1,000)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(6 in 1,000 to 1 in 100)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(more than 1 in 100)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Coastal Flood Risk
#
# * **Layer_id:** [658feec8-d3c3-48aa-accf-caaddcdb9a32](https://staging-api.globalforestwatch.org/v1/layer/658feec8-d3c3-48aa-accf-caaddcdb9a32)
#
# Change `bws` with `cfr` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(0 to 9 in 1,000,000)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(9 in 1,000,000 to 7 in 100,000)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(7 in 100,000 to 3 in 10,000)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(3 in 10,000 to 2 in 1,000)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(more than 2 in 1,000)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Untreated Collected Wastewater
#
# * **Layer_id:** [a1da2419-1271-4db1-b3b4-0bf16632436c](https://staging-api.globalforestwatch.org/v1/layer/a1da2419-1271-4db1-b3b4-0bf16632436c)
#
# Change `bws` with `ucw` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#808080",
#             "name": "No to low wastewater collected"
#         },
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<30%)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(30-60%)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(60-90%)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(90-100%)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(100%)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Coastal Eutrophication Potential
#
# * **Layer_id:** [ff9b7610-01d7-452f-81ae-18080e0d9e50](https://staging-api.globalforestwatch.org/v1/layer/ff9b7610-01d7-452f-81ae-18080e0d9e50)
#
# Change `bws` with `cep` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<-5)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(-5 to 0)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(0 to 1)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(1 to 5)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>5)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Unimproved/no drinking water
#
# * **Layer_id:** [e2702e54-1cb0-445e-b01a-439802a1eb48](https://staging-api.globalforestwatch.org/v1/layer/e2702e54-1cb0-445e-b01a-439802a1eb48)
#
# Change `bws` with `udw` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<2.5%)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(2.5-5%)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(5-10%)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(10-20%)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>20%)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### Unimproved/no sanitation
#
# * **Layer_id:** [6ad0e01e-ebc2-4747-988c-2e82902b6214](https://staging-api.globalforestwatch.org/v1/layer/6ad0e01e-ebc2-4747-988c-2e82902b6214)
#
# Change `bws` with `usa` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
# "legendConfig": {
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<2.5%)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(2.5-5%)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(5-10%)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(10-20%)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>20%)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### RepRisk Index
#
# * **Layer_id:** [bada4f7f-792b-4b58-b7c0-453414b9e0cf](https://staging-api.globalforestwatch.org/v1/layer/bada4f7f-792b-4b58-b7c0-453414b9e0cf)
#
# Change `bws` with `rri` in the *Water Stress* sql
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<25%)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(25-50%)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(50-60%)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(60-75%)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>75%)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```

# %% [markdown]
# ### **Projected**
#
# **Timeframe**:
#
# |Timeframe    |year    |
# |-------------|--------|
# |2030         |2030    |
# |2040         |2040    |
#
# **Type**:
#
# |Type                 |type    |
# |---------------------|--------|
# |Absolute value       |future_value|
# |Change from baseline |change_from_baseline|
#
# **Projected change indicator**:
#
# |Indicator            |indicator           |
# |---------------------|--------------------|
# |Water Stress         |water_stress        |
# |Seasonal Variability |seasonal_variability|
# |Water Supply         |water_supply        |
# |Water Demand         |water_demand        |
#
# **Scenario**:
#
# |Scenario             |scenario         |
# |---------------------|-----------------|
# |Optimistic           |optimistic       |
# |Pesimistic           |pessimistic      |
# |Business as usual    |business_as_usual|
#
#
# * **Account:** wri-rw
# * **Table Names:** water_risk_indicators_projections, wri_subcatchements, crops_projected
# * **Dataset_id:** [c6569326-2deb-4cdb-9c3e-16e1ce549f2a](https://staging-api.globalforestwatch.org/v1/dataset/c6569326-2deb-4cdb-9c3e-16e1ce549f2a)
#
# #### **Absolute values**
#
# #### Water stress
#
# * **Layer_id:** [935f9a49-a45a-4362-b9f7-7a8e22df5146](https://staging-api.globalforestwatch.org/v1/layer/935f9a49-a45a-4362-b9f7-7a8e22df5146)
#
# **Water Stress**:
#
# `Sql:`
# ```sql
# with r as (SELECT basinid, label FROM water_risk_indicators_projections
#            WHERE type = 'future_value' and indicator = 'water_stress' {{and}}
#
# SELECT s.cartodb_id, s.basinid, s.the_geom, s.the_geom_webmercator, r.label
# FROM wri_subcatchements s
# LEFT JOIN r on s.basinid=r.basinid
# WHERE s.the_geom is not null and r.label is not null
# ```
#
# `Cartocss :`
#
# ```css
# #water_risk_indicators_projections{
#   polygon-fill:transparent;
#   polygon-opacity: 1;
#   line-color:transparent;
#   line-width: 1;
#   line-opacity: 1;
# }
#
# #water_risk_indicators_projections [label='Extremely high (>80%)'] { polygon-fill:#990000; line-color:#990000 }
# #water_risk_indicators_projections [label='High (40-80%)'] { polygon-fill:  #FF1900; line-color:  #FF1900 }
# #water_risk_indicators_projections [label='Medium-high (20-40%)'] { polygon-fill: #FF9900; line-color: #FF9900 }
# #water_risk_indicators_projections [label='Low-medium (10-20%)'] { polygon-fill: #FFE600; line-color:  #FFE600 }
# #water_risk_indicators_projections [label='Low (<10%)'] { polygon-fill: #FFFF99; line-color:  #FFFF99 }
# #water_risk_indicators_projections [label='Arid and low water use'] { polygon-fill:#808080; line-color:  #808080 }
# #water_risk_indicators_projections [label='No data'] { polygon-fill: #4E4E4E; line-color:  #4E4E4E }
# ```
#
# **Crops**
#
# `Sql :`
# ```sql
# SELECT * FROM crops_projected {{where}}
# ```
#
# `Cartocss:`
#
# ```css
# #layer{polygon-fill: #FF6600; polygon-opacity: 1; line-color: #FF6600; line-width: 0.5; line-opacity: 1; comp-op: dst-in;}
# ```
#
# `sql_config:`
# ```json
# "sql_config": [
#     {
#     "key": "and",
#     "key_params": [
#         {
#             "required": True
#             "key": "year"
#         },
#         {
#             "required": True
#             "key": "scenario"
#         }
#     ]},
#     {
#     "key": "where",
#     "key_params": [
#         {
#             "required": False
#             "key": "iso"
#         },
#         {
#             "required": False
#             "key": "irrigation"
#         },
#         {
#             "required": False
#             "key": "crop"
#         },
#         {
#             "required": False
#             "key": "rank"
#         }
#     ]}
# ],
# ```
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#808080",
#             "name": "Arid and low water use"
#         },
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<10%)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(10-20%)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(20-40%)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(40-80%)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>80%)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# `interactionConfig:`
# ```json
# "interactionConfig": {
#   "output": [
#       {
#             "column": "label",
#             "format": None,
#             "prefix": "",
#             "property": "Category",
#             "suffix": "",
#             "type": "string"
#        },
#       {
#             "column": "name_cntr",
#             "format": None,
#             "prefix": "",
#             "property": "Country",
#             "suffix": "",
#             "type": "string"
#        },
#       {
#             "column": "crop",
#             "format": None,
#             "prefix": "",
#             "property": "Crop",
#             "suffix": "",
#             "type": "string"
#        }
#     ]
# }
# ```
#
# #### Seasonal Variability
#
# * **Layer_id:** [9d47a284-c196-4e33-a3c8-058823ccaa2f](https://staging-api.globalforestwatch.org/v1/layer/9d47a284-c196-4e33-a3c8-058823ccaa2f)
#
# `Sql:`
# ```sql
# with r as (SELECT basinid, label FROM water_risk_indicators_projections
#            WHERE type = 'future_value' and indicator = 'seasonal_variability' {{and}}
#
# SELECT s.cartodb_id, s.basinid, s.the_geom, s.the_geom_webmercator, r.label
# FROM wri_subcatchements s
# LEFT JOIN r on s.basinid=r.basinid
# WHERE s.the_geom is not null and r.label is not null
# ```
#
# `Cartocss:`
# ``` css
# #water_risk_indicators_projections{
#   polygon-fill:transparent;
#   polygon-opacity: 1;
#   line-color:transparent;
#   line-width: 1;
#   line-opacity: 1;
# }
#
# #water_risk_indicators_projections [label='Extremely High (>1.33)'] { polygon-fill:#990000; line-color:#990000 }
# #water_risk_indicators_projections [label='High (1.0-1.33)'] { polygon-fill:  #FF1900; line-color:  #FF1900 }
# #water_risk_indicators_projections [label='Medium-high (0.66-1.0)'] { polygon-fill: #FF9900; line-color: #FF9900 }
# #water_risk_indicators_projections [label='Low-medium (0.33-0.66)'] { polygon-fill: #FFE600; line-color:  #FFE600 }
# #water_risk_indicators_projections [label='Low (<0.33)'] { polygon-fill: #FFFF99; line-color:  #FFFF99 }
# #water_risk_indicators_projections [label='No data'] { polygon-fill: #4E4E4E; line-color:  #4E4E4E }
# ```
#
# `legenConfig:`
# ```json
#
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#FFFF99",
#             "value": "(<0.33)",
#             "name": "Low"
#         },
#         {
#             "color": "#FFE600",
#             "value": "(0.33-0.66)",
#             "name": "Low-medium"
#         },
#         {
#             "color": "#FF9900",
#             "value": "(0.66-1.00)",
#             "name": "Medium-high"
#         },
#         {
#             "color": "#FF1900",
#             "value": "(1.00-1.33)",
#             "name": "High"
#         },
#         {
#             "color": "#990000",
#             "value": "(>1.33)",
#             "name": "Extremely high"
#         }
#     ],
#     "type": "choropleth"
# }
# ```
#
# #### **Change from baseline**
#
# #### Water stress
#
# * **Layer_id:** [d8439b5e-c7f0-4021-9347-f1e68ef8122e](https://staging-api.globalforestwatch.org/v1/layer/d8439b5e-c7f0-4021-9347-f1e68ef8122e)
#
# `Sql:`
# ```sql
# with r as (SELECT basinid, label FROM water_risk_indicators_projections
#            WHERE type = 'change_from_baseline' and indicator = 'water_stress' {{and}}
#
# SELECT s.cartodb_id, s.basinid, s.the_geom, s.the_geom_webmercator, r.label
# FROM wri_subcatchements s
# LEFT JOIN r on s.basinid=r.basinid
# WHERE s.the_geom is not null and r.label is not null
# ```
#
# `Cartocss :`
#
# ```css
# #water_risk_indicators_projections{
#   polygon-fill:transparent;
#   polygon-opacity: 1;
#   line-color:transparent;
#   line-width: 1;
#   line-opacity: 1;
# }
#
# #water_risk_indicators_projections [label='2.8x or greater decrease'] { polygon-fill:#0099CD; line-color:#0099CD }
# #water_risk_indicators_projections [label='2x decrease'] { polygon-fill:  #74AFD1; line-color:  #74AFD1 }
# #water_risk_indicators_projections [label='1.4x decrease'] { polygon-fill: #AAC7D8; line-color: #AAC7D8 }
# #water_risk_indicators_projections [label='Near normal'] { polygon-fill: #DEDEDD; line-color:  #DEDEDD }
# #water_risk_indicators_projections [label='1.4x increase'] { polygon-fill: #F8AB95; line-color:  #F8AB95 }
# #water_risk_indicators_projections [label='2x increase'] { polygon-fill: #F27454; line-color:  #F27454 }
# #water_risk_indicators_projections [label='2.8x or greater increase'] { polygon-fill: #ED2924; line-color:  #ED2924 }
# #water_risk_indicators_projections [label='No data'] { polygon-fill: #4F4F4F; line-color:  #4F4F4F }
# ```
#
# `legenConfig:`
# ```json
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#0099CD",
#             "name": "2.8x or greater decrease"
#         },
#         {
#             "color": "#74AFD1",
#             "name": "2x decrease"
#         },
#         {
#             "color": "#AAC7D8",
#             "name": "1.4x decrease"
#         },
#         {
#             "color": "#DEDEDD",
#             "name": "Near normal"
#         },
#         {
#             "color": "#F8AB95",
#             "name": "1.4x increase"
#         },
#         {
#             "color": "#F27454",
#             "name": "2x increase"
#         },
#         {
#             "color": "#ED2924",
#             "name": "2.8x or greater increase"
#         }
#         ],
#     "type": "choropleth"
# }
# ```
#
# #### Seasonal Variability
#
# * **Layer_id:** [d93b26f3-be45-4fc5-8336-4f03ae6347dd](https://staging-api.globalforestwatch.org/v1/layer/d93b26f3-be45-4fc5-8336-4f03ae6347dd)
#
# `Sql:`
# ```sql
# with r as (SELECT basinid, label FROM water_risk_indicators_projections
#            WHERE type = 'change_from_baseline' and indicator = 'seasonal_variability' {{and}}
#
# SELECT s.cartodb_id, s.basinid, s.the_geom, s.the_geom_webmercator, r.label
# FROM wri_subcatchements s
# LEFT JOIN r on s.basinid=r.basinid
# WHERE s.the_geom is not null and r.label is not null
# ```
#
# `Cartocss :`
#
# ```css
# #water_risk_indicators_projections{
#   polygon-fill:transparent;
#   polygon-opacity: 1;
#   line-color:transparent;
#   line-width: 1;
#   line-opacity: 1;
# }
#
# #water_risk_indicators_projections [label='1.3x or greater decrease'] { polygon-fill:#0099CD; line-color:#0099CD }
# #water_risk_indicators_projections [label='1.2x decrease'] { polygon-fill:  #74AFD1; line-color:  #74AFD1 }
# #water_risk_indicators_projections [label='1.1x decrease'] { polygon-fill: #AAC7D8; line-color: #AAC7D8 }
# #water_risk_indicators_projections [label='Near normal'] { polygon-fill: #DEDEDD; line-color:  #DEDEDD }
# #water_risk_indicators_projections [label='1.1x increase'] { polygon-fill: #F8AB95; line-color:  #F8AB95 }
# #water_risk_indicators_projections [label='1.2x increase'] { polygon-fill: #F27454; line-color:  #F27454 }
# #water_risk_indicators_projections [label='1.3x or greater increase'] { polygon-fill: #ED2924; line-color:  #ED2924 }
# #water_risk_indicators_projections [label='No data'] { polygon-fill: #4F4F4F; line-color:  #4F4F4F }
# ```
#
# `legenConfig:`
# ```json
# "legendConfig": {
#     "disclaimer": [
#         {
#             "color": "#4E4E4E",
#             "name": "No data"
#         }
#     ],
#     "items": [
#         {
#             "color": "#0099CD",
#             "name": "1.3x or greater decrease"
#         },
#         {
#             "color": "#74AFD1",
#             "name": "1.2x decrease"
#         },
#         {
#             "color": "#AAC7D8",
#             "name": "1.1x decrease"
#          },
#          {
#             "color": "#DEDEDD",
#             "name": "Near normal"
#         },
#         {
#             "color": "#F8AB95",
#             "name": "1.1x increase"
#         },
#         {
#             "color": "#F27454",
#             "name": "1.2x increase"
#         },
#         {
#             "color": "#ED2924",
#             "name": "1.3x or greater increase"
#         }
#         ],
#     "type": "choropleth"
# },
# ```

# %% [markdown]
# ## Food Security
#
# #### Food demand for crop
# * **Account:** wri-rw
# * **Table Names:** combined01_prepared, impact_regions_159
# * **Dataset_id:** [76f53ba4-b1d9-4385-8bab-f56aa707d961](https://staging-api.globalforestwatch.org/v1/dataset/76f53ba4-b1d9-4385-8bab-f56aa707d961)
# * **Layer_id:** [0699ced2-960f-4f06-8792-62f6c34b4e39](https://staging-api.globalforestwatch.org/v1/layer/0699ced2-960f-4f06-8792-62f6c34b4e39)
#
# #### Total crop production
# * **Account:** wri-rw
# * **Table Names:** combined01_prepared, impact_regions_159
# * **Dataset_id:** [0eb7ef57-037b-4356-8902-04a39cf4bd24](https://staging-api.globalforestwatch.org/v1/dataset/0eb7ef57-037b-4356-8902-04a39cf4bd24)
# * **Layer_id:** [efafaa9f-37ec-4f51-be7d-999f58e6823b](https://staging-api.globalforestwatch.org/v1/layer/efafaa9f-37ec-4f51-be7d-999f58e6823b)
#
# #### Crop net trade
# * **Account:** wri-rw
# * **Table Names:** combined01_prepared, impact_regions_159
# * **Dataset_id:** [bc60a695-ab95-4264-8058-bd61d13c4918](https://staging-api.globalforestwatch.org/v1/dataset/bc60a695-ab95-4264-8058-bd61d13c4918)
# * **Layer_id:** [b8e135d2-b64f-4ea3-93e9-9f8d1245fb2a](https://staging-api.globalforestwatch.org/v1/layer/b8e135d2-b64f-4ea3-93e9-9f8d1245fb2a)
#
# #### Kilocalories per person
# * **Account:** wri-rw
# * **Table Names:** combined01_prepared, impact_regions_159
# * **Dataset_id:** [ccdaede2-5343-49d6-8ea9-769528c3ab92](https://staging-api.globalforestwatch.org/v1/dataset/ccdaede2-5343-49d6-8ea9-769528c3ab92)
# * **Layer_id:** [c29b190b-6801-49ed-a101-6770525467c4](https://staging-api.globalforestwatch.org/v1/layer/c29b190b-6801-49ed-a101-6770525467c4)
#
# #### Population at risk of hunger
# * **Account:** wri-rw
# * **Table Names:** combined01_prepared, impact_regions_159
# * **Dataset_id:** [1c9a1e4f-455b-4c03-ac88-dd2242a2e4b1](https://staging-api.globalforestwatch.org/v1/dataset/1c9a1e4f-455b-4c03-ac88-dd2242a2e4b1)
# * **Layer_id:** [63976c45-d991-4495-a318-45950912510a](https://staging-api.globalforestwatch.org/v1/layer/63976c45-d991-4495-a318-45950912510a)
